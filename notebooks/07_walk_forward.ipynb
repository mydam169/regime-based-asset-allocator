# %% [markdown]
# # Walk-Forward Backtest
#
# Simulates real-time portfolio management by re-estimating the regime model on an expanding window and using **filtered probabilities** (not smoothed) for regime detection.
#
# ## Why walk-forward?
#
# The fixed train/test split in notebooks 03-04 has two sources of look-ahead bias:
#
# 1. **Smoothed vs filtered probabilities.** The Kim smoother computes P(S_t | y₁:T) — it uses the entire sequence including future observations. In a real portfolio you only have P(S_t | y₁:t).  Walk-forward uses filtered probabilities exclusively.
#
# 2. **Static parameters.** The model is fitted once on training data. In practice a portfolio manager would update parameters as new macro data arrives.  Walk-forward refits annually on all available data.
#
# ## Design
#
# | Parameter | Value |
# |---|---|
# | Initial training window | 120 months (10 years) |
# | Refit frequency | Every 12 months (annual) |
# | Between refits | Monthly filtered probability update (cheap forward pass) |
# | Regime detection | Filtered probs argmax — no look-ahead |
# | Portfolio weights | Regime-conditional MVO (GMV) on filtered-regime obs |
# | Signal lag | 1 month — weights from t applied to returns at t+1 |
# | Transaction costs | 10 bps one-way |
#
# ## Model hierarchy
#
# | Model | Preprocessing | Role |
# |---|---|---|
# | HMM | PLS | **Primary result** |
# | HMM | PCA | Robustness check 1 |
# | MSVAR | PCA | Robustness check 2 (caveat: VAR mean structure not interpretable on PCA components) |
#
# **Computational note:** With PCA inputs (~6 components), annual refitting over a 7-year test period requires ~7 full model estimations.  Runtime ~2-5 minutes for HMM, ~5-15 minutes for MSVAR.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys, os

sys.path.insert(0, os.path.abspath('..'))

from src.constants import ASSET_COLS, REDUCTION_METHOD, N_COMPONENTS_PCA, N_COMPONENTS_PLS
from src.data_loader import load_macro_data, load_asset_data
from src.metrics import summarize_performance
from src.walk_forward import walk_forward_backtest, compare_walk_forward

BASE_DIR           = Path('..')
DATA_DIR           = BASE_DIR / 'data'
OUTPUT_TABLES_DIR  = BASE_DIR / 'outputs' / 'tables'
OUTPUT_FIGURES_DIR = BASE_DIR / 'outputs' / 'figures'
OUTPUT_TABLES_DIR.mkdir(parents=True, exist_ok=True)
OUTPUT_FIGURES_DIR.mkdir(parents=True, exist_ok=True)

# Risk-free rate: time-varying monthly rate from FEDFUNDS.
# For walk-forward, we use the actual FEDFUNDS rate for each month
# rather than a fixed average, since the model is updated annually
# and spans a period with significant rate variation (near-zero 2000-2022,
# then 5%+ in 2023-2025).
# We load this after data is available in cell 4.
ANNUAL_RISK_FREE_RATE = 0.0266   # fallback only — overridden below
INITIAL_TRAIN_MONTHS = 346

# set warnigns to ignore for cleaner output
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load data

# %%
macro_df = load_macro_data(DATA_DIR / "macro_clean.csv")
asset_df = load_asset_data(DATA_DIR / "market_clean.csv")[ASSET_COLS]

print(f'Macro data : {macro_df.shape}  '
      f'{macro_df.index.min().date()} to {macro_df.index.max().date()}')
print(f'Asset data : {asset_df.shape}  '
      f'{asset_df.index.min().date()} to {asset_df.index.max().date()}')
# Out:
# Macro data : (431, 15)  1990-02-28 to 2025-12-31
# Asset data : (431, 3)  1990-02-28 to 2025-12-31

# %%
# ── Time-varying risk-free rate ──────────────────────────────────────────
# Load FEDFUNDS (annualized %) and convert to monthly decimal rate.
# Used in summarize_performance() for each evaluation month.
macro_raw = pd.read_csv(DATA_DIR / 'macro_data.csv', index_col=0,
                         parse_dates=True).sort_index()
fed_col = 'fed_funds_rate' if 'fed_funds_rate' in macro_raw.columns else macro_raw.columns[0]
# FEDFUNDS in macro_data is already in decimal (0.05 = 5%) or percent?
# Check: if max > 1, it's in percent — convert to decimal
fedfunds = macro_raw[fed_col].copy()
if fedfunds.max() > 1:
    fedfunds = fedfunds / 100.0
# Monthly rf rate = annualized / 12
monthly_rf = fedfunds / 12

print(f'FEDFUNDS range: {fedfunds.min():.4f} to {fedfunds.max():.4f} (annualized)')
print(f'Monthly rf range: {monthly_rf.min():.6f} to {monthly_rf.max():.6f}')
# Out:
# FEDFUNDS range: 0.0005 to 0.0829 (annualized)
# Monthly rf range: 0.000042 to 0.006908

# %% [markdown]
# ## Primary model: HMM with PLS
#
# PLS is used as the primary dimensionality reduction technique since unlike PCA which outputs components that explain maximum variance of the macro series, the PLS searches for components that maximizie covariance with asset returns. PLS is thus more aligned with the portfolio objective.

# %%
hmm_pls_returns, hmm_pls_states, hmm_pls_probs, hmm_pls_filt_probs = walk_forward_backtest(
    macro_df             = macro_df,
    asset_df             = asset_df,
    model_type           = 'hmm',
    initial_train_months = INITIAL_TRAIN_MONTHS,  
    refit_every          = 12,
    dim_reduction        = 'pls',
    n_components         = 4,
    winsor_clip          = 4.0,
    transaction_cost_bps = 10,
    objective            = 'min_variance',
    rf                   = 0.0,
    long_only            = True,
    verbose              = False,
)
hmm_pls_returns.head()
# Out:
# Best log-likelihood (per sample): -1852.7022
# Sort method: 'trace'
# Transition matrix:
# [[0.96014966 0.03985034]
#  [0.07376809 0.92623191]]
# State durations (months): ['25.1', '13.6']
# State 0 = Expansion  (tr(Σ)=2.6589  PC1_mean=-0.570)
# State 1 = Recession  (tr(Σ)=5.4013  PC1_mean=0.955)
#
# ── Regime 0  (226 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.47%  →  BS +13.60%
#     treasury_fund   : sample +5.93%  →  BS +6.53%
#     gold_fund       : sample +0.10%  →  BS +1.87%
#   Bayes-Stein φ  : 0.3719  (mild shrinkage)
#   Ledoit-Wolf α  : 0.4272
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.22%
#     treasury_fund   : 9.51%
#     gold_fund       : 10.86%
#
# ── Regime 1  (120 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +0.98%  →  BS +5.30%
#     treasury_fund   : sample +10.56%  →  BS +9.18%
#     gold_fund       : sample +13.82%  →  BS +9.73%
#   Bayes-Stein φ  : 0.4563  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1659
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.77%
#     treasury_fund   : 12.38%
#     gold_fund       : 14.54%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.56%
#   Volatility     (ann.) : 6.12%
#   Sharpe ratio          : 1.2355
#   Weights:
#     index_fund    : 0.3442  (34.4%)
#     treasury_fund : 0.3546  (35.5%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.61%
#   Volatility     (ann.) : 7.25%
#   Sharpe ratio          : 1.4635
#   Weights:
#     index_fund    : 0.6267  (62.7%)
#     treasury_fund : 0.2975  (29.7%)
#     gold_fund     : 0.0759  (7.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.32%
#   Volatility     (ann.) : 7.87%
#   Sharpe ratio          : 1.0576
#   Weights:
#     index_fund    : 0.2609  (26.1%)
#     treasury_fund : 0.4594  (45.9%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.57%
#   Volatility     (ann.) : 7.99%
#   Sharpe ratio          : 1.0734
#   Weights:
#     index_fund    : 0.2021  (20.2%)
#     treasury_fund : 0.4760  (47.6%)
#     gold_fund     : 0.3219  (32.2%)
#
# ── Regime 0  (227 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.90%  →  BS +13.01%
#     treasury_fund   : sample +6.20%  →  BS +6.79%
#     gold_fund       : sample +0.22%  →  BS +2.06%
#   Bayes-Stein φ  : 0.3925  (mild shrinkage)
#   Ledoit-Wolf α  : 0.4719
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.41%
#     treasury_fund   : 9.64%
#     gold_fund       : 10.85%
#
# ── Regime 1  (120 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +0.98%  →  BS +5.22%
#     treasury_fund   : sample +10.56%  →  BS +9.23%
#     gold_fund       : sample +13.82%  →  BS +9.67%
#   Bayes-Stein φ  : 0.4663  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1659
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.77%
#     treasury_fund   : 12.38%
#     gold_fund       : 14.54%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.47%
#   Volatility     (ann.) : 6.13%
#   Sharpe ratio          : 1.2189
#   Weights:
#     index_fund    : 0.3404  (34.0%)
#     treasury_fund : 0.3549  (35.5%)
#     gold_fund     : 0.3047  (30.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.06%
#   Volatility     (ann.) : 7.11%
#   Sharpe ratio          : 1.4149
#   Weights:
#     index_fund    : 0.5906  (59.1%)
#     treasury_fund : 0.3244  (32.4%)
#     gold_fund     : 0.0851  (8.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.31%
#   Volatility     (ann.) : 7.87%
#   Sharpe ratio          : 1.0558
#   Weights:
#     index_fund    : 0.2609  (26.1%)
#     treasury_fund : 0.4594  (45.9%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.57%
#   Volatility     (ann.) : 7.99%
#   Sharpe ratio          : 1.0721
#   Weights:
#     index_fund    : 0.2010  (20.1%)
#     treasury_fund : 0.4790  (47.9%)
#     gold_fund     : 0.3200  (32.0%)
#
# ── Regime 0  (228 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.29%  →  BS +13.36%
#     treasury_fund   : sample +6.20%  →  BS +6.78%
#     gold_fund       : sample +0.40%  →  BS +2.20%
#   Bayes-Stein φ  : 0.3893  (mild shrinkage)
#   Ledoit-Wolf α  : 0.4727
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.48%
#     treasury_fund   : 9.65%
#     gold_fund       : 10.86%
#
# ── Regime 1  (120 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +0.98%  →  BS +5.33%
#     treasury_fund   : sample +10.56%  →  BS +9.23%
#     gold_fund       : sample +13.82%  →  BS +9.74%
#   Bayes-Stein φ  : 0.4646  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1659
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.77%
#     treasury_fund   : 12.38%
#     gold_fund       : 14.54%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.61%
#   Volatility     (ann.) : 6.16%
#   Sharpe ratio          : 1.2355
#   Weights:
#     index_fund    : 0.3368  (33.7%)
#     treasury_fund : 0.3587  (35.9%)
#     gold_fund     : 0.3045  (30.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.29%
#   Volatility     (ann.) : 7.16%
#   Sharpe ratio          : 1.4369
#   Weights:
#     index_fund    : 0.5929  (59.3%)
#     treasury_fund : 0.3202  (32.0%)
#     gold_fund     : 0.0868  (8.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.36%
#   Volatility     (ann.) : 7.87%
#   Sharpe ratio          : 1.0619
#   Weights:
#     index_fund    : 0.2609  (26.1%)
#     treasury_fund : 0.4594  (45.9%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.60%
#   Volatility     (ann.) : 7.99%
#   Sharpe ratio          : 1.0775
#   Weights:
#     index_fund    : 0.2024  (20.2%)
#     treasury_fund : 0.4770  (47.7%)
#     gold_fund     : 0.3206  (32.1%)
#
# ── Regime 0  (229 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.39%  →  BS +13.46%
#     treasury_fund   : sample +6.10%  →  BS +6.70%
#     gold_fund       : sample +0.51%  →  BS +2.29%
#   Bayes-Stein φ  : 0.3879  (mild shrinkage)
#   Ledoit-Wolf α  : 0.4782
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.47%
#     treasury_fund   : 9.65%
#     gold_fund       : 10.84%
#
# ── Regime 1  (120 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +0.98%  →  BS +5.37%
#     treasury_fund   : sample +10.56%  →  BS +9.20%
#     gold_fund       : sample +13.82%  →  BS +9.77%
#   Bayes-Stein φ  : 0.4647  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1659
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.77%
#     treasury_fund   : 12.38%
#     gold_fund       : 14.54%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.63%
#   Volatility     (ann.) : 6.14%
#   Sharpe ratio          : 1.2422
#   Weights:
#     index_fund    : 0.3366  (33.7%)
#     treasury_fund : 0.3589  (35.9%)
#     gold_fund     : 0.3045  (30.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.33%
#   Volatility     (ann.) : 7.15%
#   Sharpe ratio          : 1.4451
#   Weights:
#     index_fund    : 0.5955  (59.5%)
#     treasury_fund : 0.3141  (31.4%)
#     gold_fund     : 0.0904  (9.0%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.36%
#   Volatility     (ann.) : 7.87%
#   Sharpe ratio          : 1.0623
#   Weights:
#     index_fund    : 0.2609  (26.1%)
#     treasury_fund : 0.4594  (45.9%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.60%
#   Volatility     (ann.) : 7.98%
#   Sharpe ratio          : 1.0778
#   Weights:
#     index_fund    : 0.2030  (20.3%)
#     treasury_fund : 0.4754  (47.5%)
#     gold_fund     : 0.3217  (32.2%)
#
# ── Regime 0  (230 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.39%  →  BS +13.48%
#     treasury_fund   : sample +6.36%  →  BS +6.92%
#     gold_fund       : sample +0.44%  →  BS +2.21%
#   Bayes-Stein φ  : 0.3873  (mild shrinkage)
#   Ledoit-Wolf α  : 0.5007
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.45%
#     treasury_fund   : 9.70%
#     gold_fund       : 10.81%
#
# ── Regime 1  (120 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +0.98%  →  BS +5.36%
#     treasury_fund   : sample +10.56%  →  BS +9.28%
#     gold_fund       : sample +13.82%  →  BS +9.75%
#   Bayes-Stein φ  : 0.4630  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1659
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.77%
#     treasury_fund   : 12.38%
#     gold_fund       : 14.54%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.69%
#   Volatility     (ann.) : 6.13%
#   Sharpe ratio          : 1.2530
#   Weights:
#     index_fund    : 0.3371  (33.7%)
#     treasury_fund : 0.3561  (35.6%)
#     gold_fund     : 0.3068  (30.7%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.39%
#   Volatility     (ann.) : 7.13%
#   Sharpe ratio          : 1.4570
#   Weights:
#     index_fund    : 0.5920  (59.2%)
#     treasury_fund : 0.3210  (32.1%)
#     gold_fund     : 0.0870  (8.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.39%
#   Volatility     (ann.) : 7.87%
#   Sharpe ratio          : 1.0663
#   Weights:
#     index_fund    : 0.2609  (26.1%)
#     treasury_fund : 0.4594  (45.9%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.64%
#   Volatility     (ann.) : 7.98%
#   Sharpe ratio          : 1.0818
#   Weights:
#     index_fund    : 0.2027  (20.3%)
#     treasury_fund : 0.4777  (47.8%)
#     gold_fund     : 0.3196  (32.0%)
#
# ── Regime 0  (231 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.56%  →  BS +13.65%
#     treasury_fund   : sample +6.23%  →  BS +6.80%
#     gold_fund       : sample +0.38%  →  BS +2.14%
#   Bayes-Stein φ  : 0.3829  (mild shrinkage)
#   Ledoit-Wolf α  : 0.5037
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.45%
#     treasury_fund   : 9.70%
#     gold_fund       : 10.79%
#
# ── Regime 1  (120 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +0.98%  →  BS +5.38%
#     treasury_fund   : sample +10.56%  →  BS +9.25%
#     gold_fund       : sample +13.82%  →  BS +9.77%
#   Bayes-Stein φ  : 0.4583  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1659
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.77%
#     treasury_fund   : 12.38%
#     gold_fund       : 14.54%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.68%
#   Volatility     (ann.) : 6.12%
#   Sharpe ratio          : 1.2541
#   Weights:
#     index_fund    : 0.3372  (33.7%)
#     treasury_fund : 0.3558  (35.6%)
#     gold_fund     : 0.3070  (30.7%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.51%
#   Volatility     (ann.) : 7.17%
#   Sharpe ratio          : 1.4674
#   Weights:
#     index_fund    : 0.5996  (60.0%)
#     treasury_fund : 0.3156  (31.6%)
#     gold_fund     : 0.0848  (8.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.39%
#   Volatility     (ann.) : 7.87%
#   Sharpe ratio          : 1.0658
#   Weights:
#     index_fund    : 0.2609  (26.1%)
#     treasury_fund : 0.4594  (45.9%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.63%
#   Volatility     (ann.) : 7.98%
#   Sharpe ratio          : 1.0813
#   Weights:
#     index_fund    : 0.2029  (20.3%)
#     treasury_fund : 0.4766  (47.7%)
#     gold_fund     : 0.3205  (32.0%)
#
# ── Regime 0  (232 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.17%  →  BS +13.27%
#     treasury_fund   : sample +6.55%  →  BS +7.09%
#     gold_fund       : sample +0.37%  →  BS +2.17%
#   Bayes-Stein φ  : 0.3929  (mild shrinkage)
#   Ledoit-Wolf α  : 0.5609
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 9.84%
#     gold_fund       : 10.76%
#
# ── Regime 1  (120 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +0.98%  →  BS +5.31%
#     treasury_fund   : sample +10.56%  →  BS +9.34%
#     gold_fund       : sample +13.82%  →  BS +9.71%
#   Bayes-Stein φ  : 0.4635  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1659
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.77%
#     treasury_fund   : 12.38%
#     gold_fund       : 14.54%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.64%
#   Volatility     (ann.) : 6.12%
#   Sharpe ratio          : 1.2485
#   Weights:
#     index_fund    : 0.3363  (33.6%)
#     treasury_fund : 0.3534  (35.3%)
#     gold_fund     : 0.3103  (31.0%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.25%
#   Volatility     (ann.) : 7.09%
#   Sharpe ratio          : 1.4463
#   Weights:
#     index_fund    : 0.5804  (58.0%)
#     treasury_fund : 0.3337  (33.4%)
#     gold_fund     : 0.0858  (8.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.39%
#   Volatility     (ann.) : 7.87%
#   Sharpe ratio          : 1.0663
#   Weights:
#     index_fund    : 0.2609  (26.1%)
#     treasury_fund : 0.4594  (45.9%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.64%
#   Volatility     (ann.) : 7.99%
#   Sharpe ratio          : 1.0822
#   Weights:
#     index_fund    : 0.2018  (20.2%)
#     treasury_fund : 0.4802  (48.0%)
#     gold_fund     : 0.3179  (31.8%)
#
# ── Regime 0  (233 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.44%  →  BS +13.50%
#     treasury_fund   : sample +6.58%  →  BS +7.11%
#     gold_fund       : sample +0.67%  →  BS +2.43%
#   Bayes-Stein φ  : 0.3939  (mild shrinkage)
#   Ledoit-Wolf α  : 0.5447
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.56%
#     treasury_fund   : 9.83%
#     gold_fund       : 10.82%
#
# ── Regime 1  (120 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +0.98%  →  BS +5.42%
#     treasury_fund   : sample +10.56%  →  BS +9.33%
#     gold_fund       : sample +13.82%  →  BS +9.78%
#   Bayes-Stein φ  : 0.4658  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1659
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.77%
#     treasury_fund   : 12.38%
#     gold_fund       : 14.54%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.81%
#   Volatility     (ann.) : 6.15%
#   Sharpe ratio          : 1.2695
#   Weights:
#     index_fund    : 0.3350  (33.5%)
#     treasury_fund : 0.3572  (35.7%)
#     gold_fund     : 0.3078  (30.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.38%
#   Volatility     (ann.) : 7.09%
#   Sharpe ratio          : 1.4638
#   Weights:
#     index_fund    : 0.5790  (57.9%)
#     treasury_fund : 0.3301  (33.0%)
#     gold_fund     : 0.0910  (9.1%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.44%
#   Volatility     (ann.) : 7.87%
#   Sharpe ratio          : 1.0723
#   Weights:
#     index_fund    : 0.2609  (26.1%)
#     treasury_fund : 0.4594  (45.9%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.68%
#   Volatility     (ann.) : 7.98%
#   Sharpe ratio          : 1.0877
#   Weights:
#     index_fund    : 0.2033  (20.3%)
#     treasury_fund : 0.4781  (47.8%)
#     gold_fund     : 0.3187  (31.9%)
#
# ── Regime 0  (234 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.47%  →  BS +13.52%
#     treasury_fund   : sample +6.56%  →  BS +7.10%
#     gold_fund       : sample +0.87%  →  BS +2.61%
#   Bayes-Stein φ  : 0.3963  (mild shrinkage)
#   Ledoit-Wolf α  : 0.5371
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.55%
#     treasury_fund   : 9.81%
#     gold_fund       : 10.82%
#
# ── Regime 1  (120 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +0.98%  →  BS +5.47%
#     treasury_fund   : sample +10.56%  →  BS +9.32%
#     gold_fund       : sample +13.82%  →  BS +9.81%
#   Bayes-Stein φ  : 0.4689  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1659
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.77%
#     treasury_fund   : 12.38%
#     gold_fund       : 14.54%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.87%
#   Volatility     (ann.) : 6.15%
#   Sharpe ratio          : 1.2806
#   Weights:
#     index_fund    : 0.3351  (33.5%)
#     treasury_fund : 0.3582  (35.8%)
#     gold_fund     : 0.3066  (30.7%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.36%
#   Volatility     (ann.) : 7.05%
#   Sharpe ratio          : 1.4691
#   Weights:
#     index_fund    : 0.5759  (57.6%)
#     treasury_fund : 0.3270  (32.7%)
#     gold_fund     : 0.0971  (9.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.45%
#   Volatility     (ann.) : 7.87%
#   Sharpe ratio          : 1.0740
#   Weights:
#     index_fund    : 0.2609  (26.1%)
#     treasury_fund : 0.4594  (45.9%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.69%
#   Volatility     (ann.) : 7.98%
#   Sharpe ratio          : 1.0891
#   Weights:
#     index_fund    : 0.2039  (20.4%)
#     treasury_fund : 0.4768  (47.7%)
#     gold_fund     : 0.3193  (31.9%)
#
# ── Regime 0  (235 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.32%  →  BS +13.33%
#     treasury_fund   : sample +7.08%  →  BS +7.56%
#     gold_fund       : sample +1.17%  →  BS +2.93%
#   Bayes-Stein φ  : 0.4105  (mild shrinkage)
#   Ledoit-Wolf α  : 0.5611
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.59%
#     treasury_fund   : 10.00%
#     gold_fund       : 10.88%
#
# ── Regime 1  (120 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +0.98%  →  BS +5.52%
#     treasury_fund   : sample +10.56%  →  BS +9.46%
#     gold_fund       : sample +13.82%  →  BS +9.82%
#   Bayes-Stein φ  : 0.4782  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1659
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.77%
#     treasury_fund   : 12.38%
#     gold_fund       : 14.54%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.11%
#   Volatility     (ann.) : 6.20%
#   Sharpe ratio          : 1.3074
#   Weights:
#     index_fund    : 0.3418  (34.2%)
#     treasury_fund : 0.3506  (35.1%)
#     gold_fund     : 0.3076  (30.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.30%
#   Volatility     (ann.) : 6.99%
#   Sharpe ratio          : 1.4733
#   Weights:
#     index_fund    : 0.5587  (55.9%)
#     treasury_fund : 0.3359  (33.6%)
#     gold_fund     : 0.1054  (10.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.53%
#   Volatility     (ann.) : 7.87%
#   Sharpe ratio          : 1.0841
#   Weights:
#     index_fund    : 0.2609  (26.1%)
#     treasury_fund : 0.4594  (45.9%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.77%
#   Volatility     (ann.) : 7.98%
#   Sharpe ratio          : 1.0991
#   Weights:
#     index_fund    : 0.2041  (20.4%)
#     treasury_fund : 0.4796  (48.0%)
#     gold_fund     : 0.3163  (31.6%)
#
# ── Regime 0  (236 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.35%
#     treasury_fund   : sample +6.91%  →  BS +7.42%
#     gold_fund       : sample +1.21%  →  BS +2.95%
#   Bayes-Stein φ  : 0.4093  (mild shrinkage)
#   Ledoit-Wolf α  : 0.5723
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.57%
#     treasury_fund   : 10.01%
#     gold_fund       : 10.85%
#
# ── Regime 1  (120 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +0.98%  →  BS +5.52%
#     treasury_fund   : sample +10.56%  →  BS +9.40%
#     gold_fund       : sample +13.82%  →  BS +9.83%
#   Bayes-Stein φ  : 0.4779  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1659
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.77%
#     treasury_fund   : 12.38%
#     gold_fund       : 14.54%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.07%
#   Volatility     (ann.) : 6.19%
#   Sharpe ratio          : 1.3032
#   Weights:
#     index_fund    : 0.3419  (34.2%)
#     treasury_fund : 0.3496  (35.0%)
#     gold_fund     : 0.3086  (30.9%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.27%
#   Volatility     (ann.) : 6.99%
#   Sharpe ratio          : 1.4706
#   Weights:
#     index_fund    : 0.5626  (56.3%)
#     treasury_fund : 0.3294  (32.9%)
#     gold_fund     : 0.1080  (10.8%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.51%
#   Volatility     (ann.) : 7.87%
#   Sharpe ratio          : 1.0815
#   Weights:
#     index_fund    : 0.2609  (26.1%)
#     treasury_fund : 0.4594  (45.9%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.75%
#   Volatility     (ann.) : 7.98%
#   Sharpe ratio          : 1.0964
#   Weights:
#     index_fund    : 0.2043  (20.4%)
#     treasury_fund : 0.4781  (47.8%)
#     gold_fund     : 0.3176  (31.8%)
#
# ── Regime 0  (237 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.40%  →  BS +13.43%
#     treasury_fund   : sample +6.83%  →  BS +7.34%
#     gold_fund       : sample +1.15%  →  BS +2.88%
#   Bayes-Stein φ  : 0.4064  (mild shrinkage)
#   Ledoit-Wolf α  : 0.5716
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.55%
#     treasury_fund   : 10.00%
#     gold_fund       : 10.83%
#
# ── Regime 1  (120 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +0.98%  →  BS +5.52%
#     treasury_fund   : sample +10.56%  →  BS +9.38%
#     gold_fund       : sample +13.82%  →  BS +9.83%
#   Bayes-Stein φ  : 0.4747  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1659
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.77%
#     treasury_fund   : 12.38%
#     gold_fund       : 14.54%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.05%
#   Volatility     (ann.) : 6.18%
#   Sharpe ratio          : 1.3021
#   Weights:
#     index_fund    : 0.3420  (34.2%)
#     treasury_fund : 0.3495  (34.9%)
#     gold_fund     : 0.3085  (30.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.32%
#   Volatility     (ann.) : 7.00%
#   Sharpe ratio          : 1.4749
#   Weights:
#     index_fund    : 0.5675  (56.7%)
#     treasury_fund : 0.3268  (32.7%)
#     gold_fund     : 0.1058  (10.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.50%
#   Volatility     (ann.) : 7.87%
#   Sharpe ratio          : 1.0803
#   Weights:
#     index_fund    : 0.2609  (26.1%)
#     treasury_fund : 0.4594  (45.9%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.74%
#   Volatility     (ann.) : 7.98%
#   Sharpe ratio          : 1.0952
#   Weights:
#     index_fund    : 0.2044  (20.4%)
#     treasury_fund : 0.4776  (47.8%)
#     gold_fund     : 0.3181  (31.8%)
# Best log-likelihood (per sample): -1918.8208
# Sort method: 'trace'
# Transition matrix:
# [[0.97030699 0.02969301]
#  [0.12541745 0.87458255]]
# State durations (months): ['33.7', '8.0']
# State 0 = Expansion  (tr(Σ)=2.7690  PC1_mean=-0.382)
# State 1 = Recession  (tr(Σ)=7.6566  PC1_mean=1.408)
#
# ── Regime 0  (294 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.12%  →  BS +12.81%
#     treasury_fund   : sample +6.35%  →  BS +7.22%
#     gold_fund       : sample +3.45%  →  BS +4.43%
#   Bayes-Stein φ  : 0.5163  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3718
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.48%
#     treasury_fund   : 10.23%
#     gold_fund       : 11.45%
#
# ── Regime 1  (64 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -9.91%  →  BS -1.75%
#     treasury_fund   : sample +15.86%  →  BS +12.76%
#     gold_fund       : sample +14.02%  →  BS +10.57%
#   Bayes-Stein φ  : 0.3972  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2588
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.64%
#     treasury_fund   : 13.34%
#     gold_fund       : 15.94%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.29%
#   Volatility     (ann.) : 6.36%
#   Sharpe ratio          : 1.3039
#   Weights:
#     index_fund    : 0.3375  (33.8%)
#     treasury_fund : 0.3717  (37.2%)
#     gold_fund     : 0.2908  (29.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.56%
#   Volatility     (ann.) : 6.83%
#   Sharpe ratio          : 1.3998
#   Weights:
#     index_fund    : 0.4971  (49.7%)
#     treasury_fund : 0.3459  (34.6%)
#     gold_fund     : 0.1570  (15.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.68%
#   Volatility     (ann.) : 8.91%
#   Sharpe ratio          : 0.9744
#   Weights:
#     index_fund    : 0.2355  (23.6%)
#     treasury_fund : 0.4634  (46.3%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +11.62%
#   Volatility     (ann.) : 10.31%
#   Sharpe ratio          : 1.1275
#   Weights:
#     index_fund    : 0.0263  (2.6%)
#     treasury_fund : 0.6300  (63.0%)
#     gold_fund     : 0.3436  (34.4%)
#
# ── Regime 0  (295 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.17%  →  BS +12.87%
#     treasury_fund   : sample +6.19%  →  BS +7.08%
#     gold_fund       : sample +3.45%  →  BS +4.42%
#   Bayes-Stein φ  : 0.5145  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3764
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.46%
#     treasury_fund   : 10.25%
#     gold_fund       : 11.44%
#
# ── Regime 1  (64 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -9.91%  →  BS -1.77%
#     treasury_fund   : sample +15.86%  →  BS +12.72%
#     gold_fund       : sample +14.02%  →  BS +10.59%
#   Bayes-Stein φ  : 0.3949  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2588
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.64%
#     treasury_fund   : 13.34%
#     gold_fund       : 15.94%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.26%
#   Volatility     (ann.) : 6.36%
#   Sharpe ratio          : 1.2999
#   Weights:
#     index_fund    : 0.3379  (33.8%)
#     treasury_fund : 0.3706  (37.1%)
#     gold_fund     : 0.2914  (29.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.56%
#   Volatility     (ann.) : 6.84%
#   Sharpe ratio          : 1.3985
#   Weights:
#     index_fund    : 0.5017  (50.2%)
#     treasury_fund : 0.3396  (34.0%)
#     gold_fund     : 0.1586  (15.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.67%
#   Volatility     (ann.) : 8.91%
#   Sharpe ratio          : 0.9726
#   Weights:
#     index_fund    : 0.2355  (23.6%)
#     treasury_fund : 0.4634  (46.3%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +11.62%
#   Volatility     (ann.) : 10.32%
#   Sharpe ratio          : 1.1260
#   Weights:
#     index_fund    : 0.0257  (2.6%)
#     treasury_fund : 0.6292  (62.9%)
#     gold_fund     : 0.3450  (34.5%)
#
# ── Regime 0  (296 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.13%  →  BS +12.82%
#     treasury_fund   : sample +6.48%  →  BS +7.35%
#     gold_fund       : sample +3.68%  →  BS +4.63%
#   Bayes-Stein φ  : 0.5198  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3692
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.46%
#     treasury_fund   : 10.30%
#     gold_fund       : 11.47%
#
# ── Regime 1  (64 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -9.91%  →  BS -1.69%
#     treasury_fund   : sample +15.86%  →  BS +12.78%
#     gold_fund       : sample +14.02%  →  BS +10.62%
#   Bayes-Stein φ  : 0.3994  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2588
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.64%
#     treasury_fund   : 13.34%
#     gold_fund       : 15.94%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.43%
#   Volatility     (ann.) : 6.39%
#   Sharpe ratio          : 1.3197
#   Weights:
#     index_fund    : 0.3414  (34.1%)
#     treasury_fund : 0.3683  (36.8%)
#     gold_fund     : 0.2903  (29.0%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.62%
#   Volatility     (ann.) : 6.82%
#   Sharpe ratio          : 1.4103
#   Weights:
#     index_fund    : 0.4957  (49.6%)
#     treasury_fund : 0.3436  (34.4%)
#     gold_fund     : 0.1608  (16.1%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.72%
#   Volatility     (ann.) : 8.91%
#   Sharpe ratio          : 0.9789
#   Weights:
#     index_fund    : 0.2355  (23.6%)
#     treasury_fund : 0.4634  (46.3%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +11.64%
#   Volatility     (ann.) : 10.29%
#   Sharpe ratio          : 1.1307
#   Weights:
#     index_fund    : 0.0277  (2.8%)
#     treasury_fund : 0.6284  (62.8%)
#     gold_fund     : 0.3439  (34.4%)
#
# ── Regime 0  (297 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.75%  →  BS +12.41%
#     treasury_fund   : sample +6.72%  →  BS +7.59%
#     gold_fund       : sample +3.76%  →  BS +4.73%
#   Bayes-Stein φ  : 0.5351  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3485
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.59%
#     treasury_fund   : 10.33%
#     gold_fund       : 11.50%
#
# ── Regime 1  (64 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -9.91%  →  BS -1.66%
#     treasury_fund   : sample +15.86%  →  BS +12.80%
#     gold_fund       : sample +14.02%  →  BS +10.58%
#   Bayes-Stein φ  : 0.4069  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2588
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.64%
#     treasury_fund   : 13.34%
#     gold_fund       : 15.94%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.41%
#   Volatility     (ann.) : 6.39%
#   Sharpe ratio          : 1.3158
#   Weights:
#     index_fund    : 0.3408  (34.1%)
#     treasury_fund : 0.3701  (37.0%)
#     gold_fund     : 0.2891  (28.9%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.43%
#   Volatility     (ann.) : 6.77%
#   Sharpe ratio          : 1.3936
#   Weights:
#     index_fund    : 0.4783  (47.8%)
#     treasury_fund : 0.3591  (35.9%)
#     gold_fund     : 0.1626  (16.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.73%
#   Volatility     (ann.) : 8.91%
#   Sharpe ratio          : 0.9796
#   Weights:
#     index_fund    : 0.2355  (23.6%)
#     treasury_fund : 0.4634  (46.3%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +11.63%
#   Volatility     (ann.) : 10.29%
#   Sharpe ratio          : 1.1309
#   Weights:
#     index_fund    : 0.0284  (2.8%)
#     treasury_fund : 0.6294  (62.9%)
#     gold_fund     : 0.3423  (34.2%)
#
# ── Regime 0  (298 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.19%  →  BS +11.82%
#     treasury_fund   : sample +6.89%  →  BS +7.78%
#     gold_fund       : sample +3.73%  →  BS +4.74%
#   Bayes-Stein φ  : 0.5555  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3301
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.84%
#     treasury_fund   : 10.36%
#     gold_fund       : 11.53%
#
# ── Regime 1  (64 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -9.91%  →  BS -1.68%
#     treasury_fund   : sample +15.86%  →  BS +12.80%
#     gold_fund       : sample +14.02%  →  BS +10.50%
#   Bayes-Stein φ  : 0.4152  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2588
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.64%
#     treasury_fund   : 13.34%
#     gold_fund       : 15.94%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.25%
#   Volatility     (ann.) : 6.42%
#   Sharpe ratio          : 1.2844
#   Weights:
#     index_fund    : 0.3344  (33.4%)
#     treasury_fund : 0.3767  (37.7%)
#     gold_fund     : 0.2890  (28.9%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.12%
#   Volatility     (ann.) : 6.76%
#   Sharpe ratio          : 1.3507
#   Weights:
#     index_fund    : 0.4556  (45.6%)
#     treasury_fund : 0.3816  (38.2%)
#     gold_fund     : 0.1628  (16.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.70%
#   Volatility     (ann.) : 8.91%
#   Sharpe ratio          : 0.9761
#   Weights:
#     index_fund    : 0.2355  (23.6%)
#     treasury_fund : 0.4634  (46.3%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +11.61%
#   Volatility     (ann.) : 10.30%
#   Sharpe ratio          : 1.1278
#   Weights:
#     index_fund    : 0.0279  (2.8%)
#     treasury_fund : 0.6315  (63.2%)
#     gold_fund     : 0.3406  (34.1%)
#
# ── Regime 0  (299 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.67%  →  BS +12.27%
#     treasury_fund   : sample +6.98%  →  BS +7.85%
#     gold_fund       : sample +3.95%  →  BS +4.93%
#   Bayes-Stein φ  : 0.5537  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3288
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 12.02%
#     treasury_fund   : 10.38%
#     gold_fund       : 11.58%
#
# ── Regime 1  (64 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -9.91%  →  BS -1.59%
#     treasury_fund   : sample +15.86%  →  BS +12.85%
#     gold_fund       : sample +14.02%  →  BS +10.61%
#   Bayes-Stein φ  : 0.4112  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2588
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.64%
#     treasury_fund   : 13.34%
#     gold_fund       : 15.94%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.45%
#   Volatility     (ann.) : 6.52%
#   Sharpe ratio          : 1.2970
#   Weights:
#     index_fund    : 0.3279  (32.8%)
#     treasury_fund : 0.3826  (38.3%)
#     gold_fund     : 0.2895  (28.9%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.39%
#   Volatility     (ann.) : 6.87%
#   Sharpe ratio          : 1.3670
#   Weights:
#     index_fund    : 0.4560  (45.6%)
#     treasury_fund : 0.3814  (38.1%)
#     gold_fund     : 0.1626  (16.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.78%
#   Volatility     (ann.) : 8.91%
#   Sharpe ratio          : 0.9849
#   Weights:
#     index_fund    : 0.2355  (23.6%)
#     treasury_fund : 0.4634  (46.3%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +11.65%
#   Volatility     (ann.) : 10.27%
#   Sharpe ratio          : 1.1350
#   Weights:
#     index_fund    : 0.0300  (3.0%)
#     treasury_fund : 0.6288  (62.9%)
#     gold_fund     : 0.3412  (34.1%)
#
# ── Regime 0  (300 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.81%  →  BS +12.42%
#     treasury_fund   : sample +6.89%  →  BS +7.76%
#     gold_fund       : sample +4.01%  →  BS +4.99%
#   Bayes-Stein φ  : 0.5518  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3280
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 12.02%
#     treasury_fund   : 10.38%
#     gold_fund       : 11.56%
#
# ── Regime 1  (64 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -9.91%  →  BS -1.58%
#     treasury_fund   : sample +15.86%  →  BS +12.84%
#     gold_fund       : sample +14.02%  →  BS +10.65%
#   Bayes-Stein φ  : 0.4088  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2588
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.64%
#     treasury_fund   : 13.34%
#     gold_fund       : 15.94%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.48%
#   Volatility     (ann.) : 6.51%
#   Sharpe ratio          : 1.3028
#   Weights:
#     index_fund    : 0.3276  (32.8%)
#     treasury_fund : 0.3832  (38.3%)
#     gold_fund     : 0.2892  (28.9%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.44%
#   Volatility     (ann.) : 6.87%
#   Sharpe ratio          : 1.3744
#   Weights:
#     index_fund    : 0.4588  (45.9%)
#     treasury_fund : 0.3770  (37.7%)
#     gold_fund     : 0.1643  (16.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.78%
#   Volatility     (ann.) : 8.91%
#   Sharpe ratio          : 0.9856
#   Weights:
#     index_fund    : 0.2355  (23.6%)
#     treasury_fund : 0.4634  (46.3%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +11.66%
#   Volatility     (ann.) : 10.27%
#   Sharpe ratio          : 1.1354
#   Weights:
#     index_fund    : 0.0300  (3.0%)
#     treasury_fund : 0.6275  (62.7%)
#     gold_fund     : 0.3425  (34.2%)
#
# ── Regime 0  (301 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.82%  →  BS +12.43%
#     treasury_fund   : sample +6.88%  →  BS +7.75%
#     gold_fund       : sample +4.04%  →  BS +5.00%
#   Bayes-Stein φ  : 0.5514  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3282
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 12.00%
#     treasury_fund   : 10.36%
#     gold_fund       : 11.55%
#
# ── Regime 1  (64 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -9.91%  →  BS -1.58%
#     treasury_fund   : sample +15.86%  →  BS +12.84%
#     gold_fund       : sample +14.02%  →  BS +10.66%
#   Bayes-Stein φ  : 0.4085  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2588
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.64%
#     treasury_fund   : 13.34%
#     gold_fund       : 15.94%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.49%
#   Volatility     (ann.) : 6.50%
#   Sharpe ratio          : 1.3061
#   Weights:
#     index_fund    : 0.3276  (32.8%)
#     treasury_fund : 0.3832  (38.3%)
#     gold_fund     : 0.2892  (28.9%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.45%
#   Volatility     (ann.) : 6.86%
#   Sharpe ratio          : 1.3777
#   Weights:
#     index_fund    : 0.4590  (45.9%)
#     treasury_fund : 0.3762  (37.6%)
#     gold_fund     : 0.1649  (16.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.79%
#   Volatility     (ann.) : 8.91%
#   Sharpe ratio          : 0.9859
#   Weights:
#     index_fund    : 0.2355  (23.6%)
#     treasury_fund : 0.4634  (46.3%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +11.66%
#   Volatility     (ann.) : 10.26%
#   Sharpe ratio          : 1.1356
#   Weights:
#     index_fund    : 0.0301  (3.0%)
#     treasury_fund : 0.6272  (62.7%)
#     gold_fund     : 0.3427  (34.3%)
#
# ── Regime 0  (302 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.02%  →  BS +12.62%
#     treasury_fund   : sample +7.03%  →  BS +7.88%
#     gold_fund       : sample +4.28%  →  BS +5.22%
#   Bayes-Stein φ  : 0.5511  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3256
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 12.02%
#     treasury_fund   : 10.37%
#     gold_fund       : 11.58%
#
# ── Regime 1  (64 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -9.91%  →  BS -1.50%
#     treasury_fund   : sample +15.86%  →  BS +12.88%
#     gold_fund       : sample +14.02%  →  BS +10.73%
#   Bayes-Stein φ  : 0.4089  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2588
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.64%
#     treasury_fund   : 13.34%
#     gold_fund       : 15.94%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.66%
#   Volatility     (ann.) : 6.54%
#   Sharpe ratio          : 1.3241
#   Weights:
#     index_fund    : 0.3275  (32.7%)
#     treasury_fund : 0.3848  (38.5%)
#     gold_fund     : 0.2877  (28.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.61%
#   Volatility     (ann.) : 6.89%
#   Sharpe ratio          : 1.3944
#   Weights:
#     index_fund    : 0.4584  (45.8%)
#     treasury_fund : 0.3755  (37.6%)
#     gold_fund     : 0.1661  (16.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.85%
#   Volatility     (ann.) : 8.91%
#   Sharpe ratio          : 0.9928
#   Weights:
#     index_fund    : 0.2355  (23.6%)
#     treasury_fund : 0.4634  (46.3%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +11.69%
#   Volatility     (ann.) : 10.24%
#   Sharpe ratio          : 1.1411
#   Weights:
#     index_fund    : 0.0318  (3.2%)
#     treasury_fund : 0.6252  (62.5%)
#     gold_fund     : 0.3430  (34.3%)
#
# ── Regime 0  (303 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.26%  →  BS +12.85%
#     treasury_fund   : sample +6.82%  →  BS +7.68%
#     gold_fund       : sample +4.53%  →  BS +5.44%
#   Bayes-Stein φ  : 0.5486  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3369
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 12.05%
#     treasury_fund   : 10.43%
#     gold_fund       : 11.63%
#
# ── Regime 1  (64 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -9.91%  →  BS -1.49%
#     treasury_fund   : sample +15.86%  →  BS +12.83%
#     gold_fund       : sample +14.02%  →  BS +10.84%
#   Bayes-Stein φ  : 0.4054  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2588
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.64%
#     treasury_fund   : 13.34%
#     gold_fund       : 15.94%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.73%
#   Volatility     (ann.) : 6.55%
#   Sharpe ratio          : 1.3319
#   Weights:
#     index_fund    : 0.3263  (32.6%)
#     treasury_fund : 0.3868  (38.7%)
#     gold_fund     : 0.2868  (28.7%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.69%
#   Volatility     (ann.) : 6.90%
#   Sharpe ratio          : 1.4031
#   Weights:
#     index_fund    : 0.4622  (46.2%)
#     treasury_fund : 0.3651  (36.5%)
#     gold_fund     : 0.1727  (17.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.86%
#   Volatility     (ann.) : 8.91%
#   Sharpe ratio          : 0.9945
#   Weights:
#     index_fund    : 0.2355  (23.6%)
#     treasury_fund : 0.4634  (46.3%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +11.69%
#   Volatility     (ann.) : 10.23%
#   Sharpe ratio          : 1.1420
#   Weights:
#     index_fund    : 0.0321  (3.2%)
#     treasury_fund : 0.6214  (62.1%)
#     gold_fund     : 0.3465  (34.7%)
#
# ── Regime 0  (304 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.04%  →  BS +12.64%
#     treasury_fund   : sample +6.82%  →  BS +7.69%
#     gold_fund       : sample +4.43%  →  BS +5.35%
#   Bayes-Stein φ  : 0.5525  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3311
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 12.08%
#     treasury_fund   : 10.41%
#     gold_fund       : 11.63%
#
# ── Regime 1  (64 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -9.91%  →  BS -1.52%
#     treasury_fund   : sample +15.86%  →  BS +12.82%
#     gold_fund       : sample +14.02%  →  BS +10.79%
#   Bayes-Stein φ  : 0.4074  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2588
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.64%
#     treasury_fund   : 13.34%
#     gold_fund       : 15.94%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.63%
#   Volatility     (ann.) : 6.56%
#   Sharpe ratio          : 1.3159
#   Weights:
#     index_fund    : 0.3249  (32.5%)
#     treasury_fund : 0.3889  (38.9%)
#     gold_fund     : 0.2861  (28.6%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.56%
#   Volatility     (ann.) : 6.90%
#   Sharpe ratio          : 1.3853
#   Weights:
#     index_fund    : 0.4586  (45.9%)
#     treasury_fund : 0.3718  (37.2%)
#     gold_fund     : 0.1697  (17.0%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.83%
#   Volatility     (ann.) : 8.91%
#   Sharpe ratio          : 0.9913
#   Weights:
#     index_fund    : 0.2355  (23.6%)
#     treasury_fund : 0.4634  (46.3%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +11.67%
#   Volatility     (ann.) : 10.24%
#   Sharpe ratio          : 1.1393
#   Weights:
#     index_fund    : 0.0314  (3.1%)
#     treasury_fund : 0.6228  (62.3%)
#     gold_fund     : 0.3458  (34.6%)
#
# ── Regime 0  (305 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.90%  →  BS +12.52%
#     treasury_fund   : sample +6.68%  →  BS +7.56%
#     gold_fund       : sample +4.37%  →  BS +5.29%
#   Bayes-Stein φ  : 0.5533  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3345
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 12.08%
#     treasury_fund   : 10.42%
#     gold_fund       : 11.61%
#
# ── Regime 1  (64 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -9.91%  →  BS -1.56%
#     treasury_fund   : sample +15.86%  →  BS +12.77%
#     gold_fund       : sample +14.02%  →  BS +10.77%
#   Bayes-Stein φ  : 0.4071  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2588
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.64%
#     treasury_fund   : 13.34%
#     gold_fund       : 15.94%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.52%
#   Volatility     (ann.) : 6.57%
#   Sharpe ratio          : 1.2966
#   Weights:
#     index_fund    : 0.3247  (32.5%)
#     treasury_fund : 0.3879  (38.8%)
#     gold_fund     : 0.2874  (28.7%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.45%
#   Volatility     (ann.) : 6.92%
#   Sharpe ratio          : 1.3660
#   Weights:
#     index_fund    : 0.4604  (46.0%)
#     treasury_fund : 0.3686  (36.9%)
#     gold_fund     : 0.1710  (17.1%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.79%
#   Volatility     (ann.) : 8.91%
#   Sharpe ratio          : 0.9868
#   Weights:
#     index_fund    : 0.2355  (23.6%)
#     treasury_fund : 0.4634  (46.3%)
#     gold_fund     : 0.3011  (30.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +11.64%
#   Volatility     (ann.) : 10.25%
#   Sharpe ratio          : 1.1355
#   Weights:
#     index_fund    : 0.0303  (3.0%)
#     treasury_fund : 0.6230  (62.3%)
#     gold_fund     : 0.3467  (34.7%)
# Best log-likelihood (per sample): -1822.5486
# Sort method: 'trace'
# Transition matrix:
# [[0.95948417 0.04051583]
#  [0.13852057 0.86147943]]
# State durations (months): ['24.7', '7.2']
# State 0 = Expansion  (tr(Σ)=2.0988  PC1_mean=-0.323)
# State 1 = Recession  (tr(Σ)=7.5144  PC1_mean=0.939)
#
# ── Regime 0  (293 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.89%  →  BS +12.75%
#     treasury_fund   : sample +6.35%  →  BS +7.40%
#     gold_fund       : sample +4.46%  →  BS +5.27%
#   Bayes-Stein φ  : 0.5385  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3917
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.08%
#     treasury_fund   : 10.14%
#     gold_fund       : 11.39%
#
# ── Regime 1  (77 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -4.19%  →  BS +3.77%
#     treasury_fund   : sample +15.72%  →  BS +11.81%
#     gold_fund       : sample +11.68%  →  BS +8.67%
#   Bayes-Stein φ  : 0.5266  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1365
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 22.80%
#     treasury_fund   : 13.15%
#     gold_fund       : 15.45%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.63%
#   Volatility     (ann.) : 6.44%
#   Sharpe ratio          : 1.3406
#   Weights:
#     index_fund    : 0.3443  (34.4%)
#     treasury_fund : 0.3691  (36.9%)
#     gold_fund     : 0.2866  (28.7%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.74%
#   Volatility     (ann.) : 6.84%
#   Sharpe ratio          : 1.4238
#   Weights:
#     index_fund    : 0.5035  (50.3%)
#     treasury_fund : 0.3278  (32.8%)
#     gold_fund     : 0.1687  (16.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.10%
#   Volatility     (ann.) : 8.44%
#   Sharpe ratio          : 1.0789
#   Weights:
#     index_fund    : 0.2208  (22.1%)
#     treasury_fund : 0.4814  (48.1%)
#     gold_fund     : 0.2978  (29.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.74%
#   Volatility     (ann.) : 8.72%
#   Sharpe ratio          : 1.1159
#   Weights:
#     index_fund    : 0.1526  (15.3%)
#     treasury_fund : 0.5773  (57.7%)
#     gold_fund     : 0.2701  (27.0%)
#
# ...
#     index_fund      : sample -1.90%  →  BS +5.89%
#     treasury_fund   : sample +8.81%  →  BS +7.31%
#     gold_fund       : sample +9.19%  →  BS +7.67%
#   Bayes-Stein φ  : 0.5975  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1413
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.65%
#     treasury_fund   : 14.20%
#     gold_fund       : 14.62%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.50%
#   Volatility     (ann.) : 6.71%
#   Sharpe ratio          : 1.2659
#   Weights:
#     index_fund    : 0.3424  (34.2%)
#     treasury_fund : 0.3419  (34.2%)
#     gold_fund     : 0.3157  (31.6%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.95%
#   Volatility     (ann.) : 7.26%
#   Sharpe ratio          : 1.3697
#   Weights:
#     index_fund    : 0.5465  (54.7%)
#     treasury_fund : 0.2142  (21.4%)
#     gold_fund     : 0.2393  (23.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.11%
#   Volatility     (ann.) : 9.08%
#   Sharpe ratio          : 0.7829
#   Weights:
#     index_fund    : 0.2329  (23.3%)
#     treasury_fund : 0.4063  (40.6%)
#     gold_fund     : 0.3608  (36.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.16%
#   Volatility     (ann.) : 9.11%
#   Sharpe ratio          : 0.7856
#   Weights:
#     index_fund    : 0.2045  (20.4%)
#     treasury_fund : 0.4083  (40.8%)
#     gold_fund     : 0.3873  (38.7%)
#
# ── Regime 0  (318 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.40%  →  BS +13.09%
#     treasury_fund   : sample +5.40%  →  BS +5.86%
#     gold_fund       : sample +6.07%  →  BS +6.48%
#   Bayes-Stein φ  : 0.5391  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.4098
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.18%
#     treasury_fund   : 10.58%
#     gold_fund       : 11.45%
#
# ── Regime 1  (105 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -1.90%  →  BS +5.91%
#     treasury_fund   : sample +8.81%  →  BS +7.28%
#     gold_fund       : sample +9.19%  →  BS +7.78%
#   Bayes-Stein φ  : 0.6002  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1413
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.65%
#     treasury_fund   : 14.20%
#     gold_fund       : 14.62%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.53%
#   Volatility     (ann.) : 6.71%
#   Sharpe ratio          : 1.2715
#   Weights:
#     index_fund    : 0.3429  (34.3%)
#     treasury_fund : 0.3427  (34.3%)
#     gold_fund     : 0.3145  (31.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.93%
#   Volatility     (ann.) : 7.24%
#   Sharpe ratio          : 1.3718
#   Weights:
#     index_fund    : 0.5425  (54.2%)
#     treasury_fund : 0.2101  (21.0%)
#     gold_fund     : 0.2474  (24.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.14%
#   Volatility     (ann.) : 9.08%
#   Sharpe ratio          : 0.7861
#   Weights:
#     index_fund    : 0.2329  (23.3%)
#     treasury_fund : 0.4063  (40.6%)
#     gold_fund     : 0.3608  (36.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.19%
#   Volatility     (ann.) : 9.12%
#   Sharpe ratio          : 0.7892
#   Weights:
#     index_fund    : 0.2041  (20.4%)
#     treasury_fund : 0.4038  (40.4%)
#     gold_fund     : 0.3921  (39.2%)
#
# ── Regime 0  (319 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.59%  →  BS +13.27%
#     treasury_fund   : sample +5.28%  →  BS +5.75%
#     gold_fund       : sample +6.13%  →  BS +6.53%
#   Bayes-Stein φ  : 0.5348  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.4241
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.20%
#     treasury_fund   : 10.59%
#     gold_fund       : 11.44%
#
# ── Regime 1  (105 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -1.90%  →  BS +5.93%
#     treasury_fund   : sample +8.81%  →  BS +7.23%
#     gold_fund       : sample +9.19%  →  BS +7.82%
#   Bayes-Stein φ  : 0.5947  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1413
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.65%
#     treasury_fund   : 14.20%
#     gold_fund       : 14.62%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.57%
#   Volatility     (ann.) : 6.70%
#   Sharpe ratio          : 1.2785
#   Weights:
#     index_fund    : 0.3419  (34.2%)
#     treasury_fund : 0.3434  (34.3%)
#     gold_fund     : 0.3147  (31.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.05%
#   Volatility     (ann.) : 7.26%
#   Sharpe ratio          : 1.3848
#   Weights:
#     index_fund    : 0.5459  (54.6%)
#     treasury_fund : 0.2056  (20.6%)
#     gold_fund     : 0.2485  (24.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.14%
#   Volatility     (ann.) : 9.08%
#   Sharpe ratio          : 0.7863
#   Weights:
#     index_fund    : 0.2329  (23.3%)
#     treasury_fund : 0.4063  (40.6%)
#     gold_fund     : 0.3608  (36.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.20%
#   Volatility     (ann.) : 9.12%
#   Sharpe ratio          : 0.7894
#   Weights:
#     index_fund    : 0.2044  (20.4%)
#     treasury_fund : 0.4010  (40.1%)
#     gold_fund     : 0.3947  (39.5%)
#
# ── Regime 0  (320 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.72%  →  BS +13.40%
#     treasury_fund   : sample +5.36%  →  BS +5.81%
#     gold_fund       : sample +6.19%  →  BS +6.59%
#   Bayes-Stein φ  : 0.5322  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.4183
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.20%
#     treasury_fund   : 10.58%
#     gold_fund       : 11.43%
#
# ── Regime 1  (105 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -1.90%  →  BS +5.95%
#     treasury_fund   : sample +8.81%  →  BS +7.27%
#     gold_fund       : sample +9.19%  →  BS +7.85%
#   Bayes-Stein φ  : 0.5919  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1413
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.65%
#     treasury_fund   : 14.20%
#     gold_fund       : 14.62%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.65%
#   Volatility     (ann.) : 6.71%
#   Sharpe ratio          : 1.2897
#   Weights:
#     index_fund    : 0.3415  (34.2%)
#     treasury_fund : 0.3437  (34.4%)
#     gold_fund     : 0.3148  (31.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.15%
#   Volatility     (ann.) : 7.27%
#   Sharpe ratio          : 1.3973
#   Weights:
#     index_fund    : 0.5462  (54.6%)
#     treasury_fund : 0.2056  (20.6%)
#     gold_fund     : 0.2481  (24.8%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.18%
#   Volatility     (ann.) : 9.08%
#   Sharpe ratio          : 0.7902
#   Weights:
#     index_fund    : 0.2329  (23.3%)
#     treasury_fund : 0.4063  (40.6%)
#     gold_fund     : 0.3608  (36.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.23%
#   Volatility     (ann.) : 9.12%
#   Sharpe ratio          : 0.7933
#   Weights:
#     index_fund    : 0.2043  (20.4%)
#     treasury_fund : 0.4013  (40.1%)
#     gold_fund     : 0.3944  (39.4%)
#
# ── Regime 0  (321 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.77%  →  BS +13.46%
#     treasury_fund   : sample +5.31%  →  BS +5.77%
#     gold_fund       : sample +6.16%  →  BS +6.56%
#   Bayes-Stein φ  : 0.5304  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.4186
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.18%
#     treasury_fund   : 10.57%
#     gold_fund       : 11.42%
#
# ── Regime 1  (105 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -1.90%  →  BS +5.95%
#     treasury_fund   : sample +8.81%  →  BS +7.26%
#     gold_fund       : sample +9.19%  →  BS +7.84%
#   Bayes-Stein φ  : 0.5899  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1413
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.65%
#     treasury_fund   : 14.20%
#     gold_fund       : 14.62%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.64%
#   Volatility     (ann.) : 6.70%
#   Sharpe ratio          : 1.2905
#   Weights:
#     index_fund    : 0.3416  (34.2%)
#     treasury_fund : 0.3436  (34.4%)
#     gold_fund     : 0.3148  (31.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.18%
#   Volatility     (ann.) : 7.27%
#   Sharpe ratio          : 1.4009
#   Weights:
#     index_fund    : 0.5490  (54.9%)
#     treasury_fund : 0.2037  (20.4%)
#     gold_fund     : 0.2473  (24.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.16%
#   Volatility     (ann.) : 9.08%
#   Sharpe ratio          : 0.7889
#   Weights:
#     index_fund    : 0.2329  (23.3%)
#     treasury_fund : 0.4063  (40.6%)
#     gold_fund     : 0.3608  (36.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.22%
#   Volatility     (ann.) : 9.12%
#   Sharpe ratio          : 0.7920
#   Weights:
#     index_fund    : 0.2045  (20.5%)
#     treasury_fund : 0.4010  (40.1%)
#     gold_fund     : 0.3945  (39.4%)
#
# ── Regime 0  (322 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.79%  →  BS +13.49%
#     treasury_fund   : sample +5.31%  →  BS +5.76%
#     gold_fund       : sample +6.17%  →  BS +6.56%
#   Bayes-Stein φ  : 0.5293  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.4188
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.17%
#     treasury_fund   : 10.55%
#     gold_fund       : 11.40%
#
# ── Regime 1  (105 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -1.90%  →  BS +5.96%
#     treasury_fund   : sample +8.81%  →  BS +7.26%
#     gold_fund       : sample +9.19%  →  BS +7.85%
#   Bayes-Stein φ  : 0.5889  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1413
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.65%
#     treasury_fund   : 14.20%
#     gold_fund       : 14.62%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.65%
#   Volatility     (ann.) : 6.69%
#   Sharpe ratio          : 1.2942
#   Weights:
#     index_fund    : 0.3416  (34.2%)
#     treasury_fund : 0.3436  (34.4%)
#     gold_fund     : 0.3148  (31.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.21%
#   Volatility     (ann.) : 7.26%
#   Sharpe ratio          : 1.4056
#   Weights:
#     index_fund    : 0.5496  (55.0%)
#     treasury_fund : 0.2032  (20.3%)
#     gold_fund     : 0.2472  (24.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.17%
#   Volatility     (ann.) : 9.08%
#   Sharpe ratio          : 0.7892
#   Weights:
#     index_fund    : 0.2329  (23.3%)
#     treasury_fund : 0.4063  (40.6%)
#     gold_fund     : 0.3608  (36.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.22%
#   Volatility     (ann.) : 9.12%
#   Sharpe ratio          : 0.7924
#   Weights:
#     index_fund    : 0.2046  (20.5%)
#     treasury_fund : 0.4008  (40.1%)
#     gold_fund     : 0.3946  (39.5%)
#
# ── Regime 0  (323 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.87%  →  BS +13.56%
#     treasury_fund   : sample +5.40%  →  BS +5.85%
#     gold_fund       : sample +6.48%  →  BS +6.83%
#   Bayes-Stein φ  : 0.5293  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3903
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.18%
#     treasury_fund   : 10.54%
#     gold_fund       : 11.49%
#
# ── Regime 1  (105 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -1.90%  →  BS +6.00%
#     treasury_fund   : sample +8.81%  →  BS +7.30%
#     gold_fund       : sample +9.19%  →  BS +7.99%
#   Bayes-Stein φ  : 0.5888  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1413
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.65%
#     treasury_fund   : 14.20%
#     gold_fund       : 14.62%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.80%
#   Volatility     (ann.) : 6.73%
#   Sharpe ratio          : 1.3078
#   Weights:
#     index_fund    : 0.3434  (34.3%)
#     treasury_fund : 0.3459  (34.6%)
#     gold_fund     : 0.3107  (31.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.32%
#   Volatility     (ann.) : 7.29%
#   Sharpe ratio          : 1.4162
#   Weights:
#     index_fund    : 0.5481  (54.8%)
#     treasury_fund : 0.2016  (20.2%)
#     gold_fund     : 0.2503  (25.0%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.24%
#   Volatility     (ann.) : 9.08%
#   Sharpe ratio          : 0.7976
#   Weights:
#     index_fund    : 0.2329  (23.3%)
#     treasury_fund : 0.4063  (40.6%)
#     gold_fund     : 0.3608  (36.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.31%
#   Volatility     (ann.) : 9.12%
#   Sharpe ratio          : 0.8011
#   Weights:
#     index_fund    : 0.2039  (20.4%)
#     treasury_fund : 0.3983  (39.8%)
#     gold_fund     : 0.3978  (39.8%)
#
# ── Regime 0  (324 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.92%  →  BS +13.61%
#     treasury_fund   : sample +5.44%  →  BS +5.87%
#     gold_fund       : sample +6.86%  →  BS +7.16%
#   Bayes-Stein φ  : 0.5297  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3666
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.19%
#     treasury_fund   : 10.52%
#     gold_fund       : 11.61%
#
# ── Regime 1  (105 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -1.90%  →  BS +6.02%
#     treasury_fund   : sample +8.81%  →  BS +7.31%
#     gold_fund       : sample +9.19%  →  BS +8.15%
#   Bayes-Stein φ  : 0.5890  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1413
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.65%
#     treasury_fund   : 14.20%
#     gold_fund       : 14.62%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.94%
#   Volatility     (ann.) : 6.77%
#   Sharpe ratio          : 1.3200
#   Weights:
#     index_fund    : 0.3453  (34.5%)
#     treasury_fund : 0.3492  (34.9%)
#     gold_fund     : 0.3054  (30.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +10.42%
#   Volatility     (ann.) : 7.31%
#   Sharpe ratio          : 1.4257
#   Weights:
#     index_fund    : 0.5463  (54.6%)
#     treasury_fund : 0.1990  (19.9%)
#     gold_fund     : 0.2547  (25.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.31%
#   Volatility     (ann.) : 9.08%
#   Sharpe ratio          : 0.8055
#   Weights:
#     index_fund    : 0.2329  (23.3%)
#     treasury_fund : 0.4063  (40.6%)
#     gold_fund     : 0.3608  (36.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.39%
#   Volatility     (ann.) : 9.13%
#   Sharpe ratio          : 0.8095
#   Weights:
#     index_fund    : 0.2031  (20.3%)
#     treasury_fund : 0.3941  (39.4%)
#     gold_fund     : 0.4028  (40.3%)
#             gross_return  net_return_after_costs  trade_notional  \
# Date
# 2019-01-31      0.041758                0.041758        0.000000
# 2019-02-28      0.013022                0.012986        0.036484
# 2019-03-31      0.019819                0.019794        0.025699
# 2019-04-30      0.005320                0.005296        0.024031
# 2019-05-31      0.001660                0.001634        0.026195
#
#             one_way_turnover  transaction_cost  HMM_WF_State  \
# Date
# 2019-01-31          0.000000          0.000000             0
# 2019-02-28          0.018242          0.000036             0
# 2019-03-31          0.012849          0.000026             0
# 2019-04-30          0.012016          0.000024             0
# 2019-05-31          0.013097          0.000026             0
#
#             index_fund_weight  treasury_fund_weight  gold_fund_weight
# Date
# 2019-01-31           0.344239              0.354645          0.301116
# 2019-02-28           0.340427              0.354913          0.304660
# 2019-03-31           0.336828              0.358707          0.304466
# 2019-04-30           0.336591              0.358880          0.304529
# 2019-05-31           0.337096              0.356070          0.306834

# %% [markdown]
# ## Robustness check 1: HMM with PCA

# %%
hmm_pca_returns, hmm_pca_states, hmm_pca_probs, hmm_pca_filt_probs = walk_forward_backtest(
    macro_df             = macro_df,
    asset_df             = asset_df,
    model_type           = 'hmm',
    initial_train_months = INITIAL_TRAIN_MONTHS,  
    refit_every          = 12,
    dim_reduction        = 'pca',
    n_components         = 6,
    winsor_clip          = 4.0,
    transaction_cost_bps = 10,
    objective            = 'min_variance',
    rf                   = 0.0,
    long_only            = True,
    verbose              = False,
)
hmm_pca_returns.head()
# Out:
# Best log-likelihood (per sample): -984.5314
# Sort method: 'trace'
# Transition matrix:
# [[0.94849196 0.05150804]
#  [0.04829607 0.95170393]]
# State durations (months): ['19.4', '20.7']
# State 0 = Expansion  (tr(Σ)=0.8955  PC1_mean=-0.348)
# State 1 = Recession  (tr(Σ)=1.3995  PC1_mean=0.329)
#
# ── Regime 0  (177 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +8.79%
#     treasury_fund   : sample +9.61%  →  BS +8.27%
#     gold_fund       : sample +9.48%  →  BS +6.50%
#   Bayes-Stein φ  : 0.6459  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1887
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.31%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.67%
#
# ── Regime 1  (169 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.27%
#     treasury_fund   : sample +5.37%  →  BS +6.28%
#     gold_fund       : sample +0.03%  →  BS +2.07%
#   Bayes-Stein φ  : 0.4225  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3852
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 8.96%
#     gold_fund       : 10.89%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.92%
#   Volatility     (ann.) : 7.45%
#   Sharpe ratio          : 1.0625
#   Weights:
#     index_fund    : 0.2936  (29.4%)
#     treasury_fund : 0.4224  (42.2%)
#     gold_fund     : 0.2840  (28.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.03%
#   Volatility     (ann.) : 7.50%
#   Sharpe ratio          : 1.0698
#   Weights:
#     index_fund    : 0.3167  (31.7%)
#     treasury_fund : 0.4535  (45.4%)
#     gold_fund     : 0.2298  (23.0%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.10%
#   Volatility     (ann.) : 6.17%
#   Sharpe ratio          : 1.1509
#   Weights:
#     index_fund    : 0.2998  (30.0%)
#     treasury_fund : 0.3969  (39.7%)
#     gold_fund     : 0.3033  (30.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.15%
#   Volatility     (ann.) : 7.37%
#   Sharpe ratio          : 1.3760
#   Weights:
#     index_fund    : 0.6053  (60.5%)
#     treasury_fund : 0.3085  (30.8%)
#     gold_fund     : 0.0863  (8.6%)
#
# ── Regime 0  (178 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.10%  →  BS +8.25%
#     treasury_fund   : sample +9.93%  →  BS +8.52%
#     gold_fund       : sample +9.57%  →  BS +6.64%
#   Bayes-Stein φ  : 0.6318  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1746
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── Regime 1  (169 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.24%
#     treasury_fund   : sample +5.37%  →  BS +6.30%
#     gold_fund       : sample +0.03%  →  BS +1.98%
#   Bayes-Stein φ  : 0.3982  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3852
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 8.96%
#     gold_fund       : 10.89%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.91%
#   Volatility     (ann.) : 7.43%
#   Sharpe ratio          : 1.0647
#   Weights:
#     index_fund    : 0.2923  (29.2%)
#     treasury_fund : 0.4248  (42.5%)
#     gold_fund     : 0.2829  (28.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.00%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.0710
#   Weights:
#     index_fund    : 0.3030  (30.3%)
#     treasury_fund : 0.4653  (46.5%)
#     gold_fund     : 0.2318  (23.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.07%
#   Volatility     (ann.) : 6.17%
#   Sharpe ratio          : 1.1461
#   Weights:
#     index_fund    : 0.2998  (30.0%)
#     treasury_fund : 0.3969  (39.7%)
#     gold_fund     : 0.3033  (30.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.15%
#   Volatility     (ann.) : 7.39%
#   Sharpe ratio          : 1.3735
#   Weights:
#     index_fund    : 0.6064  (60.6%)
#     treasury_fund : 0.3113  (31.1%)
#     gold_fund     : 0.0823  (8.2%)
#
# ── Regime 0  (179 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.65%  →  BS +8.64%
#     treasury_fund   : sample +9.90%  →  BS +8.50%
#     gold_fund       : sample +9.75%  →  BS +6.75%
#   Bayes-Stein φ  : 0.6360  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1705
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.56%
#     treasury_fund   : 11.98%
#     gold_fund       : 13.63%
#
# ── Regime 1  (169 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.31%
#     treasury_fund   : sample +5.37%  →  BS +6.31%
#     gold_fund       : sample +0.03%  →  BS +2.06%
#   Bayes-Stein φ  : 0.4066  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3852
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 8.96%
#     gold_fund       : 10.89%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.05%
#   Volatility     (ann.) : 7.44%
#   Sharpe ratio          : 1.0812
#   Weights:
#     index_fund    : 0.2895  (28.9%)
#     treasury_fund : 0.4283  (42.8%)
#     gold_fund     : 0.2822  (28.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.14%
#   Volatility     (ann.) : 7.48%
#   Sharpe ratio          : 1.0872
#   Weights:
#     index_fund    : 0.3056  (30.6%)
#     treasury_fund : 0.4624  (46.2%)
#     gold_fund     : 0.2320  (23.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.12%
#   Volatility     (ann.) : 6.17%
#   Sharpe ratio          : 1.1545
#   Weights:
#     index_fund    : 0.2998  (30.0%)
#     treasury_fund : 0.3969  (39.7%)
#     gold_fund     : 0.3033  (30.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.18%
#   Volatility     (ann.) : 7.38%
#   Sharpe ratio          : 1.3805
#   Weights:
#     index_fund    : 0.6051  (60.5%)
#     treasury_fund : 0.3094  (30.9%)
#     gold_fund     : 0.0856  (8.6%)
#
# ── Regime 0  (180 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.83%  →  BS +8.76%
#     treasury_fund   : sample +9.76%  →  BS +8.41%
#     gold_fund       : sample +9.85%  →  BS +6.82%
#   Bayes-Stein φ  : 0.6366  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1702
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.53%
#     treasury_fund   : 11.95%
#     gold_fund       : 13.60%
#
# ── Regime 1  (169 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.32%
#     treasury_fund   : sample +5.37%  →  BS +6.30%
#     gold_fund       : sample +0.03%  →  BS +2.10%
#   Bayes-Stein φ  : 0.4100  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3852
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 8.96%
#     gold_fund       : 10.89%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.06%
#   Volatility     (ann.) : 7.42%
#   Sharpe ratio          : 1.0859
#   Weights:
#     index_fund    : 0.2894  (28.9%)
#     treasury_fund : 0.4286  (42.9%)
#     gold_fund     : 0.2820  (28.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.14%
#   Volatility     (ann.) : 7.46%
#   Sharpe ratio          : 1.0914
#   Weights:
#     index_fund    : 0.3076  (30.8%)
#     treasury_fund : 0.4575  (45.8%)
#     gold_fund     : 0.2349  (23.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.13%
#   Volatility     (ann.) : 6.17%
#   Sharpe ratio          : 1.1561
#   Weights:
#     index_fund    : 0.2998  (30.0%)
#     treasury_fund : 0.3969  (39.7%)
#     gold_fund     : 0.3033  (30.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.18%
#   Volatility     (ann.) : 7.37%
#   Sharpe ratio          : 1.3815
#   Weights:
#     index_fund    : 0.6052  (60.5%)
#     treasury_fund : 0.3073  (30.7%)
#     gold_fund     : 0.0874  (8.7%)
#
# ── Regime 0  (181 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.89%  →  BS +8.80%
#     treasury_fund   : sample +10.07%  →  BS +8.62%
#     gold_fund       : sample +9.70%  →  BS +6.72%
#   Bayes-Stein φ  : 0.6375  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1731
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 11.98%
#     gold_fund       : 13.58%
#
# ── Regime 1  (169 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.34%
#     treasury_fund   : sample +5.37%  →  BS +6.36%
#     gold_fund       : sample +0.03%  →  BS +2.07%
#   Bayes-Stein φ  : 0.4079  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3852
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 8.96%
#     gold_fund       : 10.89%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.13%
#   Volatility     (ann.) : 7.42%
#   Sharpe ratio          : 1.0961
#   Weights:
#     index_fund    : 0.2895  (29.0%)
#     treasury_fund : 0.4260  (42.6%)
#     gold_fund     : 0.2845  (28.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.24%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.1032
#   Weights:
#     index_fund    : 0.3074  (30.7%)
#     treasury_fund : 0.4619  (46.2%)
#     gold_fund     : 0.2306  (23.1%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.15%
#   Volatility     (ann.) : 6.17%
#   Sharpe ratio          : 1.1592
#   Weights:
#     index_fund    : 0.2998  (30.0%)
#     treasury_fund : 0.3969  (39.7%)
#     gold_fund     : 0.3033  (30.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.21%
#   Volatility     (ann.) : 7.37%
#   Sharpe ratio          : 1.3851
#   Weights:
#     index_fund    : 0.6039  (60.4%)
#     treasury_fund : 0.3108  (31.1%)
#     gold_fund     : 0.0853  (8.5%)
#
# ── Regime 0  (182 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +6.16%  →  BS +9.02%
#     treasury_fund   : sample +9.89%  →  BS +8.48%
#     gold_fund       : sample +9.57%  →  BS +6.60%
#   Bayes-Stein φ  : 0.6472  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1706
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.47%
#     treasury_fund   : 11.96%
#     gold_fund       : 13.55%
#
# ── Regime 1  (169 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.34%
#     treasury_fund   : sample +5.37%  →  BS +6.35%
#     gold_fund       : sample +0.03%  →  BS +2.10%
#   Bayes-Stein φ  : 0.4186  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3852
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 8.96%
#     gold_fund       : 10.89%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.10%
#   Volatility     (ann.) : 7.40%
#   Sharpe ratio          : 1.0950
#   Weights:
#     index_fund    : 0.2899  (29.0%)
#     treasury_fund : 0.4260  (42.6%)
#     gold_fund     : 0.2841  (28.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.22%
#   Volatility     (ann.) : 7.45%
#   Sharpe ratio          : 1.1030
#   Weights:
#     index_fund    : 0.3133  (31.3%)
#     treasury_fund : 0.4589  (45.9%)
#     gold_fund     : 0.2277  (22.8%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.16%
#   Volatility     (ann.) : 6.17%
#   Sharpe ratio          : 1.1601
#   Weights:
#     index_fund    : 0.2998  (30.0%)
#     treasury_fund : 0.3969  (39.7%)
#     gold_fund     : 0.3033  (30.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.20%
#   Volatility     (ann.) : 7.36%
#   Sharpe ratio          : 1.3852
#   Weights:
#     index_fund    : 0.6036  (60.4%)
#     treasury_fund : 0.3097  (31.0%)
#     gold_fund     : 0.0867  (8.7%)
#
# ── Regime 0  (183 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.71%  →  BS +8.66%
#     treasury_fund   : sample +10.27%  →  BS +8.77%
#     gold_fund       : sample +9.50%  →  BS +6.60%
#   Bayes-Stein φ  : 0.6380  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1652
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.53%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.52%
#
# ── Regime 1  (169 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.33%
#     treasury_fund   : sample +5.37%  →  BS +6.39%
#     gold_fund       : sample +0.03%  →  BS +2.00%
#   Bayes-Stein φ  : 0.4013  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3852
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 8.96%
#     gold_fund       : 10.89%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.12%
#   Volatility     (ann.) : 7.38%
#   Sharpe ratio          : 1.1007
#   Weights:
#     index_fund    : 0.2900  (29.0%)
#     treasury_fund : 0.4262  (42.6%)
#     gold_fund     : 0.2839  (28.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.25%
#   Volatility     (ann.) : 7.44%
#   Sharpe ratio          : 1.1092
#   Weights:
#     index_fund    : 0.3055  (30.6%)
#     treasury_fund : 0.4694  (46.9%)
#     gold_fund     : 0.2250  (22.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.14%
#   Volatility     (ann.) : 6.17%
#   Sharpe ratio          : 1.1574
#   Weights:
#     index_fund    : 0.2998  (30.0%)
#     treasury_fund : 0.3969  (39.7%)
#     gold_fund     : 0.3033  (30.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.22%
#   Volatility     (ann.) : 7.38%
#   Sharpe ratio          : 1.3845
#   Weights:
#     index_fund    : 0.6037  (60.4%)
#     treasury_fund : 0.3138  (31.4%)
#     gold_fund     : 0.0825  (8.2%)
#
# ── Regime 0  (184 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +6.10%  →  BS +8.91%
#     treasury_fund   : sample +10.29%  →  BS +8.79%
#     gold_fund       : sample +9.83%  →  BS +6.86%
#   Bayes-Stein φ  : 0.6343  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1648
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.55%
#     treasury_fund   : 11.98%
#     gold_fund       : 13.54%
#
# ── Regime 1  (169 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.40%
#     treasury_fund   : sample +5.37%  →  BS +6.40%
#     gold_fund       : sample +0.03%  →  BS +2.09%
#   Bayes-Stein φ  : 0.4027  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3852
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 8.96%
#     gold_fund       : 10.89%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.28%
#   Volatility     (ann.) : 7.40%
#   Sharpe ratio          : 1.1185
#   Weights:
#     index_fund    : 0.2886  (28.9%)
#     treasury_fund : 0.4298  (43.0%)
#     gold_fund     : 0.2816  (28.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.39%
#   Volatility     (ann.) : 7.45%
#   Sharpe ratio          : 1.1256
#   Weights:
#     index_fund    : 0.3058  (30.6%)
#     treasury_fund : 0.4662  (46.6%)
#     gold_fund     : 0.2280  (22.8%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.19%
#   Volatility     (ann.) : 6.17%
#   Sharpe ratio          : 1.1653
#   Weights:
#     index_fund    : 0.2998  (30.0%)
#     treasury_fund : 0.3969  (39.7%)
#     gold_fund     : 0.3033  (30.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.25%
#   Volatility     (ann.) : 7.37%
#   Sharpe ratio          : 1.3915
#   Weights:
#     index_fund    : 0.6031  (60.3%)
#     treasury_fund : 0.3113  (31.1%)
#     gold_fund     : 0.0856  (8.6%)
#
# ── Regime 0  (185 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +6.20%  →  BS +8.94%
#     treasury_fund   : sample +10.24%  →  BS +8.78%
#     gold_fund       : sample +10.04%  →  BS +7.03%
#   Bayes-Stein φ  : 0.6295  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1653
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.51%
#     treasury_fund   : 11.95%
#     gold_fund       : 13.53%
#
# ── Regime 1  (169 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.42%
#     treasury_fund   : sample +5.37%  →  BS +6.39%
#     gold_fund       : sample +0.03%  →  BS +2.12%
#   Bayes-Stein φ  : 0.4002  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3852
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 8.96%
#     gold_fund       : 10.89%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.33%
#   Volatility     (ann.) : 7.39%
#   Sharpe ratio          : 1.1280
#   Weights:
#     index_fund    : 0.2886  (28.9%)
#     treasury_fund : 0.4304  (43.0%)
#     gold_fund     : 0.2810  (28.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.42%
#   Volatility     (ann.) : 7.43%
#   Sharpe ratio          : 1.1340
#   Weights:
#     index_fund    : 0.3050  (30.5%)
#     treasury_fund : 0.4626  (46.3%)
#     gold_fund     : 0.2324  (23.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.20%
#   Volatility     (ann.) : 6.17%
#   Sharpe ratio          : 1.1676
#   Weights:
#     index_fund    : 0.2998  (30.0%)
#     treasury_fund : 0.3969  (39.7%)
#     gold_fund     : 0.3033  (30.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.26%
#   Volatility     (ann.) : 7.36%
#   Sharpe ratio          : 1.3935
#   Weights:
#     index_fund    : 0.6033  (60.3%)
#     treasury_fund : 0.3095  (31.0%)
#     gold_fund     : 0.0871  (8.7%)
#
# ── Regime 0  (186 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +6.06%  →  BS +8.77%
#     treasury_fund   : sample +10.88%  →  BS +9.27%
#     gold_fund       : sample +10.38%  →  BS +7.35%
#   Bayes-Stein φ  : 0.6143  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1690
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.17%
#     gold_fund       : 13.57%
#
# ── Regime 1  (169 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.49%
#     treasury_fund   : sample +5.37%  →  BS +6.46%
#     gold_fund       : sample +0.03%  →  BS +2.08%
#   Bayes-Stein φ  : 0.3789  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3852
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 8.96%
#     gold_fund       : 10.89%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.58%
#   Volatility     (ann.) : 7.48%
#   Sharpe ratio          : 1.1476
#   Weights:
#     index_fund    : 0.2949  (29.5%)
#     treasury_fund : 0.4223  (42.2%)
#     gold_fund     : 0.2828  (28.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.67%
#   Volatility     (ann.) : 7.51%
#   Sharpe ratio          : 1.1535
#   Weights:
#     index_fund    : 0.3026  (30.3%)
#     treasury_fund : 0.4623  (46.2%)
#     gold_fund     : 0.2351  (23.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.24%
#   Volatility     (ann.) : 6.17%
#   Sharpe ratio          : 1.1738
#   Weights:
#     index_fund    : 0.2998  (30.0%)
#     treasury_fund : 0.3969  (39.7%)
#     gold_fund     : 0.3033  (30.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.33%
#   Volatility     (ann.) : 7.37%
#   Sharpe ratio          : 1.4020
#   Weights:
#     index_fund    : 0.6029  (60.3%)
#     treasury_fund : 0.3124  (31.2%)
#     gold_fund     : 0.0847  (8.5%)
#
# ── Regime 0  (187 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +6.12%  →  BS +8.82%
#     treasury_fund   : sample +10.65%  →  BS +9.11%
#     gold_fund       : sample +10.37%  →  BS +7.34%
#   Bayes-Stein φ  : 0.6166  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1697
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.44%
#     treasury_fund   : 12.16%
#     gold_fund       : 13.53%
#
# ── Regime 1  (169 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.48%
#     treasury_fund   : sample +5.37%  →  BS +6.43%
#     gold_fund       : sample +0.03%  →  BS +2.11%
#   Bayes-Stein φ  : 0.3828  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3852
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 8.96%
#     gold_fund       : 10.89%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.52%
#   Volatility     (ann.) : 7.46%
#   Sharpe ratio          : 1.1418
#   Weights:
#     index_fund    : 0.2953  (29.5%)
#     treasury_fund : 0.4212  (42.1%)
#     gold_fund     : 0.2834  (28.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.60%
#   Volatility     (ann.) : 7.50%
#   Sharpe ratio          : 1.1470
#   Weights:
#     index_fund    : 0.3050  (30.5%)
#     treasury_fund : 0.4569  (45.7%)
#     gold_fund     : 0.2381  (23.8%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.23%
#   Volatility     (ann.) : 6.17%
#   Sharpe ratio          : 1.1725
#   Weights:
#     index_fund    : 0.2998  (30.0%)
#     treasury_fund : 0.3969  (39.7%)
#     gold_fund     : 0.3033  (30.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.31%
#   Volatility     (ann.) : 7.36%
#   Sharpe ratio          : 1.4000
#   Weights:
#     index_fund    : 0.6033  (60.3%)
#     treasury_fund : 0.3107  (31.1%)
#     gold_fund     : 0.0861  (8.6%)
#
# ── Regime 0  (188 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +6.25%  →  BS +8.93%
#     treasury_fund   : sample +10.53%  →  BS +9.00%
#     gold_fund       : sample +10.25%  →  BS +7.24%
#   Bayes-Stein φ  : 0.6228  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1690
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.40%
#     treasury_fund   : 12.14%
#     gold_fund       : 13.50%
#
# ── Regime 1  (169 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.47%
#     treasury_fund   : sample +5.37%  →  BS +6.42%
#     gold_fund       : sample +0.03%  →  BS +2.12%
#   Bayes-Stein φ  : 0.3889  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3852
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.52%
#     treasury_fund   : 8.96%
#     gold_fund       : 10.89%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.48%
#   Volatility     (ann.) : 7.44%
#   Sharpe ratio          : 1.1392
#   Weights:
#     index_fund    : 0.2957  (29.6%)
#     treasury_fund : 0.4211  (42.1%)
#     gold_fund     : 0.2832  (28.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.56%
#   Volatility     (ann.) : 7.48%
#   Sharpe ratio          : 1.1447
#   Weights:
#     index_fund    : 0.3088  (30.9%)
#     treasury_fund : 0.4556  (45.6%)
#     gold_fund     : 0.2357  (23.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.23%
#   Volatility     (ann.) : 6.17%
#   Sharpe ratio          : 1.1724
#   Weights:
#     index_fund    : 0.2998  (30.0%)
#     treasury_fund : 0.3969  (39.7%)
#     gold_fund     : 0.3033  (30.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.30%
#   Volatility     (ann.) : 7.36%
#   Sharpe ratio          : 1.3993
#   Weights:
#     index_fund    : 0.6030  (60.3%)
#     treasury_fund : 0.3103  (31.0%)
#     gold_fund     : 0.0867  (8.7%)
# Best log-likelihood (per sample): -1020.6517
# Sort method: 'trace'
# Transition matrix:
# [[0.9530991  0.0469009 ]
#  [0.04963417 0.95036583]]
# State durations (months): ['21.3', '20.1']
# State 0 = Expansion  (tr(Σ)=0.8764  PC1_mean=-0.323)
# State 1 = Recession  (tr(Σ)=1.4360  PC1_mean=0.343)
#
# ── Regime 0  (185 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.19%  →  BS +12.90%
#     treasury_fund   : sample +6.61%  →  BS +7.33%
#     gold_fund       : sample +1.52%  →  BS +3.44%
#   Bayes-Stein φ  : 0.5036  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5813
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.79%
#     treasury_fund   : 9.82%
#     gold_fund       : 10.88%
#
# ── Regime 1  (173 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +9.10%
#     treasury_fund   : sample +9.59%  →  BS +8.54%
#     gold_fund       : sample +9.42%  →  BS +6.64%
#   Bayes-Stein φ  : 0.6820  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1828
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.91%
#   Volatility     (ann.) : 6.22%
#   Sharpe ratio          : 1.2708
#   Weights:
#     index_fund    : 0.3209  (32.1%)
#     treasury_fund : 0.3681  (36.8%)
#     gold_fund     : 0.3110  (31.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.78%
#   Volatility     (ann.) : 6.92%
#   Sharpe ratio          : 1.4134
#   Weights:
#     index_fund    : 0.5306  (53.1%)
#     treasury_fund : 0.3401  (34.0%)
#     gold_fund     : 0.1292  (12.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.16%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.0915
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4235  (42.4%)
#     gold_fund     : 0.2854  (28.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.28%
#   Volatility     (ann.) : 7.53%
#   Sharpe ratio          : 1.0996
#   Weights:
#     index_fund    : 0.3148  (31.5%)
#     treasury_fund : 0.4567  (45.7%)
#     gold_fund     : 0.2285  (22.8%)
#
# ── Regime 0  (186 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.27%  →  BS +12.99%
#     treasury_fund   : sample +6.36%  →  BS +7.13%
#     gold_fund       : sample +1.54%  →  BS +3.43%
#   Bayes-Stein φ  : 0.4975  (mild shrinkage)
#   Ledoit-Wolf α  : 0.6020
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.76%
#     treasury_fund   : 9.86%
#     gold_fund       : 10.85%
#
# ── Regime 1  (173 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +9.12%
#     treasury_fund   : sample +9.59%  →  BS +8.45%
#     gold_fund       : sample +9.42%  →  BS +6.65%
#   Bayes-Stein φ  : 0.6783  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1828
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.86%
#   Volatility     (ann.) : 6.21%
#   Sharpe ratio          : 1.2668
#   Weights:
#     index_fund    : 0.3221  (32.2%)
#     treasury_fund : 0.3653  (36.5%)
#     gold_fund     : 0.3125  (31.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.81%
#   Volatility     (ann.) : 6.93%
#   Sharpe ratio          : 1.4150
#   Weights:
#     index_fund    : 0.5394  (53.9%)
#     treasury_fund : 0.3297  (33.0%)
#     gold_fund     : 0.1309  (13.1%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.13%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.0881
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4235  (42.4%)
#     gold_fund     : 0.2854  (28.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.25%
#   Volatility     (ann.) : 7.53%
#   Sharpe ratio          : 1.0958
#   Weights:
#     index_fund    : 0.3158  (31.6%)
#     treasury_fund : 0.4540  (45.4%)
#     gold_fund     : 0.2302  (23.0%)
#
# ── Regime 0  (187 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.21%  →  BS +12.88%
#     treasury_fund   : sample +6.81%  →  BS +7.50%
#     gold_fund       : sample +1.90%  →  BS +3.76%
#   Bayes-Stein φ  : 0.5154  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.6069
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.78%
#     treasury_fund   : 9.96%
#     gold_fund       : 10.90%
#
# ── Regime 1  (173 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +9.16%
#     treasury_fund   : sample +9.59%  →  BS +8.59%
#     gold_fund       : sample +9.42%  →  BS +6.72%
#   Bayes-Stein φ  : 0.6902  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1828
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.09%
#   Volatility     (ann.) : 6.25%
#   Sharpe ratio          : 1.2946
#   Weights:
#     index_fund    : 0.3268  (32.7%)
#     treasury_fund : 0.3613  (36.1%)
#     gold_fund     : 0.3119  (31.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.81%
#   Volatility     (ann.) : 6.88%
#   Sharpe ratio          : 1.4252
#   Weights:
#     index_fund    : 0.5254  (52.5%)
#     treasury_fund : 0.3360  (33.6%)
#     gold_fund     : 0.1387  (13.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.23%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.1006
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4235  (42.4%)
#     gold_fund     : 0.2854  (28.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.34%
#   Volatility     (ann.) : 7.53%
#   Sharpe ratio          : 1.1085
#   Weights:
#     index_fund    : 0.3146  (31.5%)
#     treasury_fund : 0.4557  (45.6%)
#     gold_fund     : 0.2297  (23.0%)
#
# ── Regime 0  (188 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.61%  →  BS +12.29%
#     treasury_fund   : sample +7.20%  →  BS +7.83%
#     gold_fund       : sample +2.04%  →  BS +3.98%
#   Bayes-Stein φ  : 0.5480  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.6406
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.91%
#     treasury_fund   : 10.11%
#     gold_fund       : 10.93%
#
# ── Regime 1  (173 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +9.04%
#     treasury_fund   : sample +9.59%  →  BS +8.71%
#     gold_fund       : sample +9.42%  →  BS +6.70%
#   Bayes-Stein φ  : 0.7081  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1828
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.08%
#   Volatility     (ann.) : 6.27%
#   Sharpe ratio          : 1.2883
#   Weights:
#     index_fund    : 0.3272  (32.7%)
#     treasury_fund : 0.3586  (35.9%)
#     gold_fund     : 0.3143  (31.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.47%
#   Volatility     (ann.) : 6.79%
#   Sharpe ratio          : 1.3953
#   Weights:
#     index_fund    : 0.4979  (49.8%)
#     treasury_fund : 0.3528  (35.3%)
#     gold_fund     : 0.1493  (14.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.23%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.1012
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4235  (42.4%)
#     gold_fund     : 0.2854  (28.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.35%
#   Volatility     (ann.) : 7.53%
#   Sharpe ratio          : 1.1093
#   Weights:
#     index_fund    : 0.3118  (31.2%)
#     treasury_fund : 0.4605  (46.0%)
#     gold_fund     : 0.2278  (22.8%)
#
# ── Regime 0  (189 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +13.72%  →  BS +11.49%
#     treasury_fund   : sample +7.46%  →  BS +8.06%
#     gold_fund       : sample +2.01%  →  BS +4.09%
#   Bayes-Stein φ  : 0.5881  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.6235
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.23%
#     treasury_fund   : 10.22%
#     gold_fund       : 11.04%
#
# ── Regime 1  (173 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +8.79%
#     treasury_fund   : sample +9.59%  →  BS +8.78%
#     gold_fund       : sample +9.42%  →  BS +6.61%
#   Bayes-Stein φ  : 0.7263  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1828
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.91%
#   Volatility     (ann.) : 6.35%
#   Sharpe ratio          : 1.2453
#   Weights:
#     index_fund    : 0.3204  (32.0%)
#     treasury_fund : 0.3645  (36.5%)
#     gold_fund     : 0.3151  (31.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.03%
#   Volatility     (ann.) : 6.79%
#   Sharpe ratio          : 1.3308
#   Weights:
#     index_fund    : 0.4637  (46.4%)
#     treasury_fund : 0.3804  (38.0%)
#     gold_fund     : 0.1559  (15.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.17%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.0925
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4235  (42.4%)
#     gold_fund     : 0.2854  (28.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.30%
#   Volatility     (ann.) : 7.53%
#   Sharpe ratio          : 1.1013
#   Weights:
#     index_fund    : 0.3081  (30.8%)
#     treasury_fund : 0.4667  (46.7%)
#     gold_fund     : 0.2252  (22.5%)
#
# ── Regime 0  (190 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.48%  →  BS +12.07%
#     treasury_fund   : sample +7.60%  →  BS +8.15%
#     gold_fund       : sample +2.36%  →  BS +4.32%
#   Bayes-Stein φ  : 0.5822  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5468
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.55%
#     treasury_fund   : 10.17%
#     gold_fund       : 11.18%
#
# ── Regime 1  (173 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +9.06%
#     treasury_fund   : sample +9.59%  →  BS +8.84%
#     gold_fund       : sample +9.42%  →  BS +6.77%
#   Bayes-Stein φ  : 0.7183  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1828
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.17%
#   Volatility     (ann.) : 6.49%
#   Sharpe ratio          : 1.2582
#   Weights:
#     index_fund    : 0.3098  (31.0%)
#     treasury_fund : 0.3784  (37.8%)
#     gold_fund     : 0.3118  (31.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.38%
#   Volatility     (ann.) : 6.96%
#   Sharpe ratio          : 1.3480
#   Weights:
#     index_fund    : 0.4613  (46.1%)
#     treasury_fund : 0.3870  (38.7%)
#     gold_fund     : 0.1517  (15.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.31%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.1119
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4235  (42.4%)
#     gold_fund     : 0.2854  (28.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.43%
#   Volatility     (ann.) : 7.53%
#   Sharpe ratio          : 1.1202
#   Weights:
#     index_fund    : 0.3103  (31.0%)
#     treasury_fund : 0.4623  (46.2%)
#     gold_fund     : 0.2274  (22.7%)
#
# ── Regime 0  (191 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.71%  →  BS +12.26%
#     treasury_fund   : sample +7.45%  →  BS +8.04%
#     gold_fund       : sample +2.47%  →  BS +4.37%
#   Bayes-Stein φ  : 0.5763  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5473
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.54%
#     treasury_fund   : 10.17%
#     gold_fund       : 11.17%
#
# ── Regime 1  (173 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +9.13%
#     treasury_fund   : sample +9.59%  →  BS +8.79%
#     gold_fund       : sample +9.42%  →  BS +6.81%
#   Bayes-Stein φ  : 0.7150  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1828
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.20%
#   Volatility     (ann.) : 6.48%
#   Sharpe ratio          : 1.2653
#   Weights:
#     index_fund    : 0.3094  (30.9%)
#     treasury_fund : 0.3790  (37.9%)
#     gold_fund     : 0.3117  (31.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.45%
#   Volatility     (ann.) : 6.96%
#   Sharpe ratio          : 1.3578
#   Weights:
#     index_fund    : 0.4664  (46.6%)
#     treasury_fund : 0.3802  (38.0%)
#     gold_fund     : 0.1534  (15.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.32%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.1137
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4235  (42.4%)
#     gold_fund     : 0.2854  (28.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.44%
#   Volatility     (ann.) : 7.53%
#   Sharpe ratio          : 1.1215
#   Weights:
#     index_fund    : 0.3115  (31.2%)
#     treasury_fund : 0.4592  (45.9%)
#     gold_fund     : 0.2293  (22.9%)
#
# ── Regime 0  (192 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.72%  →  BS +12.28%
#     treasury_fund   : sample +7.44%  →  BS +8.02%
#     gold_fund       : sample +2.52%  →  BS +4.40%
#   Bayes-Stein φ  : 0.5756  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5475
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.51%
#     treasury_fund   : 10.14%
#     gold_fund       : 11.14%
#
# ── Regime 1  (173 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +9.14%
#     treasury_fund   : sample +9.59%  →  BS +8.78%
#     gold_fund       : sample +9.42%  →  BS +6.82%
#   Bayes-Stein φ  : 0.7148  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1828
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.21%
#   Volatility     (ann.) : 6.47%
#   Sharpe ratio          : 1.2701
#   Weights:
#     index_fund    : 0.3094  (30.9%)
#     treasury_fund : 0.3790  (37.9%)
#     gold_fund     : 0.3117  (31.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.45%
#   Volatility     (ann.) : 6.94%
#   Sharpe ratio          : 1.3626
#   Weights:
#     index_fund    : 0.4667  (46.7%)
#     treasury_fund : 0.3790  (37.9%)
#     gold_fund     : 0.1543  (15.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.33%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.1143
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4235  (42.4%)
#     gold_fund     : 0.2854  (28.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.44%
#   Volatility     (ann.) : 7.53%
#   Sharpe ratio          : 1.1220
#   Weights:
#     index_fund    : 0.3117  (31.2%)
#     treasury_fund : 0.4587  (45.9%)
#     gold_fund     : 0.2296  (23.0%)
#
# ── Regime 0  (193 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.03%  →  BS +12.50%
#     treasury_fund   : sample +7.66%  →  BS +8.19%
#     gold_fund       : sample +2.90%  →  BS +4.68%
#   Bayes-Stein φ  : 0.5788  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5153
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.59%
#     treasury_fund   : 10.11%
#     gold_fund       : 11.21%
#
# ── Regime 1  (173 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +9.28%
#     treasury_fund   : sample +9.59%  →  BS +8.86%
#     gold_fund       : sample +9.42%  →  BS +6.96%
#   Bayes-Stein φ  : 0.7164  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1828
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.43%
#   Volatility     (ann.) : 6.53%
#   Sharpe ratio          : 1.2914
#   Weights:
#     index_fund    : 0.3076  (30.8%)
#     treasury_fund : 0.3842  (38.4%)
#     gold_fund     : 0.3082  (30.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.64%
#   Volatility     (ann.) : 6.98%
#   Sharpe ratio          : 1.3805
#   Weights:
#     index_fund    : 0.4627  (46.3%)
#     treasury_fund : 0.3819  (38.2%)
#     gold_fund     : 0.1554  (15.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.44%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.1290
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4235  (42.4%)
#     gold_fund     : 0.2854  (28.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.55%
#   Volatility     (ann.) : 7.52%
#   Sharpe ratio          : 1.1364
#   Weights:
#     index_fund    : 0.3118  (31.2%)
#     treasury_fund : 0.4568  (45.7%)
#     gold_fund     : 0.2314  (23.1%)
#
# ── Regime 0  (194 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.41%  →  BS +12.81%
#     treasury_fund   : sample +7.33%  →  BS +7.94%
#     gold_fund       : sample +3.31%  →  BS +4.96%
#   Bayes-Stein φ  : 0.5733  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5411
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.63%
#     treasury_fund   : 10.23%
#     gold_fund       : 11.28%
#
# ── Regime 1  (173 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +9.42%
#     treasury_fund   : sample +9.59%  →  BS +8.73%
#     gold_fund       : sample +9.42%  →  BS +7.11%
#   Bayes-Stein φ  : 0.7150  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1828
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.52%
#   Volatility     (ann.) : 6.55%
#   Sharpe ratio          : 1.3015
#   Weights:
#     index_fund    : 0.3076  (30.8%)
#     treasury_fund : 0.3844  (38.4%)
#     gold_fund     : 0.3080  (30.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.74%
#   Volatility     (ann.) : 7.00%
#   Sharpe ratio          : 1.3915
#   Weights:
#     index_fund    : 0.4703  (47.0%)
#     treasury_fund : 0.3649  (36.5%)
#     gold_fund     : 0.1649  (16.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.47%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.1333
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4235  (42.4%)
#     gold_fund     : 0.2854  (28.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.57%
#   Volatility     (ann.) : 7.52%
#   Sharpe ratio          : 1.1396
#   Weights:
#     index_fund    : 0.3139  (31.4%)
#     treasury_fund : 0.4492  (44.9%)
#     gold_fund     : 0.2370  (23.7%)
#
# ── Regime 0  (195 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.06%  →  BS +12.52%
#     treasury_fund   : sample +7.34%  →  BS +7.95%
#     gold_fund       : sample +3.14%  →  BS +4.86%
#   Bayes-Stein φ  : 0.5823  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5176
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.68%
#     treasury_fund   : 10.18%
#     gold_fund       : 11.29%
#
# ── Regime 1  (173 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +9.32%
#     treasury_fund   : sample +9.59%  →  BS +8.73%
#     gold_fund       : sample +9.42%  →  BS +7.03%
#   Bayes-Stein φ  : 0.7194  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1828
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.40%
#   Volatility     (ann.) : 6.56%
#   Sharpe ratio          : 1.2805
#   Weights:
#     index_fund    : 0.3046  (30.5%)
#     treasury_fund : 0.3891  (38.9%)
#     gold_fund     : 0.3063  (30.6%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.57%
#   Volatility     (ann.) : 7.00%
#   Sharpe ratio          : 1.3670
#   Weights:
#     index_fund    : 0.4630  (46.3%)
#     treasury_fund : 0.3762  (37.6%)
#     gold_fund     : 0.1609  (16.1%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.42%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.1261
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4235  (42.4%)
#     gold_fund     : 0.2854  (28.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.51%
#   Volatility     (ann.) : 7.52%
#   Sharpe ratio          : 1.1326
#   Weights:
#     index_fund    : 0.3131  (31.3%)
#     treasury_fund : 0.4517  (45.2%)
#     gold_fund     : 0.2353  (23.5%)
#
# ── Regime 0  (196 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.84%  →  BS +12.36%
#     treasury_fund   : sample +7.10%  →  BS +7.79%
#     gold_fund       : sample +3.06%  →  BS +4.80%
#   Bayes-Stein φ  : 0.5847  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5162
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.68%
#     treasury_fund   : 10.19%
#     gold_fund       : 11.28%
#
# ── Regime 1  (173 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.78%  →  BS +9.25%
#     treasury_fund   : sample +9.59%  →  BS +8.64%
#     gold_fund       : sample +9.42%  →  BS +6.98%
#   Bayes-Stein φ  : 0.7212  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1828
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 16.48%
#     treasury_fund   : 12.01%
#     gold_fund       : 13.65%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.26%
#   Volatility     (ann.) : 6.57%
#   Sharpe ratio          : 1.2572
#   Weights:
#     index_fund    : 0.3043  (30.4%)
#     treasury_fund : 0.3883  (38.8%)
#     gold_fund     : 0.3074  (30.7%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.43%
#   Volatility     (ann.) : 7.02%
#   Sharpe ratio          : 1.3433
#   Weights:
#     index_fund    : 0.4650  (46.5%)
#     treasury_fund : 0.3730  (37.3%)
#     gold_fund     : 0.1619  (16.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.35%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.1165
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4235  (42.4%)
#     gold_fund     : 0.2854  (28.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.44%
#   Volatility     (ann.) : 7.52%
#   Sharpe ratio          : 1.1229
#   Weights:
#     index_fund    : 0.3133  (31.3%)
#     treasury_fund : 0.4507  (45.1%)
#     gold_fund     : 0.2360  (23.6%)
# Best log-likelihood (per sample): -947.5789
# Sort method: 'trace'
# Transition matrix:
# [[0.96867364 0.03132636]
#  [0.26979945 0.73020055]]
# State durations (months): ['31.9', '3.7']
# State 0 = Expansion  (tr(Σ)=0.6648  PC1_mean=-0.097)
# State 1 = Recession  (tr(Σ)=9.4498  PC1_mean=0.087)
#
# ── Regime 0  (335 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.12%  →  BS +11.05%
#     treasury_fund   : sample +7.09%  →  BS +8.16%
#     gold_fund       : sample +5.17%  →  BS +5.87%
#   Bayes-Stein φ  : 0.8886  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1696
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.22%
#     treasury_fund   : 9.98%
#     gold_fund       : 12.10%
#
# ── Regime 1  (35 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -0.50%  →  BS +6.97%
#     treasury_fund   : sample +19.87%  →  BS +12.30%
#     gold_fund       : sample +13.53%  →  BS +8.58%
#   Bayes-Stein φ  : 0.6543  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5436
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.17%
#     treasury_fund   : 17.22%
#     gold_fund       : 17.23%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.44%
#   Volatility     (ann.) : 6.60%
#   Sharpe ratio          : 1.2789
#   Weights:
#     index_fund    : 0.3025  (30.2%)
#     treasury_fund : 0.4377  (43.8%)
#     gold_fund     : 0.2598  (26.0%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.86%
#   Volatility     (ann.) : 6.76%
#   Sharpe ratio          : 1.3099
#   Weights:
#     index_fund    : 0.3765  (37.6%)
#     treasury_fund : 0.4516  (45.2%)
#     gold_fund     : 0.1719  (17.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.56%
#   Volatility     (ann.) : 10.42%
#   Sharpe ratio          : 0.9178
#   Weights:
#     index_fund    : 0.2561  (25.6%)
#     treasury_fund : 0.3754  (37.5%)
#     gold_fund     : 0.3685  (36.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +10.05%
#   Volatility     (ann.) : 10.68%
#   Sharpe ratio          : 0.9406
#   Weights:
#     index_fund    : 0.1928  (19.3%)
#     treasury_fund : 0.4777  (47.8%)
#     gold_fund     : 0.3295  (32.9%)
#
# ── Regime 0  (336 observations) ──
# ...
#     index_fund      : sample +5.04%  →  BS +9.45%
#     treasury_fund   : sample +16.81%  →  BS +9.22%
#     gold_fund       : sample +12.02%  →  BS +8.14%
#   Bayes-Stein φ  : 0.7222  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5917
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 19.88%
#     treasury_fund   : 16.98%
#     gold_fund       : 16.72%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.80%
#   Volatility     (ann.) : 7.21%
#   Sharpe ratio          : 1.0823
#   Weights:
#     index_fund    : 0.2953  (29.5%)
#     treasury_fund : 0.3825  (38.3%)
#     gold_fund     : 0.3222  (32.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.40%
#   Volatility     (ann.) : 7.48%
#   Sharpe ratio          : 1.1229
#   Weights:
#     index_fund    : 0.4175  (41.8%)
#     treasury_fund : 0.2985  (29.9%)
#     gold_fund     : 0.2840  (28.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.89%
#   Volatility     (ann.) : 10.17%
#   Sharpe ratio          : 0.8744
#   Weights:
#     index_fund    : 0.2794  (27.9%)
#     treasury_fund : 0.3573  (35.7%)
#     gold_fund     : 0.3633  (36.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.93%
#   Volatility     (ann.) : 10.19%
#   Sharpe ratio          : 0.8763
#   Weights:
#     index_fund    : 0.2957  (29.6%)
#     treasury_fund : 0.3724  (37.2%)
#     gold_fund     : 0.3319  (33.2%)
#
# ── Regime 0  (381 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +11.78%  →  BS +11.16%
#     treasury_fund   : sample +5.09%  →  BS +6.15%
#     gold_fund       : sample +6.27%  →  BS +6.79%
#   Bayes-Stein φ  : 0.9144  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2149
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.53%
#     treasury_fund   : 10.92%
#     gold_fund       : 12.09%
#
# ── Regime 1  (42 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.04%  →  BS +9.43%
#     treasury_fund   : sample +16.81%  →  BS +9.17%
#     gold_fund       : sample +12.02%  →  BS +8.27%
#   Bayes-Stein φ  : 0.7238  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5917
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 19.88%
#     treasury_fund   : 16.98%
#     gold_fund       : 16.72%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.84%
#   Volatility     (ann.) : 7.20%
#   Sharpe ratio          : 1.0881
#   Weights:
#     index_fund    : 0.2958  (29.6%)
#     treasury_fund : 0.3833  (38.3%)
#     gold_fund     : 0.3210  (32.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.42%
#   Volatility     (ann.) : 7.47%
#   Sharpe ratio          : 1.1276
#   Weights:
#     index_fund    : 0.4152  (41.5%)
#     treasury_fund : 0.2936  (29.4%)
#     gold_fund     : 0.2912  (29.1%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.92%
#   Volatility     (ann.) : 10.17%
#   Sharpe ratio          : 0.8770
#   Weights:
#     index_fund    : 0.2794  (27.9%)
#     treasury_fund : 0.3573  (35.7%)
#     gold_fund     : 0.3633  (36.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.94%
#   Volatility     (ann.) : 10.18%
#   Sharpe ratio          : 0.8783
#   Weights:
#     index_fund    : 0.2944  (29.4%)
#     treasury_fund : 0.3690  (36.9%)
#     gold_fund     : 0.3365  (33.7%)
#
# ── Regime 0  (382 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +11.94%  →  BS +11.32%
#     treasury_fund   : sample +4.98%  →  BS +6.05%
#     gold_fund       : sample +6.32%  →  BS +6.84%
#   Bayes-Stein φ  : 0.9132  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2143
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.54%
#     treasury_fund   : 10.92%
#     gold_fund       : 12.08%
#
# ── Regime 1  (42 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.04%  →  BS +9.52%
#     treasury_fund   : sample +16.81%  →  BS +9.13%
#     gold_fund       : sample +12.02%  →  BS +8.32%
#   Bayes-Stein φ  : 0.7203  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5917
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 19.88%
#     treasury_fund   : 16.98%
#     gold_fund       : 16.72%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.86%
#   Volatility     (ann.) : 7.20%
#   Sharpe ratio          : 1.0917
#   Weights:
#     index_fund    : 0.2953  (29.5%)
#     treasury_fund : 0.3840  (38.4%)
#     gold_fund     : 0.3207  (32.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.49%
#   Volatility     (ann.) : 7.48%
#   Sharpe ratio          : 1.1345
#   Weights:
#     index_fund    : 0.4187  (41.9%)
#     treasury_fund : 0.2883  (28.8%)
#     gold_fund     : 0.2930  (29.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.95%
#   Volatility     (ann.) : 10.17%
#   Sharpe ratio          : 0.8801
#   Weights:
#     index_fund    : 0.2794  (27.9%)
#     treasury_fund : 0.3573  (35.7%)
#     gold_fund     : 0.3633  (36.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.97%
#   Volatility     (ann.) : 10.18%
#   Sharpe ratio          : 0.8814
#   Weights:
#     index_fund    : 0.2960  (29.6%)
#     treasury_fund : 0.3665  (36.6%)
#     gold_fund     : 0.3376  (33.8%)
#
# ── Regime 0  (383 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.06%  →  BS +11.43%
#     treasury_fund   : sample +5.05%  →  BS +6.11%
#     gold_fund       : sample +6.38%  →  BS +6.89%
#   Bayes-Stein φ  : 0.9135  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2130
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.54%
#     treasury_fund   : 10.91%
#     gold_fund       : 12.07%
#
# ── Regime 1  (42 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.04%  →  BS +9.60%
#     treasury_fund   : sample +16.81%  →  BS +9.16%
#     gold_fund       : sample +12.02%  →  BS +8.35%
#   Bayes-Stein φ  : 0.7213  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5917
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 19.88%
#     treasury_fund   : 16.98%
#     gold_fund       : 16.72%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.93%
#   Volatility     (ann.) : 7.20%
#   Sharpe ratio          : 1.1008
#   Weights:
#     index_fund    : 0.2948  (29.5%)
#     treasury_fund : 0.3842  (38.4%)
#     gold_fund     : 0.3210  (32.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.56%
#   Volatility     (ann.) : 7.49%
#   Sharpe ratio          : 1.1442
#   Weights:
#     index_fund    : 0.4188  (41.9%)
#     treasury_fund : 0.2886  (28.9%)
#     gold_fund     : 0.2926  (29.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.99%
#   Volatility     (ann.) : 10.17%
#   Sharpe ratio          : 0.8846
#   Weights:
#     index_fund    : 0.2794  (27.9%)
#     treasury_fund : 0.3573  (35.7%)
#     gold_fund     : 0.3633  (36.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.02%
#   Volatility     (ann.) : 10.18%
#   Sharpe ratio          : 0.8860
#   Weights:
#     index_fund    : 0.2970  (29.7%)
#     treasury_fund : 0.3659  (36.6%)
#     gold_fund     : 0.3371  (33.7%)
#
# ── Regime 0  (384 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.11%  →  BS +11.47%
#     treasury_fund   : sample +5.01%  →  BS +6.07%
#     gold_fund       : sample +6.35%  →  BS +6.86%
#   Bayes-Stein φ  : 0.9129  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2128
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.52%
#     treasury_fund   : 10.90%
#     gold_fund       : 12.06%
#
# ── Regime 1  (42 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.04%  →  BS +9.62%
#     treasury_fund   : sample +16.81%  →  BS +9.16%
#     gold_fund       : sample +12.02%  →  BS +8.34%
#   Bayes-Stein φ  : 0.7194  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5917
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 19.88%
#     treasury_fund   : 16.98%
#     gold_fund       : 16.72%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.92%
#   Volatility     (ann.) : 7.19%
#   Sharpe ratio          : 1.1006
#   Weights:
#     index_fund    : 0.2949  (29.5%)
#     treasury_fund : 0.3842  (38.4%)
#     gold_fund     : 0.3209  (32.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.57%
#   Volatility     (ann.) : 7.49%
#   Sharpe ratio          : 1.1455
#   Weights:
#     index_fund    : 0.4210  (42.1%)
#     treasury_fund : 0.2869  (28.7%)
#     gold_fund     : 0.2921  (29.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.99%
#   Volatility     (ann.) : 10.17%
#   Sharpe ratio          : 0.8844
#   Weights:
#     index_fund    : 0.2794  (27.9%)
#     treasury_fund : 0.3573  (35.7%)
#     gold_fund     : 0.3633  (36.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.02%
#   Volatility     (ann.) : 10.18%
#   Sharpe ratio          : 0.8859
#   Weights:
#     index_fund    : 0.2976  (29.8%)
#     treasury_fund : 0.3657  (36.6%)
#     gold_fund     : 0.3367  (33.7%)
#
# ── Regime 0  (385 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.14%  →  BS +11.50%
#     treasury_fund   : sample +5.01%  →  BS +6.07%
#     gold_fund       : sample +6.35%  →  BS +6.86%
#   Bayes-Stein φ  : 0.9127  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2128
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.51%
#     treasury_fund   : 10.89%
#     gold_fund       : 12.04%
#
# ── Regime 1  (42 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.04%  →  BS +9.64%
#     treasury_fund   : sample +16.81%  →  BS +9.16%
#     gold_fund       : sample +12.02%  →  BS +8.35%
#   Bayes-Stein φ  : 0.7191  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5917
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 19.88%
#     treasury_fund   : 16.98%
#     gold_fund       : 16.72%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.92%
#   Volatility     (ann.) : 7.18%
#   Sharpe ratio          : 1.1032
#   Weights:
#     index_fund    : 0.2949  (29.5%)
#     treasury_fund : 0.3842  (38.4%)
#     gold_fund     : 0.3209  (32.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.59%
#   Volatility     (ann.) : 7.48%
#   Sharpe ratio          : 1.1486
#   Weights:
#     index_fund    : 0.4216  (42.2%)
#     treasury_fund : 0.2864  (28.6%)
#     gold_fund     : 0.2921  (29.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.00%
#   Volatility     (ann.) : 10.17%
#   Sharpe ratio          : 0.8852
#   Weights:
#     index_fund    : 0.2794  (27.9%)
#     treasury_fund : 0.3573  (35.7%)
#     gold_fund     : 0.3633  (36.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.03%
#   Volatility     (ann.) : 10.18%
#   Sharpe ratio          : 0.8867
#   Weights:
#     index_fund    : 0.2979  (29.8%)
#     treasury_fund : 0.3654  (36.5%)
#     gold_fund     : 0.3367  (33.7%)
#
# ── Regime 0  (386 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.21%  →  BS +11.57%
#     treasury_fund   : sample +5.09%  →  BS +6.14%
#     gold_fund       : sample +6.62%  →  BS +7.10%
#   Bayes-Stein φ  : 0.9141  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2126
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.50%
#     treasury_fund   : 10.89%
#     gold_fund       : 12.11%
#
# ── Regime 1  (42 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.04%  →  BS +9.72%
#     treasury_fund   : sample +16.81%  →  BS +9.17%
#     gold_fund       : sample +12.02%  →  BS +8.50%
#   Bayes-Stein φ  : 0.7229  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5917
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 19.88%
#     treasury_fund   : 16.98%
#     gold_fund       : 16.72%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.05%
#   Volatility     (ann.) : 7.21%
#   Sharpe ratio          : 1.1166
#   Weights:
#     index_fund    : 0.2960  (29.6%)
#     treasury_fund : 0.3863  (38.6%)
#     gold_fund     : 0.3177  (31.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.70%
#   Volatility     (ann.) : 7.50%
#   Sharpe ratio          : 1.1609
#   Weights:
#     index_fund    : 0.4200  (42.0%)
#     treasury_fund : 0.2854  (28.5%)
#     gold_fund     : 0.2946  (29.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.08%
#   Volatility     (ann.) : 10.17%
#   Sharpe ratio          : 0.8929
#   Weights:
#     index_fund    : 0.2794  (27.9%)
#     treasury_fund : 0.3573  (35.7%)
#     gold_fund     : 0.3633  (36.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.10%
#   Volatility     (ann.) : 10.18%
#   Sharpe ratio          : 0.8942
#   Weights:
#     index_fund    : 0.2976  (29.8%)
#     treasury_fund : 0.3625  (36.3%)
#     gold_fund     : 0.3399  (34.0%)
#
# ── Regime 0  (387 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.26%  →  BS +11.61%
#     treasury_fund   : sample +5.12%  →  BS +6.16%
#     gold_fund       : sample +6.93%  →  BS +7.38%
#   Bayes-Stein φ  : 0.9150  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2141
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.49%
#     treasury_fund   : 10.89%
#     gold_fund       : 12.20%
#
# ── Regime 1  (42 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +5.04%  →  BS +9.77%
#     treasury_fund   : sample +16.81%  →  BS +9.15%
#     gold_fund       : sample +12.02%  →  BS +8.68%
#   Bayes-Stein φ  : 0.7262  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5917
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 19.88%
#     treasury_fund   : 16.98%
#     gold_fund       : 16.72%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.17%
#   Volatility     (ann.) : 7.23%
#   Sharpe ratio          : 1.1290
#   Weights:
#     index_fund    : 0.2972  (29.7%)
#     treasury_fund : 0.3893  (38.9%)
#     gold_fund     : 0.3135  (31.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.81%
#   Volatility     (ann.) : 7.51%
#   Sharpe ratio          : 1.1725
#   Weights:
#     index_fund    : 0.4184  (41.8%)
#     treasury_fund : 0.2830  (28.3%)
#     gold_fund     : 0.2986  (29.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.15%
#   Volatility     (ann.) : 10.17%
#   Sharpe ratio          : 0.9005
#   Weights:
#     index_fund    : 0.2794  (27.9%)
#     treasury_fund : 0.3573  (35.7%)
#     gold_fund     : 0.3633  (36.3%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.17%
#   Volatility     (ann.) : 10.18%
#   Sharpe ratio          : 0.9015
#   Weights:
#     index_fund    : 0.2967  (29.7%)
#     treasury_fund : 0.3586  (35.9%)
#     gold_fund     : 0.3447  (34.5%)
#             gross_return  net_return_after_costs  trade_notional  \
# Date
# 2019-01-31      0.037169                0.037169        0.000000
# 2019-02-28      0.010107                0.010076        0.031077
# 2019-03-31      0.023275                0.023249        0.026304
# 2019-04-30      0.002087                0.002061        0.025618
# 2019-05-31      0.009385                0.009360        0.024968
#
#             one_way_turnover  transaction_cost  HMM_WF_State  \
# Date
# 2019-01-31          0.000000          0.000000             0
# 2019-02-28          0.015539          0.000031             0
# 2019-03-31          0.013152          0.000026             0
# 2019-04-30          0.012809          0.000026             0
# 2019-05-31          0.012484          0.000025             0
#
#             index_fund_weight  treasury_fund_weight  gold_fund_weight
# Date
# 2019-01-31           0.293577              0.422394          0.284029
# 2019-02-28           0.292253              0.424834          0.282913
# 2019-03-31           0.289481              0.428340          0.282179
# 2019-04-30           0.289369              0.428591          0.282041
# 2019-05-31           0.289550              0.425979          0.284471

# %% [markdown]
# ## Robustness check 2: MSVAR(1) with PCA
#
# The MSVAR is included as robustness check only. The VAR structure on components are not supported theoretically. PCs are statistical artifacts; most do not have an economic intepretation.

# %%
msvar_pca_returns, msvar_pca_states, msvar_pca_probs, msvar_pca_filt_probs = walk_forward_backtest(
    macro_df             = macro_df,
    asset_df             = asset_df,
    model_type           = 'msvar',
    initial_train_months = INITIAL_TRAIN_MONTHS,
    refit_every          = 12,
    dim_reduction        = 'pca',
    n_components         = 6,
    variance_threshold   = 0.85,
    winsor_clip          = 4.0,
    transaction_cost_bps = 10,
    objective            = 'min_variance',
    rf                   = 0.0,
    long_only            = True,
    verbose              = False,
)
msvar_pca_returns.head()
# Out:
# Sort method: 'trace'
# State 0 = Expansion  (tr(Σ)=0.5071  PC1_mean=-0.023)
# State 1 = Recession  (tr(Σ)=2.5578  PC1_mean=0.553)
# Transition matrix:
# [[0.9599 0.0401]
#  [0.2549 0.7451]]
# State durations (months): ['24.9', '3.9']
#
# ── Regime 0  (301 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.18%  →  BS +10.43%
#     treasury_fund   : sample +6.50%  →  BS +7.48%
#     gold_fund       : sample +4.65%  →  BS +4.85%
#   Bayes-Stein φ  : 0.9478  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2302
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.45%
#     treasury_fund   : 10.24%
#     gold_fund       : 12.32%
#
# ── Regime 1  (45 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.24%  →  BS +10.77%
#     treasury_fund   : sample +14.44%  →  BS +8.80%
#     gold_fund       : sample +6.24%  →  BS +5.11%
#   Bayes-Stein φ  : 0.8170  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5044
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.44%
#     treasury_fund   : 13.18%
#     gold_fund       : 14.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.61%
#   Volatility     (ann.) : 6.80%
#   Sharpe ratio          : 1.1188
#   Weights:
#     index_fund    : 0.2875  (28.7%)
#     treasury_fund : 0.4372  (43.7%)
#     gold_fund     : 0.2753  (27.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.17%
#   Volatility     (ann.) : 7.04%
#   Sharpe ratio          : 1.1595
#   Weights:
#     index_fund    : 0.3810  (38.1%)
#     treasury_fund : 0.4530  (45.3%)
#     gold_fund     : 0.1660  (16.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.16%
#   Volatility     (ann.) : 7.70%
#   Sharpe ratio          : 1.0603
#   Weights:
#     index_fund    : 0.3318  (33.2%)
#     treasury_fund : 0.3172  (31.7%)
#     gold_fund     : 0.3509  (35.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.65%
#   Volatility     (ann.) : 7.92%
#   Sharpe ratio          : 1.0917
#   Weights:
#     index_fund    : 0.3918  (39.2%)
#     treasury_fund : 0.3579  (35.8%)
#     gold_fund     : 0.2503  (25.0%)
#
# ── Regime 0  (302 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +9.77%  →  BS +10.07%
#     treasury_fund   : sample +6.70%  →  BS +7.65%
#     gold_fund       : sample +4.73%  →  BS +4.91%
#   Bayes-Stein φ  : 0.9490  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2168
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.59%
#     treasury_fund   : 10.25%
#     gold_fund       : 12.32%
#
# ── Regime 1  (45 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.24%  →  BS +10.47%
#     treasury_fund   : sample +14.44%  →  BS +8.92%
#     gold_fund       : sample +6.24%  →  BS +5.16%
#   Bayes-Stein φ  : 0.8201  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5044
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.44%
#     treasury_fund   : 13.18%
#     gold_fund       : 14.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.59%
#   Volatility     (ann.) : 6.79%
#   Sharpe ratio          : 1.1184
#   Weights:
#     index_fund    : 0.2864  (28.6%)
#     treasury_fund : 0.4395  (43.9%)
#     gold_fund     : 0.2742  (27.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.08%
#   Volatility     (ann.) : 7.01%
#   Sharpe ratio          : 1.1538
#   Weights:
#     index_fund    : 0.3670  (36.7%)
#     treasury_fund : 0.4660  (46.6%)
#     gold_fund     : 0.1670  (16.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.11%
#   Volatility     (ann.) : 7.70%
#   Sharpe ratio          : 1.0544
#   Weights:
#     index_fund    : 0.3318  (33.2%)
#     treasury_fund : 0.3172  (31.7%)
#     gold_fund     : 0.3509  (35.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.57%
#   Volatility     (ann.) : 7.91%
#   Sharpe ratio          : 1.0838
#   Weights:
#     index_fund    : 0.3848  (38.5%)
#     treasury_fund : 0.3645  (36.5%)
#     gold_fund     : 0.2507  (25.1%)
#
# ── Regime 0  (303 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.07%  →  BS +10.34%
#     treasury_fund   : sample +6.70%  →  BS +7.65%
#     gold_fund       : sample +4.85%  →  BS +5.02%
#   Bayes-Stein φ  : 0.9498  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2106
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.66%
#     treasury_fund   : 10.23%
#     gold_fund       : 12.32%
#
# ── Regime 1  (45 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.24%  →  BS +10.68%
#     treasury_fund   : sample +14.44%  →  BS +8.89%
#     gold_fund       : sample +6.24%  →  BS +5.24%
#   Bayes-Stein φ  : 0.8234  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5044
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.44%
#     treasury_fund   : 13.18%
#     gold_fund       : 14.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.69%
#   Volatility     (ann.) : 6.80%
#   Sharpe ratio          : 1.1312
#   Weights:
#     index_fund    : 0.2839  (28.4%)
#     treasury_fund : 0.4429  (44.3%)
#     gold_fund     : 0.2733  (27.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.20%
#   Volatility     (ann.) : 7.02%
#   Sharpe ratio          : 1.1677
#   Weights:
#     index_fund    : 0.3684  (36.8%)
#     treasury_fund : 0.4639  (46.4%)
#     gold_fund     : 0.1677  (16.8%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.21%
#   Volatility     (ann.) : 7.70%
#   Sharpe ratio          : 1.0662
#   Weights:
#     index_fund    : 0.3318  (33.2%)
#     treasury_fund : 0.3172  (31.7%)
#     gold_fund     : 0.3509  (35.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.66%
#   Volatility     (ann.) : 7.91%
#   Sharpe ratio          : 1.0956
#   Weights:
#     index_fund    : 0.3879  (38.8%)
#     treasury_fund : 0.3591  (35.9%)
#     gold_fund     : 0.2529  (25.3%)
#
# ── Regime 0  (304 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.16%  →  BS +10.42%
#     treasury_fund   : sample +6.63%  →  BS +7.58%
#     gold_fund       : sample +4.92%  →  BS +5.08%
#   Bayes-Stein φ  : 0.9492  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2105
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.64%
#     treasury_fund   : 10.22%
#     gold_fund       : 12.31%
#
# ── Regime 1  (45 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.24%  →  BS +10.75%
#     treasury_fund   : sample +14.44%  →  BS +8.85%
#     gold_fund       : sample +6.24%  →  BS +5.30%
#   Bayes-Stein φ  : 0.8219  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5044
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.44%
#     treasury_fund   : 13.18%
#     gold_fund       : 14.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.70%
#   Volatility     (ann.) : 6.79%
#   Sharpe ratio          : 1.1344
#   Weights:
#     index_fund    : 0.2838  (28.4%)
#     treasury_fund : 0.4431  (44.3%)
#     gold_fund     : 0.2731  (27.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.21%
#   Volatility     (ann.) : 7.01%
#   Sharpe ratio          : 1.1708
#   Weights:
#     index_fund    : 0.3703  (37.0%)
#     treasury_fund : 0.4596  (46.0%)
#     gold_fund     : 0.1701  (17.0%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.23%
#   Volatility     (ann.) : 7.70%
#   Sharpe ratio          : 1.0697
#   Weights:
#     index_fund    : 0.3318  (33.2%)
#     treasury_fund : 0.3172  (31.7%)
#     gold_fund     : 0.3509  (35.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.68%
#   Volatility     (ann.) : 7.90%
#   Sharpe ratio          : 1.0986
#   Weights:
#     index_fund    : 0.3892  (38.9%)
#     treasury_fund : 0.3559  (35.6%)
#     gold_fund     : 0.2548  (25.5%)
#
# ── Regime 0  (305 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.19%  →  BS +10.44%
#     treasury_fund   : sample +6.82%  →  BS +7.75%
#     gold_fund       : sample +4.85%  →  BS +5.02%
#   Bayes-Stein φ  : 0.9519  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2149
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.61%
#     treasury_fund   : 10.25%
#     gold_fund       : 12.30%
#
# ── Regime 1  (45 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.24%  →  BS +10.76%
#     treasury_fund   : sample +14.44%  →  BS +8.94%
#     gold_fund       : sample +6.24%  →  BS +5.24%
#   Bayes-Stein φ  : 0.8283  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5044
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.44%
#     treasury_fund   : 13.18%
#     gold_fund       : 14.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.76%
#   Volatility     (ann.) : 6.79%
#   Sharpe ratio          : 1.1429
#   Weights:
#     index_fund    : 0.2843  (28.4%)
#     treasury_fund : 0.4405  (44.0%)
#     gold_fund     : 0.2752  (27.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.29%
#   Volatility     (ann.) : 7.02%
#   Sharpe ratio          : 1.1808
#   Weights:
#     index_fund    : 0.3696  (37.0%)
#     treasury_fund : 0.4630  (46.3%)
#     gold_fund     : 0.1674  (16.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.24%
#   Volatility     (ann.) : 7.70%
#   Sharpe ratio          : 1.0710
#   Weights:
#     index_fund    : 0.3318  (33.2%)
#     treasury_fund : 0.3172  (31.7%)
#     gold_fund     : 0.3509  (35.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.71%
#   Volatility     (ann.) : 7.91%
#   Sharpe ratio          : 1.1011
#   Weights:
#     index_fund    : 0.3885  (38.8%)
#     treasury_fund : 0.3597  (36.0%)
#     gold_fund     : 0.2518  (25.2%)
#
# ── Regime 0  (306 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.33%  →  BS +10.57%
#     treasury_fund   : sample +6.72%  →  BS +7.66%
#     gold_fund       : sample +4.79%  →  BS +4.97%
#   Bayes-Stein φ  : 0.9511  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2130
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.61%
#     treasury_fund   : 10.24%
#     gold_fund       : 12.28%
#
# ── Regime 1  (45 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.24%  →  BS +10.87%
#     treasury_fund   : sample +14.44%  →  BS +8.88%
#     gold_fund       : sample +6.24%  →  BS +5.20%
#   Bayes-Stein φ  : 0.8258  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5044
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.44%
#     treasury_fund   : 13.18%
#     gold_fund       : 14.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.75%
#   Volatility     (ann.) : 6.78%
#   Sharpe ratio          : 1.1423
#   Weights:
#     index_fund    : 0.2845  (28.5%)
#     treasury_fund : 0.4405  (44.1%)
#     gold_fund     : 0.2749  (27.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.30%
#   Volatility     (ann.) : 7.02%
#   Sharpe ratio          : 1.1824
#   Weights:
#     index_fund    : 0.3740  (37.4%)
#     treasury_fund : 0.4600  (46.0%)
#     gold_fund     : 0.1660  (16.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.25%
#   Volatility     (ann.) : 7.70%
#   Sharpe ratio          : 1.0716
#   Weights:
#     index_fund    : 0.3318  (33.2%)
#     treasury_fund : 0.3172  (31.7%)
#     gold_fund     : 0.3509  (35.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.73%
#   Volatility     (ann.) : 7.92%
#   Sharpe ratio          : 1.1027
#   Weights:
#     index_fund    : 0.3914  (39.1%)
#     treasury_fund : 0.3574  (35.7%)
#     gold_fund     : 0.2512  (25.1%)
#
# ── Regime 0  (307 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.05%  →  BS +10.32%
#     treasury_fund   : sample +6.96%  →  BS +7.87%
#     gold_fund       : sample +4.77%  →  BS +4.95%
#   Bayes-Stein φ  : 0.9533  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2091
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.67%
#     treasury_fund   : 10.28%
#     gold_fund       : 12.27%
#
# ── Regime 1  (45 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.24%  →  BS +10.65%
#     treasury_fund   : sample +14.44%  →  BS +9.02%
#     gold_fund       : sample +6.24%  →  BS +5.17%
#   Bayes-Stein φ  : 0.8313  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5044
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.44%
#     treasury_fund   : 13.18%
#     gold_fund       : 14.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.76%
#   Volatility     (ann.) : 6.78%
#   Sharpe ratio          : 1.1459
#   Weights:
#     index_fund    : 0.2849  (28.5%)
#     treasury_fund : 0.4402  (44.0%)
#     gold_fund     : 0.2748  (27.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.29%
#   Volatility     (ann.) : 7.00%
#   Sharpe ratio          : 1.1839
#   Weights:
#     index_fund    : 0.3659  (36.6%)
#     treasury_fund : 0.4705  (47.1%)
#     gold_fund     : 0.1635  (16.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.21%
#   Volatility     (ann.) : 7.70%
#   Sharpe ratio          : 1.0667
#   Weights:
#     index_fund    : 0.3318  (33.2%)
#     treasury_fund : 0.3172  (31.7%)
#     gold_fund     : 0.3509  (35.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.69%
#   Volatility     (ann.) : 7.92%
#   Sharpe ratio          : 1.0975
#   Weights:
#     index_fund    : 0.3862  (38.6%)
#     treasury_fund : 0.3646  (36.5%)
#     gold_fund     : 0.2492  (24.9%)
#
# ── Regime 0  (308 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.27%  →  BS +10.51%
#     treasury_fund   : sample +6.98%  →  BS +7.89%
#     gold_fund       : sample +4.98%  →  BS +5.13%
#   Bayes-Stein φ  : 0.9541  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2062
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.69%
#     treasury_fund   : 10.27%
#     gold_fund       : 12.30%
#
# ── Regime 1  (45 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.24%  →  BS +10.81%
#     treasury_fund   : sample +14.44%  →  BS +9.01%
#     gold_fund       : sample +6.24%  →  BS +5.32%
#   Bayes-Stein φ  : 0.8346  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5044
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.44%
#     treasury_fund   : 13.18%
#     gold_fund       : 14.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.88%
#   Volatility     (ann.) : 6.79%
#   Sharpe ratio          : 1.1599
#   Weights:
#     index_fund    : 0.2837  (28.4%)
#     treasury_fund : 0.4434  (44.3%)
#     gold_fund     : 0.2729  (27.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.39%
#   Volatility     (ann.) : 7.01%
#   Sharpe ratio          : 1.1970
#   Weights:
#     index_fund    : 0.3663  (36.6%)
#     treasury_fund : 0.4678  (46.8%)
#     gold_fund     : 0.1659  (16.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.31%
#   Volatility     (ann.) : 7.70%
#   Sharpe ratio          : 1.0797
#   Weights:
#     index_fund    : 0.3318  (33.2%)
#     treasury_fund : 0.3172  (31.7%)
#     gold_fund     : 0.3509  (35.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.77%
#   Volatility     (ann.) : 7.91%
#   Sharpe ratio          : 1.1092
#   Weights:
#     index_fund    : 0.3876  (38.8%)
#     treasury_fund : 0.3592  (35.9%)
#     gold_fund     : 0.2532  (25.3%)
#
# ── Regime 0  (309 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.31%  →  BS +10.55%
#     treasury_fund   : sample +6.97%  →  BS +7.87%
#     gold_fund       : sample +5.12%  →  BS +5.25%
#   Bayes-Stein φ  : 0.9541  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2061
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.67%
#     treasury_fund   : 10.25%
#     gold_fund       : 12.29%
#
# ── Regime 1  (45 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.24%  →  BS +10.84%
#     treasury_fund   : sample +14.44%  →  BS +8.99%
#     gold_fund       : sample +6.24%  →  BS +5.42%
#   Bayes-Stein φ  : 0.8349  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5044
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.44%
#     treasury_fund   : 13.18%
#     gold_fund       : 14.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.92%
#   Volatility     (ann.) : 6.79%
#   Sharpe ratio          : 1.1668
#   Weights:
#     index_fund    : 0.2837  (28.4%)
#     treasury_fund : 0.4439  (44.4%)
#     gold_fund     : 0.2723  (27.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.41%
#   Volatility     (ann.) : 6.99%
#   Sharpe ratio          : 1.2023
#   Weights:
#     index_fund    : 0.3658  (36.6%)
#     treasury_fund : 0.4648  (46.5%)
#     gold_fund     : 0.1694  (16.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.35%
#   Volatility     (ann.) : 7.70%
#   Sharpe ratio          : 1.0850
#   Weights:
#     index_fund    : 0.3318  (33.2%)
#     treasury_fund : 0.3172  (31.7%)
#     gold_fund     : 0.3509  (35.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.79%
#   Volatility     (ann.) : 7.90%
#   Sharpe ratio          : 1.1133
#   Weights:
#     index_fund    : 0.3874  (38.7%)
#     treasury_fund : 0.3565  (35.7%)
#     gold_fund     : 0.2561  (25.6%)
#
# ── Regime 0  (310 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.22%  →  BS +10.46%
#     treasury_fund   : sample +7.36%  →  BS +8.22%
#     gold_fund       : sample +5.33%  →  BS +5.44%
#   Bayes-Stein φ  : 0.9594  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2148
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.66%
#     treasury_fund   : 10.43%
#     gold_fund       : 12.33%
#
# ── Regime 1  (45 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.24%  →  BS +10.74%
#     treasury_fund   : sample +14.44%  →  BS +9.19%
#     gold_fund       : sample +6.24%  →  BS +5.57%
#   Bayes-Stein φ  : 0.8479  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5044
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.44%
#     treasury_fund   : 13.18%
#     gold_fund       : 14.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.11%
#   Volatility     (ann.) : 6.85%
#   Sharpe ratio          : 1.1839
#   Weights:
#     index_fund    : 0.2905  (29.1%)
#     treasury_fund : 0.4357  (43.6%)
#     gold_fund     : 0.2738  (27.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.56%
#   Volatility     (ann.) : 7.04%
#   Sharpe ratio          : 1.2164
#   Weights:
#     index_fund    : 0.3642  (36.4%)
#     treasury_fund : 0.4648  (46.5%)
#     gold_fund     : 0.1710  (17.1%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.44%
#   Volatility     (ann.) : 7.70%
#   Sharpe ratio          : 1.0961
#   Weights:
#     index_fund    : 0.3318  (33.2%)
#     treasury_fund : 0.3172  (31.7%)
#     gold_fund     : 0.3509  (35.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.85%
#   Volatility     (ann.) : 7.88%
#   Sharpe ratio          : 1.1228
#   Weights:
#     index_fund    : 0.3818  (38.2%)
#     treasury_fund : 0.3606  (36.1%)
#     gold_fund     : 0.2576  (25.8%)
#
# ── Regime 0  (311 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.24%  →  BS +10.48%
#     treasury_fund   : sample +7.23%  →  BS +8.11%
#     gold_fund       : sample +5.35%  →  BS +5.46%
#   Bayes-Stein φ  : 0.9583  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2163
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.63%
#     treasury_fund   : 10.43%
#     gold_fund       : 12.31%
#
# ── Regime 1  (45 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.24%  →  BS +10.76%
#     treasury_fund   : sample +14.44%  →  BS +9.13%
#     gold_fund       : sample +6.24%  →  BS +5.58%
#   Bayes-Stein φ  : 0.8438  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5044
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.44%
#     treasury_fund   : 13.18%
#     gold_fund       : 14.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.07%
#   Volatility     (ann.) : 6.84%
#   Sharpe ratio          : 1.1790
#   Weights:
#     index_fund    : 0.2909  (29.1%)
#     treasury_fund : 0.4347  (43.5%)
#     gold_fund     : 0.2744  (27.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.52%
#   Volatility     (ann.) : 7.03%
#   Sharpe ratio          : 1.2113
#   Weights:
#     index_fund    : 0.3666  (36.7%)
#     treasury_fund : 0.4599  (46.0%)
#     gold_fund     : 0.1734  (17.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.43%
#   Volatility     (ann.) : 7.70%
#   Sharpe ratio          : 1.0949
#   Weights:
#     index_fund    : 0.3318  (33.2%)
#     treasury_fund : 0.3172  (31.7%)
#     gold_fund     : 0.3509  (35.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.84%
#   Volatility     (ann.) : 7.88%
#   Sharpe ratio          : 1.1212
#   Weights:
#     index_fund    : 0.3830  (38.3%)
#     treasury_fund : 0.3581  (35.8%)
#     gold_fund     : 0.2588  (25.9%)
#
# ── Regime 0  (312 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.31%  →  BS +10.54%
#     treasury_fund   : sample +7.17%  →  BS +8.04%
#     gold_fund       : sample +5.29%  →  BS +5.40%
#   Bayes-Stein φ  : 0.9578  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2159
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.62%
#     treasury_fund   : 10.42%
#     gold_fund       : 12.29%
#
# ── Regime 1  (45 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.24%  →  BS +10.82%
#     treasury_fund   : sample +14.44%  →  BS +9.09%
#     gold_fund       : sample +6.24%  →  BS +5.54%
#   Bayes-Stein φ  : 0.8419  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5044
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.44%
#     treasury_fund   : 13.18%
#     gold_fund       : 14.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.05%
#   Volatility     (ann.) : 6.83%
#   Sharpe ratio          : 1.1773
#   Weights:
#     index_fund    : 0.2911  (29.1%)
#     treasury_fund : 0.4346  (43.5%)
#     gold_fund     : 0.2743  (27.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.51%
#   Volatility     (ann.) : 7.03%
#   Sharpe ratio          : 1.2109
#   Weights:
#     index_fund    : 0.3694  (36.9%)
#     treasury_fund : 0.4584  (45.8%)
#     gold_fund     : 0.1721  (17.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.42%
#   Volatility     (ann.) : 7.70%
#   Sharpe ratio          : 1.0936
#   Weights:
#     index_fund    : 0.3318  (33.2%)
#     treasury_fund : 0.3172  (31.7%)
#     gold_fund     : 0.3509  (35.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.84%
#   Volatility     (ann.) : 7.89%
#   Sharpe ratio          : 1.1206
#   Weights:
#     index_fund    : 0.3848  (38.5%)
#     treasury_fund : 0.3572  (35.7%)
#     gold_fund     : 0.2581  (25.8%)
# Sort method: 'trace'
# State 0 = Expansion  (tr(Σ)=0.5136  PC1_mean=-0.029)
# State 1 = Recession  (tr(Σ)=2.5874  PC1_mean=0.667)
# Transition matrix:
# [[0.96   0.04  ]
#  [0.2673 0.7327]]
# State durations (months): ['25.0', '3.7']
#
# ── Regime 0  (315 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.12%  →  BS +10.62%
#     treasury_fund   : sample +7.23%  →  BS +8.01%
#     gold_fund       : sample +5.37%  →  BS +5.34%
#   Bayes-Stein φ  : 0.9574  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2149
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.55%
#     treasury_fund   : 10.33%
#     gold_fund       : 12.27%
#
# ── Regime 1  (43 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.45%  →  BS +11.25%
#     treasury_fund   : sample +14.02%  →  BS +9.01%
#     gold_fund       : sample +5.09%  →  BS +5.30%
#   Bayes-Stein φ  : 0.8398  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5224
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.78%
#     treasury_fund   : 13.67%
#     gold_fund       : 14.29%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.04%
#   Volatility     (ann.) : 6.83%
#   Sharpe ratio          : 1.1770
#   Weights:
#     index_fund    : 0.2899  (29.0%)
#     treasury_fund : 0.4357  (43.6%)
#     gold_fund     : 0.2745  (27.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.53%
#   Volatility     (ann.) : 7.03%
#   Sharpe ratio          : 1.2123
#   Weights:
#     index_fund    : 0.3713  (37.1%)
#     treasury_fund : 0.4584  (45.8%)
#     gold_fund     : 0.1703  (17.0%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.46%
#   Volatility     (ann.) : 7.80%
#   Sharpe ratio          : 1.0852
#   Weights:
#     index_fund    : 0.3328  (33.3%)
#     treasury_fund : 0.3190  (31.9%)
#     gold_fund     : 0.3482  (34.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.97%
#   Volatility     (ann.) : 8.03%
#   Sharpe ratio          : 1.1175
#   Weights:
#     index_fund    : 0.3962  (39.6%)
#     treasury_fund : 0.3552  (35.5%)
#     gold_fund     : 0.2486  (24.9%)
#
# ── Regime 0  (316 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.19%  →  BS +10.68%
#     treasury_fund   : sample +7.08%  →  BS +7.88%
#     gold_fund       : sample +5.37%  →  BS +5.34%
#   Bayes-Stein φ  : 0.9564  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2163
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.53%
#     treasury_fund   : 10.34%
#     gold_fund       : 12.26%
#
# ── Regime 1  (43 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.45%  →  BS +11.31%
#     treasury_fund   : sample +14.02%  →  BS +8.92%
#     gold_fund       : sample +5.09%  →  BS +5.30%
#   Bayes-Stein φ  : 0.8362  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5224
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.78%
#     treasury_fund   : 13.67%
#     gold_fund       : 14.29%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.99%
#   Volatility     (ann.) : 6.82%
#   Sharpe ratio          : 1.1718
#   Weights:
#     index_fund    : 0.2905  (29.0%)
#     treasury_fund : 0.4345  (43.5%)
#     gold_fund     : 0.2750  (27.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.49%
#   Volatility     (ann.) : 7.03%
#   Sharpe ratio          : 1.2077
#   Weights:
#     index_fund    : 0.3752  (37.5%)
#     treasury_fund : 0.4525  (45.3%)
#     gold_fund     : 0.1723  (17.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.45%
#   Volatility     (ann.) : 7.80%
#   Sharpe ratio          : 1.0840
#   Weights:
#     index_fund    : 0.3328  (33.3%)
#     treasury_fund : 0.3190  (31.9%)
#     gold_fund     : 0.3482  (34.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.97%
#   Volatility     (ann.) : 8.03%
#   Sharpe ratio          : 1.1165
#   Weights:
#     index_fund    : 0.3982  (39.8%)
#     treasury_fund : 0.3522  (35.2%)
#     gold_fund     : 0.2496  (25.0%)
#
# ── Regime 0  (317 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.17%  →  BS +10.66%
#     treasury_fund   : sample +7.35%  →  BS +8.11%
#     gold_fund       : sample +5.57%  →  BS +5.52%
#   Bayes-Stein φ  : 0.9590  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2194
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.51%
#     treasury_fund   : 10.41%
#     gold_fund       : 12.28%
#
# ── Regime 1  (43 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.45%  →  BS +11.27%
#     treasury_fund   : sample +14.02%  →  BS +9.07%
#     gold_fund       : sample +5.09%  →  BS +5.45%
#   Bayes-Stein φ  : 0.8437  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5224
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.78%
#     treasury_fund   : 13.67%
#     gold_fund       : 14.29%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.15%
#   Volatility     (ann.) : 6.86%
#   Sharpe ratio          : 1.1881
#   Weights:
#     index_fund    : 0.2938  (29.4%)
#     treasury_fund : 0.4312  (43.1%)
#     gold_fund     : 0.2750  (27.5%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.61%
#   Volatility     (ann.) : 7.05%
#   Sharpe ratio          : 1.2215
#   Weights:
#     index_fund    : 0.3730  (37.3%)
#     treasury_fund : 0.4532  (45.3%)
#     gold_fund     : 0.1738  (17.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.54%
#   Volatility     (ann.) : 7.80%
#   Sharpe ratio          : 1.0951
#   Weights:
#     index_fund    : 0.3328  (33.3%)
#     treasury_fund : 0.3190  (31.9%)
#     gold_fund     : 0.3482  (34.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.02%
#   Volatility     (ann.) : 8.02%
#   Sharpe ratio          : 1.1257
#   Weights:
#     index_fund    : 0.3943  (39.4%)
#     treasury_fund : 0.3539  (35.4%)
#     gold_fund     : 0.2518  (25.2%)
#
# ── Regime 0  (318 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +9.83%  →  BS +10.36%
#     treasury_fund   : sample +7.58%  →  BS +8.31%
#     gold_fund       : sample +5.64%  →  BS +5.58%
#   Bayes-Stein φ  : 0.9595  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2094
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.61%
#     treasury_fund   : 10.44%
#     gold_fund       : 12.28%
#
# ── Regime 1  (43 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.45%  →  BS +11.01%
#     treasury_fund   : sample +14.02%  →  BS +9.23%
#     gold_fund       : sample +5.09%  →  BS +5.50%
#   Bayes-Stein φ  : 0.8447  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5224
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.78%
#     treasury_fund   : 13.67%
#     gold_fund       : 14.29%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.16%
#   Volatility     (ann.) : 6.85%
#   Sharpe ratio          : 1.1915
#   Weights:
#     index_fund    : 0.2941  (29.4%)
#     treasury_fund : 0.4319  (43.2%)
#     gold_fund     : 0.2741  (27.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.58%
#   Volatility     (ann.) : 7.02%
#   Sharpe ratio          : 1.2213
#   Weights:
#     index_fund    : 0.3625  (36.3%)
#     treasury_fund : 0.4635  (46.4%)
#     gold_fund     : 0.1739  (17.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.52%
#   Volatility     (ann.) : 7.80%
#   Sharpe ratio          : 1.0929
#   Weights:
#     index_fund    : 0.3328  (33.3%)
#     treasury_fund : 0.3190  (31.9%)
#     gold_fund     : 0.3482  (34.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.98%
#   Volatility     (ann.) : 8.00%
#   Sharpe ratio          : 1.1218
#   Weights:
#     index_fund    : 0.3879  (38.8%)
#     treasury_fund : 0.3601  (36.0%)
#     gold_fund     : 0.2520  (25.2%)
#
# ── Regime 0  (319 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +9.32%  →  BS +9.90%
#     treasury_fund   : sample +7.73%  →  BS +8.45%
#     gold_fund       : sample +5.61%  →  BS +5.55%
#   Bayes-Stein φ  : 0.9587  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1930
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.84%
#     treasury_fund   : 10.43%
#     gold_fund       : 12.28%
#
# ── Regime 1  (43 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.45%  →  BS +10.65%
#     treasury_fund   : sample +14.02%  →  BS +9.37%
#     gold_fund       : sample +5.09%  →  BS +5.48%
#   Bayes-Stein φ  : 0.8403  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5224
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.78%
#     treasury_fund   : 13.67%
#     gold_fund       : 14.29%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.08%
#   Volatility     (ann.) : 6.86%
#   Sharpe ratio          : 1.1780
#   Weights:
#     index_fund    : 0.2895  (29.0%)
#     treasury_fund : 0.4377  (43.8%)
#     gold_fund     : 0.2728  (27.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.45%
#   Volatility     (ann.) : 7.02%
#   Sharpe ratio          : 1.2050
#   Weights:
#     index_fund    : 0.3468  (34.7%)
#     treasury_fund : 0.4811  (48.1%)
#     gold_fund     : 0.1721  (17.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.44%
#   Volatility     (ann.) : 7.80%
#   Sharpe ratio          : 1.0821
#   Weights:
#     index_fund    : 0.3328  (33.3%)
#     treasury_fund : 0.3190  (31.9%)
#     gold_fund     : 0.3482  (34.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.88%
#   Volatility     (ann.) : 8.00%
#   Sharpe ratio          : 1.1100
#   Weights:
#     index_fund    : 0.3809  (38.1%)
#     treasury_fund : 0.3686  (36.9%)
#     gold_fund     : 0.2506  (25.1%)
#
# ── Regime 0  (320 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +9.79%  →  BS +10.32%
#     treasury_fund   : sample +7.81%  →  BS +8.52%
#     gold_fund       : sample +5.81%  →  BS +5.73%
#   Bayes-Stein φ  : 0.9615  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1854
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 14.02%
#     treasury_fund   : 10.42%
#     gold_fund       : 12.31%
#
# ── Regime 1  (43 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.45%  →  BS +10.95%
#     treasury_fund   : sample +14.02%  →  BS +9.37%
#     gold_fund       : sample +5.09%  →  BS +5.63%
#   Bayes-Stein φ  : 0.8503  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5224
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.78%
#     treasury_fund   : 13.67%
#     gold_fund       : 14.29%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.27%
#   Volatility     (ann.) : 6.93%
#   Sharpe ratio          : 1.1926
#   Weights:
#     index_fund    : 0.2837  (28.4%)
#     treasury_fund : 0.4440  (44.4%)
#     gold_fund     : 0.2723  (27.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.66%
#   Volatility     (ann.) : 7.10%
#   Sharpe ratio          : 1.2207
#   Weights:
#     index_fund    : 0.3466  (34.7%)
#     treasury_fund : 0.4819  (48.2%)
#     gold_fund     : 0.1715  (17.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.59%
#   Volatility     (ann.) : 7.80%
#   Sharpe ratio          : 1.1019
#   Weights:
#     index_fund    : 0.3328  (33.3%)
#     treasury_fund : 0.3190  (31.9%)
#     gold_fund     : 0.3482  (34.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.03%
#   Volatility     (ann.) : 7.99%
#   Sharpe ratio          : 1.1294
#   Weights:
#     index_fund    : 0.3842  (38.4%)
#     treasury_fund : 0.3620  (36.2%)
#     gold_fund     : 0.2538  (25.4%)
#
# ── Regime 0  (321 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +9.93%  →  BS +10.45%
#     treasury_fund   : sample +7.72%  →  BS +8.44%
#     gold_fund       : sample +5.87%  →  BS +5.78%
#   Bayes-Stein φ  : 0.9612  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1842
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 14.02%
#     treasury_fund   : 10.41%
#     gold_fund       : 12.30%
#
# ── Regime 1  (43 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.45%  →  BS +11.06%
#     treasury_fund   : sample +14.02%  →  BS +9.30%
#     gold_fund       : sample +5.09%  →  BS +5.67%
#   Bayes-Stein φ  : 0.8501  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5224
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.78%
#     treasury_fund   : 13.67%
#     gold_fund       : 14.29%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.28%
#   Volatility     (ann.) : 6.92%
#   Sharpe ratio          : 1.1964
#   Weights:
#     index_fund    : 0.2834  (28.3%)
#     treasury_fund : 0.4446  (44.5%)
#     gold_fund     : 0.2720  (27.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.68%
#   Volatility     (ann.) : 7.09%
#   Sharpe ratio          : 1.2246
#   Weights:
#     index_fund    : 0.3491  (34.9%)
#     treasury_fund : 0.4776  (47.8%)
#     gold_fund     : 0.1733  (17.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.62%
#   Volatility     (ann.) : 7.80%
#   Sharpe ratio          : 1.1058
#   Weights:
#     index_fund    : 0.3328  (33.3%)
#     treasury_fund : 0.3190  (31.9%)
#     gold_fund     : 0.3482  (34.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.05%
#   Volatility     (ann.) : 7.99%
#   Sharpe ratio          : 1.1331
#   Weights:
#     index_fund    : 0.3863  (38.6%)
#     treasury_fund : 0.3583  (35.8%)
#     gold_fund     : 0.2554  (25.5%)
#
# ── Regime 0  (322 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +9.96%  →  BS +10.47%
#     treasury_fund   : sample +7.71%  →  BS +8.43%
#     gold_fund       : sample +5.88%  →  BS +5.79%
#   Bayes-Stein φ  : 0.9611  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1842
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 14.00%
#     treasury_fund   : 10.40%
#     gold_fund       : 12.28%
#
# ── Regime 1  (43 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.45%  →  BS +11.08%
#     treasury_fund   : sample +14.02%  →  BS +9.29%
#     gold_fund       : sample +5.09%  →  BS +5.68%
#   Bayes-Stein φ  : 0.8501  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5224
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.78%
#     treasury_fund   : 13.67%
#     gold_fund       : 14.29%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.29%
#   Volatility     (ann.) : 6.91%
#   Sharpe ratio          : 1.1991
#   Weights:
#     index_fund    : 0.2834  (28.3%)
#     treasury_fund : 0.4446  (44.5%)
#     gold_fund     : 0.2720  (27.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.68%
#   Volatility     (ann.) : 7.07%
#   Sharpe ratio          : 1.2272
#   Weights:
#     index_fund    : 0.3494  (34.9%)
#     treasury_fund : 0.4767  (47.7%)
#     gold_fund     : 0.1738  (17.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.63%
#   Volatility     (ann.) : 7.80%
#   Sharpe ratio          : 1.1068
#   Weights:
#     index_fund    : 0.3328  (33.3%)
#     treasury_fund : 0.3190  (31.9%)
#     gold_fund     : 0.3482  (34.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.06%
#   Volatility     (ann.) : 7.99%
#   Sharpe ratio          : 1.1340
#   Weights:
#     index_fund    : 0.3865  (38.7%)
#     treasury_fund : 0.3577  (35.8%)
#     gold_fund     : 0.2558  (25.6%)
#
# ── Regime 0  (323 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.15%  →  BS +10.64%
#     treasury_fund   : sample +7.85%  →  BS +8.54%
#     gold_fund       : sample +6.10%  →  BS +5.99%
#   Bayes-Stein φ  : 0.9629  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1834
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 14.01%
#     treasury_fund   : 10.41%
#     gold_fund       : 12.31%
#
# ── Regime 1  (43 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.45%  →  BS +11.20%
#     treasury_fund   : sample +14.02%  →  BS +9.35%
#     gold_fund       : sample +5.09%  →  BS +5.86%
#   Bayes-Stein φ  : 0.8563  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5224
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.78%
#     treasury_fund   : 13.67%
#     gold_fund       : 14.29%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.45%
#   Volatility     (ann.) : 6.95%
#   Sharpe ratio          : 1.2145
#   Weights:
#     index_fund    : 0.2831  (28.3%)
#     treasury_fund : 0.4462  (44.6%)
#     gold_fund     : 0.2707  (27.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.83%
#   Volatility     (ann.) : 7.11%
#   Sharpe ratio          : 1.2418
#   Weights:
#     index_fund    : 0.3492  (34.9%)
#     treasury_fund : 0.4759  (47.6%)
#     gold_fund     : 0.1748  (17.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.75%
#   Volatility     (ann.) : 7.80%
#   Sharpe ratio          : 1.1222
#   Weights:
#     index_fund    : 0.3328  (33.3%)
#     treasury_fund : 0.3190  (31.9%)
#     gold_fund     : 0.3482  (34.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.16%
#   Volatility     (ann.) : 7.98%
#   Sharpe ratio          : 1.1482
#   Weights:
#     index_fund    : 0.3861  (38.6%)
#     treasury_fund : 0.3549  (35.5%)
#     gold_fund     : 0.2590  (25.9%)
#
# ── Regime 0  (324 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.40%  →  BS +10.85%
#     treasury_fund   : sample +7.65%  →  BS +8.36%
#     gold_fund       : sample +6.33%  →  BS +6.19%
#   Bayes-Stein φ  : 0.9618  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1838
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 14.05%
#     treasury_fund   : 10.45%
#     gold_fund       : 12.35%
#
# ── Regime 1  (43 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.45%  →  BS +11.40%
#     treasury_fund   : sample +14.02%  →  BS +9.22%
#     gold_fund       : sample +5.09%  →  BS +6.03%
#   Bayes-Stein φ  : 0.8532  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5224
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.78%
#     treasury_fund   : 13.67%
#     gold_fund       : 14.29%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.48%
#   Volatility     (ann.) : 6.95%
#   Sharpe ratio          : 1.2201
#   Weights:
#     index_fund    : 0.2824  (28.2%)
#     treasury_fund : 0.4481  (44.8%)
#     gold_fund     : 0.2695  (27.0%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.85%
#   Volatility     (ann.) : 7.10%
#   Sharpe ratio          : 1.2461
#   Weights:
#     index_fund    : 0.3527  (35.3%)
#     treasury_fund : 0.4654  (46.5%)
#     gold_fund     : 0.1820  (18.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.83%
#   Volatility     (ann.) : 7.80%
#   Sharpe ratio          : 1.1327
#   Weights:
#     index_fund    : 0.3328  (33.3%)
#     treasury_fund : 0.3190  (31.9%)
#     gold_fund     : 0.3482  (34.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.22%
#   Volatility     (ann.) : 7.97%
#   Sharpe ratio          : 1.1574
#   Weights:
#     index_fund    : 0.3891  (38.9%)
#     treasury_fund : 0.3464  (34.6%)
#     gold_fund     : 0.2645  (26.5%)
#
# ── Regime 0  (325 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.20%  →  BS +10.68%
#     treasury_fund   : sample +7.65%  →  BS +8.37%
#     gold_fund       : sample +6.23%  →  BS +6.10%
#   Bayes-Stein φ  : 0.9613  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1811
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 14.06%
#     treasury_fund   : 10.43%
#     gold_fund       : 12.35%
#
# ── Regime 1  (43 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.45%  →  BS +11.26%
#     treasury_fund   : sample +14.02%  →  BS +9.24%
#     gold_fund       : sample +5.09%  →  BS +5.95%
#   Bayes-Stein φ  : 0.8509  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5224
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.78%
#     treasury_fund   : 13.67%
#     gold_fund       : 14.29%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.41%
#   Volatility     (ann.) : 6.95%
#   Sharpe ratio          : 1.2094
#   Weights:
#     index_fund    : 0.2814  (28.1%)
#     treasury_fund : 0.4498  (45.0%)
#     gold_fund     : 0.2688  (26.9%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.77%
#   Volatility     (ann.) : 7.10%
#   Sharpe ratio          : 1.2352
#   Weights:
#     index_fund    : 0.3498  (35.0%)
#     treasury_fund : 0.4712  (47.1%)
#     gold_fund     : 0.1790  (17.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.76%
#   Volatility     (ann.) : 7.80%
#   Sharpe ratio          : 1.1237
#   Weights:
#     index_fund    : 0.3328  (33.3%)
#     treasury_fund : 0.3190  (31.9%)
#     gold_fund     : 0.3482  (34.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.16%
#   Volatility     (ann.) : 7.97%
#   Sharpe ratio          : 1.1486
#   Weights:
#     index_fund    : 0.3876  (38.8%)
#     treasury_fund : 0.3498  (35.0%)
#     gold_fund     : 0.2627  (26.3%)
#
# ── Regime 0  (326 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +10.09%  →  BS +10.58%
#     treasury_fund   : sample +7.51%  →  BS +8.24%
#     gold_fund       : sample +6.17%  →  BS +6.05%
#   Bayes-Stein φ  : 0.9599  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1821
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 14.05%
#     treasury_fund   : 10.44%
#     gold_fund       : 12.33%
#
# ── Regime 1  (43 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.45%  →  BS +11.19%
#     treasury_fund   : sample +14.02%  →  BS +9.16%
#     gold_fund       : sample +5.09%  →  BS +5.89%
#   Bayes-Stein φ  : 0.8451  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5224
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 15.78%
#     treasury_fund   : 13.67%
#     gold_fund       : 14.29%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.30%
#   Volatility     (ann.) : 6.96%
#   Sharpe ratio          : 1.1925
#   Weights:
#     index_fund    : 0.2813  (28.1%)
#     treasury_fund : 0.4488  (44.9%)
#     gold_fund     : 0.2699  (27.0%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.66%
#   Volatility     (ann.) : 7.11%
#   Sharpe ratio          : 1.2179
#   Weights:
#     index_fund    : 0.3508  (35.1%)
#     treasury_fund : 0.4687  (46.9%)
#     gold_fund     : 0.1805  (18.1%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.70%
#   Volatility     (ann.) : 7.80%
#   Sharpe ratio          : 1.1156
#   Weights:
#     index_fund    : 0.3328  (33.3%)
#     treasury_fund : 0.3190  (31.9%)
#     gold_fund     : 0.3482  (34.8%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +9.09%
#   Volatility     (ann.) : 7.97%
#   Sharpe ratio          : 1.1405
#   Weights:
#     index_fund    : 0.3880  (38.8%)
#     treasury_fund : 0.3495  (35.0%)
#     gold_fund     : 0.2625  (26.3%)
# Sort method: 'trace'
# State 0 = Expansion  (tr(Σ)=0.5277  PC1_mean=-0.143)
# State 1 = Recession  (tr(Σ)=3.2702  PC1_mean=-3.706)
# Transition matrix:
# [[0.9447 0.0553]
#  [0.4538 0.5462]]
# State durations (months): ['18.1', '2.2']
#
# ── Regime 0  (333 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.53%  →  BS +11.06%
#     treasury_fund   : sample +7.67%  →  BS +8.24%
#     gold_fund       : sample +5.61%  →  BS +5.93%
#   Bayes-Stein φ  : 0.9141  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1675
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.21%
#     treasury_fund   : 10.17%
#     gold_fund       : 12.56%
#
# ── Regime 1  (37 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -3.53%  →  BS +6.57%
#     treasury_fund   : sample +13.94%  →  BS +10.00%
#     gold_fund       : sample +9.17%  →  BS +6.93%
#   Bayes-Stein φ  : 0.6985  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2641
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 22.01%
#     treasury_fund   : 15.09%
#     gold_fund       : 12.99%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.57%
#   Volatility     (ann.) : 6.66%
#   Sharpe ratio          : 1.2878
#   Weights:
#     index_fund    : 0.3199  (32.0%)
#     treasury_fund : 0.4333  (43.3%)
#     gold_fund     : 0.2468  (24.7%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.96%
#   Volatility     (ann.) : 6.81%
#   Sharpe ratio          : 1.3163
#   Weights:
#     index_fund    : 0.3886  (38.9%)
#     treasury_fund : 0.4473  (44.7%)
#     gold_fund     : 0.1641  (16.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.07%
#   Volatility     (ann.) : 8.75%
#   Sharpe ratio          : 0.9220
#   Weights:
#     index_fund    : 0.1299  (13.0%)
#     treasury_fund : 0.3855  (38.5%)
#     gold_fund     : 0.4846  (48.5%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.31%
#   Volatility     (ann.) : 8.88%
#   Sharpe ratio          : 0.9357
#   Weights:
#     index_fund    : 0.1035  (10.3%)
#     treasury_fund : 0.4611  (46.1%)
#     gold_fund     : 0.4354  (43.5%)
#
# ── Regime 0  (334 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.61%  →  BS +11.14%
# ...
#     index_fund      : sample +8.98%  →  BS +11.11%
#     treasury_fund   : sample +6.56%  →  BS +6.30%
#     gold_fund       : sample +5.79%  →  BS +6.63%
#   Bayes-Stein φ  : 0.9855  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5171
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.27%
#     treasury_fund   : 15.11%
#     gold_fund       : 14.28%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.88%
#   Volatility     (ann.) : 7.28%
#   Sharpe ratio          : 1.0818
#   Weights:
#     index_fund    : 0.3038  (30.4%)
#     treasury_fund : 0.3838  (38.4%)
#     gold_fund     : 0.3124  (31.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.41%
#   Volatility     (ann.) : 7.53%
#   Sharpe ratio          : 1.1179
#   Weights:
#     index_fund    : 0.4167  (41.7%)
#     treasury_fund : 0.3076  (30.8%)
#     gold_fund     : 0.2757  (27.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.61%
#   Volatility     (ann.) : 9.16%
#   Sharpe ratio          : 0.8310
#   Weights:
#     index_fund    : 0.2451  (24.5%)
#     treasury_fund : 0.3536  (35.4%)
#     gold_fund     : 0.4014  (40.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.16%
#   Volatility     (ann.) : 9.48%
#   Sharpe ratio          : 0.8602
#   Weights:
#     index_fund    : 0.3617  (36.2%)
#     treasury_fund : 0.2890  (28.9%)
#     gold_fund     : 0.3493  (34.9%)
#
# ── Regime 0  (374 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +11.39%  →  BS +11.11%
#     treasury_fund   : sample +6.21%  →  BS +6.25%
#     gold_fund       : sample +6.98%  →  BS +6.84%
#   Bayes-Stein φ  : 0.9963  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2140
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.74%
#     treasury_fund   : 11.12%
#     gold_fund       : 12.41%
#
# ── Regime 1  (49 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +8.98%  →  BS +11.07%
#     treasury_fund   : sample +6.56%  →  BS +6.26%
#     gold_fund       : sample +5.79%  →  BS +6.82%
#   Bayes-Stein φ  : 0.9843  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5171
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.27%
#     treasury_fund   : 15.11%
#     gold_fund       : 14.28%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.91%
#   Volatility     (ann.) : 7.28%
#   Sharpe ratio          : 1.0872
#   Weights:
#     index_fund    : 0.3042  (30.4%)
#     treasury_fund : 0.3845  (38.4%)
#     gold_fund     : 0.3113  (31.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.43%
#   Volatility     (ann.) : 7.51%
#   Sharpe ratio          : 1.1223
#   Weights:
#     index_fund    : 0.4145  (41.5%)
#     treasury_fund : 0.3027  (30.3%)
#     gold_fund     : 0.2828  (28.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.66%
#   Volatility     (ann.) : 9.16%
#   Sharpe ratio          : 0.8367
#   Weights:
#     index_fund    : 0.2451  (24.5%)
#     treasury_fund : 0.3536  (35.4%)
#     gold_fund     : 0.4014  (40.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.18%
#   Volatility     (ann.) : 9.47%
#   Sharpe ratio          : 0.8646
#   Weights:
#     index_fund    : 0.3580  (35.8%)
#     treasury_fund : 0.2846  (28.5%)
#     gold_fund     : 0.3574  (35.7%)
#
# ── Regime 0  (375 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +11.56%  →  BS +11.26%
#     treasury_fund   : sample +6.10%  →  BS +6.15%
#     gold_fund       : sample +7.03%  →  BS +6.89%
#   Bayes-Stein φ  : 0.9958  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2133
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.75%
#     treasury_fund   : 11.13%
#     gold_fund       : 12.40%
#
# ── Regime 1  (49 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +8.98%  →  BS +11.22%
#     treasury_fund   : sample +6.56%  →  BS +6.16%
#     gold_fund       : sample +5.79%  →  BS +6.87%
#   Bayes-Stein φ  : 0.9820  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5171
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.27%
#     treasury_fund   : 15.11%
#     gold_fund       : 14.28%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.93%
#   Volatility     (ann.) : 7.27%
#   Sharpe ratio          : 1.0910
#   Weights:
#     index_fund    : 0.3037  (30.4%)
#     treasury_fund : 0.3852  (38.5%)
#     gold_fund     : 0.3111  (31.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.50%
#   Volatility     (ann.) : 7.52%
#   Sharpe ratio          : 1.1290
#   Weights:
#     index_fund    : 0.4178  (41.8%)
#     treasury_fund : 0.2977  (29.8%)
#     gold_fund     : 0.2846  (28.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.68%
#   Volatility     (ann.) : 9.16%
#   Sharpe ratio          : 0.8388
#   Weights:
#     index_fund    : 0.2451  (24.5%)
#     treasury_fund : 0.3536  (35.4%)
#     gold_fund     : 0.4014  (40.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.24%
#   Volatility     (ann.) : 9.49%
#   Sharpe ratio          : 0.8688
#   Weights:
#     index_fund    : 0.3618  (36.2%)
#     treasury_fund : 0.2793  (27.9%)
#     gold_fund     : 0.3589  (35.9%)
#
# ── Regime 0  (376 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +11.68%  →  BS +11.37%
#     treasury_fund   : sample +6.17%  →  BS +6.21%
#     gold_fund       : sample +7.08%  →  BS +6.93%
#   Bayes-Stein φ  : 0.9955  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2124
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.75%
#     treasury_fund   : 11.12%
#     gold_fund       : 12.38%
#
# ── Regime 1  (49 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +8.98%  →  BS +11.32%
#     treasury_fund   : sample +6.56%  →  BS +6.22%
#     gold_fund       : sample +5.79%  →  BS +6.91%
#   Bayes-Stein φ  : 0.9806  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5171
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.27%
#     treasury_fund   : 15.11%
#     gold_fund       : 14.28%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.00%
#   Volatility     (ann.) : 7.27%
#   Sharpe ratio          : 1.1000
#   Weights:
#     index_fund    : 0.3033  (30.3%)
#     treasury_fund : 0.3854  (38.5%)
#     gold_fund     : 0.3113  (31.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.57%
#   Volatility     (ann.) : 7.53%
#   Sharpe ratio          : 1.1387
#   Weights:
#     index_fund    : 0.4179  (41.8%)
#     treasury_fund : 0.2979  (29.8%)
#     gold_fund     : 0.2842  (28.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.75%
#   Volatility     (ann.) : 9.16%
#   Sharpe ratio          : 0.8457
#   Weights:
#     index_fund    : 0.2451  (24.5%)
#     treasury_fund : 0.3536  (35.4%)
#     gold_fund     : 0.4014  (40.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.31%
#   Volatility     (ann.) : 9.49%
#   Sharpe ratio          : 0.8762
#   Weights:
#     index_fund    : 0.3622  (36.2%)
#     treasury_fund : 0.2796  (28.0%)
#     gold_fund     : 0.3583  (35.8%)
#
# ── Regime 0  (377 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +11.73%  →  BS +11.41%
#     treasury_fund   : sample +6.12%  →  BS +6.17%
#     gold_fund       : sample +7.05%  →  BS +6.91%
#   Bayes-Stein φ  : 0.9954  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2121
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.73%
#     treasury_fund   : 11.10%
#     gold_fund       : 12.37%
#
# ── Regime 1  (49 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +8.98%  →  BS +11.36%
#     treasury_fund   : sample +6.56%  →  BS +6.18%
#     gold_fund       : sample +5.79%  →  BS +6.88%
#   Bayes-Stein φ  : 0.9802  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5171
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.27%
#     treasury_fund   : 15.11%
#     gold_fund       : 14.28%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.99%
#   Volatility     (ann.) : 7.26%
#   Sharpe ratio          : 1.1001
#   Weights:
#     index_fund    : 0.3034  (30.3%)
#     treasury_fund : 0.3854  (38.5%)
#     gold_fund     : 0.3113  (31.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.58%
#   Volatility     (ann.) : 7.53%
#   Sharpe ratio          : 1.1400
#   Weights:
#     index_fund    : 0.4199  (42.0%)
#     treasury_fund : 0.2964  (29.6%)
#     gold_fund     : 0.2837  (28.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.73%
#   Volatility     (ann.) : 9.16%
#   Sharpe ratio          : 0.8442
#   Weights:
#     index_fund    : 0.2451  (24.5%)
#     treasury_fund : 0.3536  (35.4%)
#     gold_fund     : 0.4014  (40.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.32%
#   Volatility     (ann.) : 9.50%
#   Sharpe ratio          : 0.8756
#   Weights:
#     index_fund    : 0.3642  (36.4%)
#     treasury_fund : 0.2783  (27.8%)
#     gold_fund     : 0.3575  (35.7%)
#
# ── Regime 0  (378 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +11.76%  →  BS +11.44%
#     treasury_fund   : sample +6.12%  →  BS +6.17%
#     gold_fund       : sample +7.06%  →  BS +6.91%
#   Bayes-Stein φ  : 0.9953  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2122
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.72%
#     treasury_fund   : 11.09%
#     gold_fund       : 12.35%
#
# ── Regime 1  (49 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +8.98%  →  BS +11.39%
#     treasury_fund   : sample +6.56%  →  BS +6.18%
#     gold_fund       : sample +5.79%  →  BS +6.89%
#   Bayes-Stein φ  : 0.9798  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5171
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.27%
#     treasury_fund   : 15.11%
#     gold_fund       : 14.28%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.00%
#   Volatility     (ann.) : 7.25%
#   Sharpe ratio          : 1.1027
#   Weights:
#     index_fund    : 0.3033  (30.3%)
#     treasury_fund : 0.3854  (38.5%)
#     gold_fund     : 0.3113  (31.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.60%
#   Volatility     (ann.) : 7.52%
#   Sharpe ratio          : 1.1431
#   Weights:
#     index_fund    : 0.4205  (42.0%)
#     treasury_fund : 0.2958  (29.6%)
#     gold_fund     : 0.2837  (28.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.74%
#   Volatility     (ann.) : 9.16%
#   Sharpe ratio          : 0.8450
#   Weights:
#     index_fund    : 0.2451  (24.5%)
#     treasury_fund : 0.3536  (35.4%)
#     gold_fund     : 0.4014  (40.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.33%
#   Volatility     (ann.) : 9.50%
#   Sharpe ratio          : 0.8768
#   Weights:
#     index_fund    : 0.3648  (36.5%)
#     treasury_fund : 0.2778  (27.8%)
#     gold_fund     : 0.3574  (35.7%)
#
# ── Regime 0  (379 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +11.84%  →  BS +11.51%
#     treasury_fund   : sample +6.20%  →  BS +6.24%
#     gold_fund       : sample +7.32%  →  BS +7.15%
#   Bayes-Stein φ  : 0.9947  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2118
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.71%
#     treasury_fund   : 11.09%
#     gold_fund       : 12.41%
#
# ── Regime 1  (49 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +8.98%  →  BS +11.45%
#     treasury_fund   : sample +6.56%  →  BS +6.25%
#     gold_fund       : sample +5.79%  →  BS +7.12%
#   Bayes-Stein φ  : 0.9770  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5171
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.27%
#     treasury_fund   : 15.11%
#     gold_fund       : 14.28%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.12%
#   Volatility     (ann.) : 7.28%
#   Sharpe ratio          : 1.1157
#   Weights:
#     index_fund    : 0.3043  (30.4%)
#     treasury_fund : 0.3874  (38.7%)
#     gold_fund     : 0.3082  (30.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.71%
#   Volatility     (ann.) : 7.54%
#   Sharpe ratio          : 1.1552
#   Weights:
#     index_fund    : 0.4190  (41.9%)
#     treasury_fund : 0.2948  (29.5%)
#     gold_fund     : 0.2862  (28.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.87%
#   Volatility     (ann.) : 9.16%
#   Sharpe ratio          : 0.8592
#   Weights:
#     index_fund    : 0.2451  (24.5%)
#     treasury_fund : 0.3536  (35.4%)
#     gold_fund     : 0.4014  (40.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.44%
#   Volatility     (ann.) : 9.49%
#   Sharpe ratio          : 0.8897
#   Weights:
#     index_fund    : 0.3606  (36.1%)
#     treasury_fund : 0.2762  (27.6%)
#     gold_fund     : 0.3632  (36.3%)
#
# ── Regime 0  (380 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +11.89%  →  BS +11.56%
#     treasury_fund   : sample +6.22%  →  BS +6.26%
#     gold_fund       : sample +7.64%  →  BS +7.43%
#   Bayes-Stein φ  : 0.9940  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2128
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.70%
#     treasury_fund   : 11.09%
#     gold_fund       : 12.51%
#
# ── Regime 1  (49 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +8.98%  →  BS +11.49%
#     treasury_fund   : sample +6.56%  →  BS +6.27%
#     gold_fund       : sample +5.79%  →  BS +7.38%
#   Bayes-Stein φ  : 0.9733  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.5171
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 18.27%
#     treasury_fund   : 15.11%
#     gold_fund       : 14.28%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.23%
#   Volatility     (ann.) : 7.30%
#   Sharpe ratio          : 1.1276
#   Weights:
#     index_fund    : 0.3054  (30.5%)
#     treasury_fund : 0.3904  (39.0%)
#     gold_fund     : 0.3042  (30.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.81%
#   Volatility     (ann.) : 7.55%
#   Sharpe ratio          : 1.1664
#   Weights:
#     index_fund    : 0.4175  (41.7%)
#     treasury_fund : 0.2924  (29.2%)
#     gold_fund     : 0.2901  (29.0%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.99%
#   Volatility     (ann.) : 9.16%
#   Sharpe ratio          : 0.8728
#   Weights:
#     index_fund    : 0.2451  (24.5%)
#     treasury_fund : 0.3536  (35.4%)
#     gold_fund     : 0.4014  (40.1%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.54%
#   Volatility     (ann.) : 9.47%
#   Sharpe ratio          : 0.9021
#   Weights:
#     index_fund    : 0.3560  (35.6%)
#     treasury_fund : 0.2727  (27.3%)
#     gold_fund     : 0.3713  (37.1%)
#             gross_return  net_return_after_costs  trade_notional  \
# Date
# 2019-01-31      0.036416                0.036416        0.000000
# 2019-02-28      0.009539                0.009508        0.031017
# 2019-03-31      0.024119                0.024093        0.026296
# 2019-04-30      0.001655                0.001629        0.025822
# 2019-05-31      0.010701                0.010677        0.023960
#
#             one_way_turnover  transaction_cost  MSVAR_WF_State  \
# Date
# 2019-01-31          0.000000          0.000000               0
# 2019-02-28          0.015509          0.000031               0
# 2019-03-31          0.013148          0.000026               0
# 2019-04-30          0.012911          0.000026               0
# 2019-05-31          0.011980          0.000024               0
#
#             index_fund_weight  treasury_fund_weight  gold_fund_weight
# Date
# 2019-01-31           0.287475              0.437221          0.275305
# 2019-02-28           0.286369              0.439479          0.274153
# 2019-03-31           0.283859              0.442890          0.273251
# 2019-04-30           0.283760              0.443106          0.273134
# 2019-05-31           0.284327              0.440485          0.275188

# %% [markdown]
# ## Regime certainty diagnostics
#
# How often is the model genuinely uncertain about the regime? Periods with max **filtered** probability P(S_t | y_{1:t}) close to 0.5 are cases where hard regime assignment is unreliable — the model has seen all data up to time t but still cannot confidently assign a state. Filtered probabilities are used here (not smoothed) to avoid look-ahead bias, consistent with the walk-forward design.

# %%
fig, axes = plt.subplots(3, 2, figsize=(14, 12))

for ax_row, (name, probs, states) in zip(
    axes,
    [('HMM (PLS, primary)',      hmm_pls_filt_probs,      hmm_pls_states),
     ('HMM (PCA, robustness)',   hmm_pca_filt_probs,      hmm_pca_states),
     ('MSVAR (PCA, robustness)', msvar_pca_filt_probs,  msvar_pca_states)]
):
    if probs.empty:
        continue
    max_prob = probs.max(axis=1)

    ax_row[0].hist(max_prob, bins=40, color='steelblue', edgecolor='white', alpha=0.8)
    ax_row[0].axvline(0.8, color='red',    ls='--', lw=1.5, label='0.8')
    ax_row[0].axvline(0.6, color='orange', ls='--', lw=1.5, label='0.6')
    ax_row[0].set_title(f'{name}: distribution of max regime probability')
    ax_row[0].set_xlabel('Max P(state | data)')
    ax_row[0].set_ylabel('Count')
    ax_row[0].legend(title='Threshold')

    ax_row[1].plot(max_prob.index, max_prob, color='steelblue', lw=0.9)
    ax_row[1].fill_between(max_prob.index, 0.5, max_prob,
                           where=max_prob < 0.8, alpha=0.3,
                           color='orange', label='Uncertain (<0.8)')
    ax_row[1].axhline(0.8, color='red',    ls='--', lw=1.2)
    ax_row[1].axhline(0.6, color='orange', ls='--', lw=1.2)
    ax_row[1].set_ylim(0.45, 1.02)
    ax_row[1].set_title(f'{name}: regime certainty over time')
    ax_row[1].set_ylabel('Max P(state | data)')
    ax_row[1].legend(fontsize=9)

    n_total     = len(max_prob)
    n_certain   = (max_prob >= 0.8).sum()
    n_moderate  = ((max_prob >= 0.6) & (max_prob < 0.8)).sum()
    n_uncertain = (max_prob < 0.6).sum()
    print(f'\n{name}:')
    print(f'  Certain    (≥0.8):   {n_certain:3d} months  ({100*n_certain/n_total:.1f}%)')
    print(f'  Moderate (0.6–0.8):  {n_moderate:3d} months  ({100*n_moderate/n_total:.1f}%)')
    print(f'  Uncertain  (<0.6):   {n_uncertain:3d} months  ({100*n_uncertain/n_total:.1f}%)')

plt.tight_layout()
plt.savefig(OUTPUT_FIGURES_DIR / 'regime_certainty_diagnostics.png',
            dpi=300, bbox_inches='tight')
plt.show()
# Out:
# HMM (PLS, primary):
#   Certain    (≥0.8):   379 months  (90.7%)
#   Moderate (0.6–0.8):   30 months  (7.2%)
#   Uncertain  (<0.6):     9 months  (2.2%)
#
# HMM (PCA, robustness):
#   Certain    (≥0.8):   411 months  (98.3%)
#   Moderate (0.6–0.8):    6 months  (1.4%)
#   Uncertain  (<0.6):     1 months  (0.2%)
#
# MSVAR (PCA, robustness):
#   Certain    (≥0.8):   407 months  (97.6%)
#   Moderate (0.6–0.8):    8 months  (1.9%)
#   Uncertain  (<0.6):     2 months  (0.5%)

# %% [markdown]
# ## Benchmarks

# %%
from src.benchmarks import (build_sixty_forty_benchmark,
                             build_equal_weight_benchmark,
                             build_equity_only_benchmark)
from src.backtest import backtest_with_transaction_costs

# Restrict benchmarks to the walk-forward evaluation period
wf_start = hmm_pls_returns.index.min()
wf_end   = hmm_pls_returns.index.max()
wf_index = asset_df.loc[wf_start:wf_end].index

benchmark_configs = {
    '60_40':           build_sixty_forty_benchmark(wf_index),
    'Equal_Weight':    build_equal_weight_benchmark(wf_index),
    'Buy_Hold_Equity': build_equity_only_benchmark(wf_index),
}

benchmark_returns = {}
for name, weights in benchmark_configs.items():
    res = backtest_with_transaction_costs(
        target_weights       = weights,
        asset_returns        = asset_df,
        transaction_cost_bps = 0,    # static — no rebalancing cost
        apply_signal_lag     = False, # benchmarks don't have signal lag
    )
    benchmark_returns[name] = res.loc[wf_start:wf_end, 'gross_return']

print('Walk-forward evaluation period:', wf_start.date(), 'to', wf_end.date())
print(f'{len(wf_index)} months')
# Out:
# Walk-forward evaluation period: 2019-01-31 to 2025-12-31
# 84 months

# %% [markdown]
# ## Unconditional GMV walk-forward
#
# A regime-agnostic benchmark that re-estimates GMV weights annually on an expanding window of asset returns — no macro data, no regime model. This isolates the contribution of regime detection: if HMM_WF and MSVAR_WF cannot beat this, the regime machinery adds no value beyond simple expanding-window MVO.

# %%
from src.portfolio import estimate_unconditional_moments, _solve_mvo
from src.benchmarks import build_constant_weights

# ── Expanding-window unconditional GMV ───────────────────────────────────
# At each annual refit date, re-estimate GMV weights on all asset returns
# available up to that point.  No macro data, no regime model.
# Signal lag applied: weights from t used for returns at t+1.
INITIAL_TRAIN = INITIAL_TRAIN_MONTHS
REFIT_EVERY   = 12

common_idx   = asset_df.index
uncond_records = []
prev_w       = np.ones(3) / 3
last_refit   = -REFIT_EVERY

for t in range(INITIAL_TRAIN, len(common_idx) - 1):
    date_t   = common_idx[t]
    date_tp1 = common_idx[t + 1]

    if (t - last_refit) >= REFIT_EVERY:
        # Re-estimate GMV on expanding window
        R_train  = asset_df.iloc[:t][ASSET_COLS].values
        from sklearn.covariance import LedoitWolf
        lw       = LedoitWolf().fit(R_train)
        mu_dummy = np.zeros(3)   # GMV ignores mean
        w_gmv    = _solve_mvo(mu_dummy, lw.covariance_,
                              objective='min_variance', long_only=True)
        last_refit = t

    # Signal lag: weights from t → returns at t+1
    ret_tp1      = asset_df.loc[date_tp1, ASSET_COLS].values
    gross_ret    = float(w_gmv @ ret_tp1)

    # Transaction cost
    if uncond_records:
        prev_ret = asset_df.loc[date_t, ASSET_COLS].values
        drifted  = prev_w * (1 + prev_ret)
        drifted  = drifted / drifted.sum()
        notional = float(np.abs(w_gmv - drifted).sum())
    else:
        notional = 0.0
    tc       = notional * 10 / 10_000
    net_ret  = gross_ret - tc

    uncond_records.append({'Date': date_tp1,
                           'net_return_after_costs': net_ret})
    prev_w = w_gmv.copy()

uncond_gmv_wf = pd.DataFrame(uncond_records).set_index('Date')
print(f'Unconditional GMV WF: {len(uncond_gmv_wf)} months, '
      f'starting {uncond_gmv_wf.index.min().date()}')
# Out:
# Unconditional GMV WF: 84 months, starting 2019-01-31

# %% [markdown]
# ## Performance comparison

# %%
# Combine all strategies — including unconditional benchmarks
all_returns = pd.DataFrame({
    'HMM_PLS_WF':    hmm_pls_returns['net_return_after_costs'],
    'HMM_PCA_WF':    hmm_pca_returns['net_return_after_costs'],
    'MSVAR_PCA_WF':  msvar_pca_returns['net_return_after_costs'],
    **benchmark_returns,
    'Uncond_GMV_WF': uncond_gmv_wf['net_return_after_costs'],
}).dropna()
print('Strategies in all_returns:', list(all_returns.columns))

# ── Time-varying rf rate for the walk-forward period ──────────────
# Align FEDFUNDS monthly rate to the evaluation period.
# For summarize_performance(), we pass the period-average annualized rate.
rf_wf = monthly_rf.reindex(all_returns.index, method='ffill').fillna(0)
rf_wf_annual = float(rf_wf.mean() * 12)   # avg annualized over WF period
print(f'Walk-forward period avg annual rf: {rf_wf_annual:.4f} ({rf_wf_annual*100:.2f}%)')

benchmark_ref = all_returns['60_40']

perf_table = pd.DataFrame({
    col: summarize_performance(
        all_returns[col],
        benchmark_returns=(
            None if col == '60_40' else benchmark_ref
        ),
        risk_free_rate=rf_wf_annual,
    )
    for col in all_returns.columns
})

metric_order = [
    'Annualized Return',
    'Annualized Volatility',
    'Sharpe Ratio',
    'Sortino Ratio',
    'Max Drawdown',
    'VaR 95% (monthly)',
    'CVaR 95% (monthly)',
    'Information Ratio vs 60/40',
]
available = [m for m in metric_order if m in perf_table.index]
perf_table.loc[available].to_csv(
    OUTPUT_TABLES_DIR / 'walk_forward_performance.csv'
)
perf_table.loc[available]
# Out:
# Strategies in all_returns: ['HMM_PLS_WF', 'HMM_PCA_WF', 'MSVAR_PCA_WF', '60_40', 'Equal_Weight', 'Buy_Hold_Equity', 'Uncond_GMV_WF']
# Walk-forward period avg annual rf: 0.0267 (2.67%)
#                             HMM_PLS_WF  HMM_PCA_WF  MSVAR_PCA_WF     60_40  \
# Annualized Return             0.116662    0.109168      0.106526  0.100091
# Annualized Volatility         0.100417    0.101552      0.101796  0.127855
# Sharpe Ratio                  0.887585    0.811869      0.786578  0.603604
# Sortino Ratio                 1.512261    1.380627      1.317150  0.948351
# Max Drawdown                 -0.200484   -0.204347     -0.212146 -0.257789
# VaR 95% (monthly)             0.031975    0.033575      0.033335  0.055796
# CVaR 95% (monthly)            0.049999    0.050170      0.051078  0.070214
# Information Ratio vs 60/40    0.218971    0.090240      0.049253       NaN
#
#                             Equal_Weight  Buy_Hold_Equity  Uncond_GMV_WF
# Annualized Return               0.120313         0.171620       0.106870
# Annualized Volatility           0.099479         0.168540       0.101413
# Sharpe Ratio                    0.928138         0.871230       0.792240
# Sortino Ratio                   1.589837         1.300196       1.325053
# Max Drawdown                   -0.196445        -0.240140      -0.211728
# VaR 95% (monthly)               0.031279         0.079598       0.033552
# CVaR 95% (monthly)              0.048962         0.095303       0.050501
# Information Ratio vs 60/40      0.267324         0.880986       0.052135

# %% [markdown]
# ## Cumulative wealth chart

# %%
cum_returns = (1 + all_returns).cumprod()

fig, ax = plt.subplots(figsize=(13, 6))

plot_config = {
    'HMM_PLS_WF':   ('#1a6faf', '-',  2.5, 'HMM Walk-Forward (PLS, GMV)'),
    'HMM_PCA_WF':   ('#2ca02c', '-',  2.0, 'HMM Walk-Forward (PCA, GMV)'),
    'MSVAR_PCA_WF': ('#d62728', '--', 1.6, 'MSVAR Walk-Forward (PCA, GMV) †'),
    'Uncond_GMV_WF':('#9467bd', '-',  1.4, 'Unconditional GMV (WF)'),
    'Uncond_GMV':   ('#9467bd', '--', 1.2, 'Unconditional GMV (fixed)'),
    'Uncond_MVO':   ('#8c564b', '--', 1.2, 'Unconditional MVO (fixed)'),
    '60_40':        ('#444444', ':',  1.2, '60/40'),
    'Equal_Weight': ('#e07b00', ':',  1.2, 'Equal Weight'),
}

for col in cum_returns.columns:
    cfg = plot_config.get(col, ('#aaaaaa', '--', 1.0, col))
    color, ls, lw, label = cfg
    ax.plot(cum_returns.index, cum_returns[col],
            color=color, linestyle=ls, linewidth=lw, label=label)

ax.set_title(
    'Walk-Forward Backtest: Cumulative Wealth\n'
    'Solid thick = regime WF | Solid medium = uncond. GMV WF | '
    'Dashed = fixed | Dotted = naive',
    fontweight='bold', fontsize=10
)
ax.set_ylabel('Portfolio Value (rebased to 1)')
ax.axhline(1, color='gray', lw=0.6, ls='--')
ax.legend(fontsize=9, loc='upper left', framealpha=0.95, ncol=2)
ax.grid(axis='y', linestyle='--', alpha=0.3)
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.savefig(OUTPUT_FIGURES_DIR / 'walk_forward_cumulative_wealth.png',
            dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## GMV strategies comparison
#
# Direct comparison of the four GMV strategies: `HMM_PLS_WF` (primary), `HMM_PCA_WF`
# (robustness 1), `MSVAR_PCA_WF` (robustness 2†), and `Uncond_GMV_WF`.
# This isolates (a) whether regime detection adds value over a naive expanding-window GMV
# and (b) whether PLS alignment to the portfolio objective improves on PCA.
#
# † MSVAR VAR mean structure is not economically interpretable on PCA components;
# included for completeness only.

# %%
# Three GMV strategies on the same chart — cleaner comparison
gmv_cols = ['HMM_PLS_WF', 'HMM_PCA_WF', 'MSVAR_PCA_WF', 'Uncond_GMV_WF']
gmv_available = [c for c in gmv_cols if c in all_returns.columns]

# Performance table
gmv_perf = pd.DataFrame({
    col: summarize_performance(
        all_returns[col],
        benchmark_returns=all_returns.get('Uncond_GMV_WF'),
        risk_free_rate=rf_wf_annual,
    )
    for col in gmv_available
})
avail = [m for m in metric_order if m in gmv_perf.index]
gmv_perf.loc[avail].to_csv(
    OUTPUT_TABLES_DIR / 'gmv_strategies_comparison.csv'
)
display(gmv_perf.loc[avail])

# Cumulative wealth
gmv_colors = {
    'HMM_PLS_WF':   ('#1a6faf', '-',  2.2, 'HMM Walk-Forward (PLS, GMV)'),
    'HMM_PCA_WF':   ('#2ca02c', '-',  2.2, 'HMM Walk-Forward (PCA, GMV)'),
    'MSVAR_PCA_WF': ('#d62728', '--', 2.0, 'MSVAR Walk-Forward (PCA, GMV) †'),
    'Uncond_GMV_WF': ('#9467bd', '--', 2.0, 'Unconditional GMV (WF)'),
}

fig, axes = plt.subplots(2, 1, figsize=(13, 9), sharex=True,
                          gridspec_kw={'height_ratios': [2, 1]})

# Top: cumulative wealth
for col in gmv_available:
    cfg = gmv_colors[col]
    color, ls, lw, label = cfg
    wealth = (1 + all_returns[col]).cumprod()
    axes[0].plot(wealth.index, wealth, color=color, ls=ls,
                 lw=lw, label=label)
axes[0].set_title('GMV Strategies: Walk-Forward Regime vs Unconditional',
                   fontweight='bold')
axes[0].set_ylabel('Portfolio Value')
axes[0].axhline(1, color='gray', lw=0.6, ls='--')
axes[0].legend(fontsize=10)
axes[0].grid(axis='y', linestyle='--', alpha=0.3)
axes[0].spines[['top','right']].set_visible(False)

# Bottom: rolling 12m Sharpe
for col in gmv_available:
    cfg = gmv_colors[col]
    color, ls, lw, label = cfg
    r = all_returns[col]
    roll_sh = (r.rolling(12).mean() /
               r.rolling(12).std().clip(1e-12)) * np.sqrt(12)
    axes[1].plot(roll_sh.index, roll_sh, color=color,
                 ls=ls, lw=lw, label=label)
axes[1].axhline(0, color='gray', lw=0.7, ls='--')
axes[1].set_title('Rolling 12-Month Sharpe Ratio', fontweight='bold')
axes[1].set_ylabel('Sharpe Ratio')
axes[1].grid(axis='y', linestyle='--', alpha=0.3)
axes[1].spines[['top','right']].set_visible(False)

plt.tight_layout()
plt.savefig(OUTPUT_FIGURES_DIR / 'gmv_strategies_comparison.png',
            dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                             HMM_PLS_WF  HMM_PCA_WF  MSVAR_PCA_WF  \
# Annualized Return             0.116662    0.109168      0.106526
# Annualized Volatility         0.100417    0.101552      0.101796
# Sharpe Ratio                  0.887585    0.811869      0.786578
# Sortino Ratio                 1.512261    1.380627      1.317150
# Max Drawdown                 -0.200484   -0.204347     -0.212146
# VaR 95% (monthly)             0.031975    0.033575      0.033335
# CVaR 95% (monthly)            0.049999    0.050170      0.051078
# Information Ratio vs 60/40    0.848708    0.394542     -0.065461
#
#                             Uncond_GMV_WF
# Annualized Return                0.106870
# Annualized Volatility            0.101413
# Sharpe Ratio                     0.792240
# Sortino Ratio                    1.325053
# Max Drawdown                    -0.211728
# VaR 95% (monthly)                0.033552
# CVaR 95% (monthly)               0.050501
# Information Ratio vs 60/40            NaN

# %% [markdown]
# ## Drawdown chart

# %%
# ── Drawdown chart ───────────────────────────────────────────────────────
# Uses the same color/style config as the cumulative wealth chart
# so every strategy is visually consistent across both charts.
fig, ax = plt.subplots(figsize=(13, 5))

# Full color map — covers all strategies in all_returns
draw_config = {
    'HMM_PLS_WF':          ('#1a6faf', '-',  1.8),
    'HMM_PCA_WF':          ('#2ca02c', '-',  1.8),
    'MSVAR_PCA_WF':        ('#d62728', '-',  1.8),
    'Uncond_GMV_WF':       ('#9467bd', '-',  1.4),
    '60_40':               ('#444444', ':',  1.2),
    'Equal_Weight':     ('#e07b00', ':',  1.2),
    'Buy_Hold_Equity':  ('#d62728', ':',  1.2),
}

for col in all_returns.columns:
    color, ls, lw = draw_config.get(col, ('#aaaaaa', '--', 1.0))
    wealth   = (1 + all_returns[col]).cumprod()
    roll_max = wealth.expanding().max()
    drawdown = (wealth / roll_max - 1) * 100
    ax.fill_between(wealth.index, drawdown, 0,
                    alpha=0.12, color=color)
    ax.plot(wealth.index, drawdown,
            lw=lw, ls=ls, color=color, label=col)

ax.axhline(0, color='black', lw=0.6, ls='--')
ax.set_title('Walk-Forward Backtest: Drawdown (%)', fontweight='bold')
ax.set_ylabel('Drawdown (%)')
ax.legend(fontsize=9, loc='lower left', framealpha=0.9, ncol=2)
ax.grid(axis='y', linestyle='--', alpha=0.3)
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.savefig(OUTPUT_FIGURES_DIR / 'walk_forward_drawdown.png',
            dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Regime state over time

# %%
# Plot filtered recession probability (State 1) for both models.
# Filtered probs P(S_t=1 | y_{1:t}) are the correct choice for a
# walk-forward simulation — no look-ahead bias from the smoother.
# The continuous probability series is far more informative than a
# binary step function: you can immediately see where the model is
# certain (prob near 0 or 1) vs uncertain (prob near 0.5).

fig, axes = plt.subplots(3, 1, figsize=(16, 7), sharex=True)

NBER_RECESSIONS = [
    ("2001-03-01", "2001-11-30"),
    ("2007-12-01", "2009-06-30"),
    ("2020-02-01", "2020-04-30"),
]

for ax, (name, filt_probs) in zip(axes, [
    ('HMM Walk-Forward (PLS)',   hmm_pls_filt_probs),
    ('HMM Walk-Forward (PCA)', hmm_pca_filt_probs),
    ('MSVAR Walk-Forward (PCA)', msvar_pca_filt_probs),
]):
    if filt_probs.empty:
        ax.set_title(f'{name}: no data')
        continue

    # Get recession filtered probability (State 1)
    rec_col = 'State_1_prob'
    if rec_col not in filt_probs.columns:
        rec_col = filt_probs.columns[1]
    rec_prob = filt_probs[rec_col].reindex(
        all_returns.index, method='ffill'
    ).dropna()

    # NBER recession shading
    for rs, re in NBER_RECESSIONS:
        rs, re = pd.Timestamp(rs), pd.Timestamp(re)
        if re >= rec_prob.index.min() and rs <= rec_prob.index.max():
            ax.axvspan(
                max(rs, rec_prob.index.min()),
                min(re, rec_prob.index.max()),
                color='#d4d4d4', alpha=0.5, zorder=0,
                label='NBER Recession'
            )

    # Filtered recession probability
    ax.fill_between(rec_prob.index, 0, rec_prob,
                    where=rec_prob >= 0.5,
                    color='#d62728', alpha=0.4,
                    label='P(Recession) ≥ 0.5')
    ax.fill_between(rec_prob.index, 0, rec_prob,
                    where=rec_prob < 0.5,
                    color='#1a6faf', alpha=0.3,
                    label='P(Recession) < 0.5')
    ax.plot(rec_prob.index, rec_prob,
            color='#222222', lw=0.9, zorder=3)
    ax.axhline(0.5, color='black', lw=0.7, ls='--', alpha=0.6)
    ax.set_ylim(-0.02, 1.02)
    ax.set_ylabel('P(Recession | data up to t)')
    ax.set_title(f'{name}: filtered recession probability',
                 fontweight='bold')

    # Deduplicate legend entries
    handles, labels = ax.get_legend_handles_labels()
    seen = set()
    unique = [(h,l) for h,l in zip(handles,labels)
              if not (l in seen or seen.add(l))]
    ax.legend(*zip(*unique), fontsize=9, loc='upper left')
    ax.grid(axis='y', linestyle='--', alpha=0.3)
    ax.spines[['top','right']].set_visible(False)

axes[-1].set_xlabel('Date')
plt.tight_layout()
plt.savefig(OUTPUT_FIGURES_DIR / 'walk_forward_regime_states.png',
            dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Subperiod robustness analysis
#
# Checks whether the walk-forward strategies outperform consistently across key market environments, or only in specific subperiods.

# %%
SUBPERIODS = {
    "Full_Period":                (all_returns.index.min(), all_returns.index.max()),
    "Dot-com bust (2001)":        (pd.Timestamp("2001-01-31"), pd.Timestamp("2001-12-31")),
    "GFC (2007-2009)":            (pd.Timestamp("2007-12-31"), pd.Timestamp("2009-06-30")),
    "COVID-19 (2020)":            (pd.Timestamp("2020-03-31"), pd.Timestamp("2020-12-31")),
    "Inflation 2021-2022":        (pd.Timestamp("2021-01-31"), pd.Timestamp("2022-12-31")),
    "Post-2022 normalization":    (pd.Timestamp("2023-01-31"), all_returns.index.max()),
}

subperiod_blocks = []
for period_name, (start, end) in SUBPERIODS.items():
    mask = (all_returns.index >= start) & (all_returns.index <= end)
    period_rets = all_returns.loc[mask]
    if period_rets.empty:
        continue
    # Time-varying rf for this subperiod
    period_rf = float(rf_wf.loc[mask].mean() * 12)
    bench = period_rets['60_40']
    for strat in period_rets.columns:
        s = summarize_performance(
            period_rets[strat],
            benchmark_returns=None if strat == '60_40' else bench,
            risk_free_rate=period_rf,
        )
        subperiod_blocks.append({
            'Subperiod': period_name, 'Strategy': strat, **s.to_dict()
        })

subperiod_df = pd.DataFrame(subperiod_blocks).set_index(['Subperiod', 'Strategy'])
subperiod_df.to_csv(OUTPUT_TABLES_DIR / 'walk_forward_subperiod.csv')
subperiod_df[['Annualized Return', 'Sharpe Ratio', 'Max Drawdown']]
# Out:
#                                          Annualized Return  Sharpe Ratio  \
# Subperiod               Strategy
# Full_Period             HMM_PLS_WF                0.116662      0.887585
#                         HMM_PCA_WF                0.109168      0.811869
#                         MSVAR_PCA_WF              0.106526      0.786578
#                         60_40                     0.100091      0.603604
#                         Equal_Weight              0.120313      0.928138
#                         Buy_Hold_Equity           0.171620      0.871230
#                         Uncond_GMV_WF             0.106870      0.792240
# COVID-19 (2020)         HMM_PLS_WF                0.151351      1.218542
#                         HMM_PCA_WF                0.149450      1.218668
#                         MSVAR_PCA_WF              0.129841      1.124997
#                         60_40                     0.189774      1.144337
#                         Equal_Weight              0.167358      1.327378
#                         Buy_Hold_Equity           0.349695      1.254228
#                         Uncond_GMV_WF             0.138995      1.194706
# Inflation 2021-2022     HMM_PLS_WF               -0.044227     -0.445660
#                         HMM_PCA_WF               -0.051721     -0.511847
#                         MSVAR_PCA_WF             -0.055322     -0.533402
#                         60_40                    -0.045415     -0.289590
#                         Equal_Weight             -0.044483     -0.457063
#                         Buy_Hold_Equity           0.024736      0.174143
#                         Uncond_GMV_WF            -0.059229     -0.578868
# Post-2022 normalization HMM_PLS_WF                0.181498      1.327591
#                         HMM_PCA_WF                0.171953      1.221011
#                         MSVAR_PCA_WF              0.170880      1.209617
#                         60_40                     0.136731      0.759539
#                         Equal_Weight              0.187137      1.403177
#                         Buy_Hold_Equity           0.229128      1.399219
#                         Uncond_GMV_WF             0.172873      1.230058
#
#                                          Max Drawdown
# Subperiod               Strategy
# Full_Period             HMM_PLS_WF          -0.200484
#                         HMM_PCA_WF          -0.204347
#                         MSVAR_PCA_WF        -0.212146
#                         60_40               -0.257789
#                         Equal_Weight        -0.196445
#                         Buy_Hold_Equity     -0.240140
#                         Uncond_GMV_WF       -0.211728
# COVID-19 (2020)         HMM_PLS_WF          -0.040833
#                         HMM_PCA_WF          -0.040210
#                         MSVAR_PCA_WF        -0.038814
#                         60_40               -0.049024
#                         Equal_Weight        -0.041461
#                         Buy_Hold_Equity     -0.065702
#                         Uncond_GMV_WF       -0.039423
# Inflation 2021-2022     HMM_PLS_WF          -0.200484
#                         HMM_PCA_WF          -0.204347
#                         MSVAR_PCA_WF        -0.212146
#                         60_40               -0.257789
#                         Equal_Weight        -0.196445
#                         Buy_Hold_Equity     -0.240140
#                         Uncond_GMV_WF       -0.211728
# Post-2022 normalization HMM_PLS_WF          -0.086529
#                         HMM_PCA_WF          -0.089132
#                         MSVAR_PCA_WF        -0.089576
#                         60_40               -0.107667
#                         Equal_Weight        -0.082556
#                         Buy_Hold_Equity     -0.082860
#                         Uncond_GMV_WF       -0.088449

# %% [markdown]
# ## Robustness checks
#
# Two checks to verify that the dim-reduction choice does not drive results:
#
# 1. **VIF analysis** — documents multicollinearity among the 15 macro indicators
# and justifies dimensionality reduction.
# 2. **HMM without any dimensionality reduction** — feeds all 15 raw robust-scaled
# indicators directly to the HMM; checks that PCA/PLS compression does not discard
# critical regime signal.
#
# The PCA vs PLS comparison is presented in the main results section (HMM_PLS_WF vs
# HMM_PCA_WF), not here.

# %% [markdown]
# ### 1. VIF analysis
#
# Variance Inflation Factor measures how much each indicator's variance is inflated
# by collinearity with the others. VIF > 10 indicates severe multicollinearity.
# This documents which indicators are redundant and whether dimensionality reduction
# is warranted. All VIF values below 5 here — multicollinearity is present but not
# severe; reduction is precautionary rather than a hard requirement.

# %%
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LinearRegression

# Robust-scale macro data on the full training window (same as WF engine)
train_cutoff = macro_df.index[346]   # initial_train_months = 346
macro_train  = macro_df.loc[macro_df.index <= train_cutoff]
scaler_vif   = RobustScaler(quantile_range=(5, 95))
X_vif        = scaler_vif.fit_transform(macro_train.values)
feature_names = macro_train.columns.tolist()

# Compute VIF for each indicator:
# VIF_j = 1 / (1 - R²_j) where R²_j is from regressing indicator j
# on all other indicators.
vif_scores = {}
for j, name in enumerate(feature_names):
    X_other = np.delete(X_vif, j, axis=1)
    y_j     = X_vif[:, j]
    reg     = LinearRegression().fit(X_other, y_j)
    r2      = reg.score(X_other, y_j)
    vif_scores[name] = 1 / (1 - r2) if r2 < 1.0 else np.inf

vif_df = pd.Series(vif_scores, name='VIF').sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(10, 5))
colors  = ['#d62728' if v > 10 else '#e07b00' if v > 5 else '#1a6faf'
           for v in vif_df.values]
ax.barh(vif_df.index, vif_df.values, color=colors)
ax.axvline(10, color='#d62728', ls='--', lw=1.5, label='VIF = 10 (severe)')
ax.axvline(5,  color='#e07b00', ls='--', lw=1.5, label='VIF = 5 (moderate)')
ax.set_title('Variance Inflation Factor — Macro Indicators\n'
             '(training window to Dec 2018)', fontweight='bold')
ax.set_xlabel('VIF')
ax.legend(fontsize=9)
ax.spines[['top','right']].set_visible(False)
plt.tight_layout()
plt.savefig(OUTPUT_FIGURES_DIR / 'vif_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

print('VIF scores:')
print(vif_df.round(2).to_string())
print(f'\nIndicators with VIF > 10 (severe collinearity): '
      f'{vif_df[vif_df > 10].index.tolist()}')
print(f'Indicators with VIF > 5  (moderate):              '
      f'{vif_df[(vif_df > 5) & (vif_df <= 10)].index.tolist()}')
# Out:
# VIF scores:
# credit_spread             3.55
# vix                       2.12
# continuing_claims         1.80
# yield_curve_slope         1.79
# industrial_production     1.63
# fed_funds_rate            1.37
# m2_money_supply           1.37
# cpi                       1.34
# unemployment_rate         1.33
# initial_jobless_claims    1.30
# oil_price                 1.24
# real_person_income        1.23
# consumer_sentiment        1.17
# dollar_index              1.15
# housing_starts            1.09
#
# Indicators with VIF > 10 (severe collinearity): []
# Indicators with VIF > 5  (moderate):              []

# %% [markdown]
# ### 2. HMM walk-forward without dimensionality reduction
#
# Feeds all 15 raw robust-scaled indicators directly to the HMM, bypassing PCA and PLS.
# If regime detection quality is similar to the PCA/PLS versions, it confirms that
# dimensionality reduction is not discarding critical regime signal. MSVAR is excluded
# because 15 variables makes it computationally prohibitive (≈630 free parameters vs
# ≈346 training observations).
#
# `covariance_type='diag'` is used: with 15 variables, full covariance requires 120
# parameters per regime from ~20 recession observations — guaranteed to degenerate.

# %%
# HMM without dimensionality reduction: use 'diag' covariance to avoid degeneracy
hmm_no_red_returns, hmm_no_red_states, hmm_no_red_probs, hmm_no_red_filt = \
    walk_forward_backtest(
        macro_df             = macro_df,
        asset_df             = asset_df,
        model_type           = 'hmm',
        initial_train_months = INITIAL_TRAIN_MONTHS,
        refit_every          = 12,
        dim_reduction        = 'none',      # key change: no reduction
        winsor_clip          = 4.0,
        transaction_cost_bps = 10,
        objective            = 'min_variance',
        rf                   = 0.0,
        long_only            = True,
        hmm_kwargs           = dict(
            n_states=2, n_iter=200, n_restarts=10,
            tol=1e-4, covariance_type='diag',  # diag essential with 15 vars
            constrain_transmat=True,
        ),
        verbose              = True,
    )
# Out:
# Walk-forward backtest: HMM, 431 months total, initial window=346, refit every=12
#   Refitting at 2018-12-31 (t=346, window=346 months)...
#     No dim reduction: feeding 15 raw indicators
# Best log-likelihood (per sample): -1267.2701
# Sort method: 'trace'
# Transition matrix:
# [[0.95071452 0.04928548]
#  [0.18808476 0.81191524]]
# State durations (months): ['20.3', '5.3']
# State 0 = Expansion  (tr(Σ)=1.3208  PC1_mean=0.046)
# State 1 = Recession  (tr(Σ)=3.0517  PC1_mean=-0.339)
#
# ── Regime 0  (275 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.01%  →  BS +13.01%
#     treasury_fund   : sample +4.58%  →  BS +5.88%
#     gold_fund       : sample +2.95%  →  BS +3.79%
#   Bayes-Stein φ  : 0.4394  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3155
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.99%
#     treasury_fund   : 9.57%
#     gold_fund       : 11.40%
#
# ── Regime 1  (71 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.25%  →  BS -0.62%
#     treasury_fund   : sample +18.99%  →  BS +14.70%
#     gold_fund       : sample +12.27%  →  BS +9.49%
#   Bayes-Stein φ  : 0.3743  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2448
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.70%
#     treasury_fund   : 13.79%
#     gold_fund       : 15.77%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.70%
#   Volatility     (ann.) : 6.20%
#   Sharpe ratio          : 1.2417
#   Weights:
#     index_fund    : 0.3367  (33.7%)
#     treasury_fund : 0.3875  (38.7%)
#     gold_fund     : 0.2758  (27.6%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.49%
#   Volatility     (ann.) : 6.88%
#   Sharpe ratio          : 1.3782
#   Weights:
#     index_fund    : 0.5485  (54.8%)
#     treasury_fund : 0.3085  (30.8%)
#     gold_fund     : 0.1430  (14.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.36%
#   Volatility     (ann.) : 8.94%
#   Sharpe ratio          : 1.0475
#   Weights:
#     index_fund    : 0.2385  (23.9%)
#     treasury_fund : 0.4376  (43.8%)
#     gold_fund     : 0.3238  (32.4%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.33%
#   Volatility     (ann.) : 10.26%
#   Sharpe ratio          : 1.2022
#   Weights:
#     index_fund    : 0.0536  (5.4%)
#     treasury_fund : 0.6484  (64.8%)
#     gold_fund     : 0.2980  (29.8%)
#
# ── Regime 0  (276 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.54%  →  BS +12.50%
#     treasury_fund   : sample +4.80%  →  BS +6.13%
#     gold_fund       : sample +3.03%  →  BS +3.90%
#   Bayes-Stein φ  : 0.4581  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3123
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.15%
#     treasury_fund   : 9.63%
#     gold_fund       : 11.42%
#
# ── Regime 1  (71 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.25%  →  BS -0.62%
#     treasury_fund   : sample +18.99%  →  BS +14.68%
#     gold_fund       : sample +12.27%  →  BS +9.46%
#   Bayes-Stein φ  : 0.3821  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2448
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.70%
#     treasury_fund   : 13.79%
#     gold_fund       : 15.77%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.64%
#   Volatility     (ann.) : 6.21%
#   Sharpe ratio          : 1.2306
#   Weights:
#     index_fund    : 0.3342  (33.4%)
#     treasury_fund : 0.3894  (38.9%)
#     gold_fund     : 0.2763  (27.6%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.13%
#   Volatility     (ann.) : 6.79%
#   Sharpe ratio          : 1.3452
#   Weights:
#     index_fund    : 0.5228  (52.3%)
#     treasury_fund : 0.3303  (33.0%)
#     gold_fund     : 0.1469  (14.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.34%
#   Volatility     (ann.) : 8.94%
#   Sharpe ratio          : 1.0451
#   Weights:
#     index_fund    : 0.2385  (23.9%)
#     treasury_fund : 0.4376  (43.8%)
#     gold_fund     : 0.3238  (32.4%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.31%
#   Volatility     (ann.) : 10.26%
#   Sharpe ratio          : 1.1997
#   Weights:
#     index_fund    : 0.0536  (5.4%)
#     treasury_fund : 0.6488  (64.9%)
#     gold_fund     : 0.2976  (29.8%)
#
# ── Regime 0  (277 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.86%  →  BS +12.81%
#     treasury_fund   : sample +4.81%  →  BS +6.13%
#     gold_fund       : sample +3.18%  →  BS +4.02%
#   Bayes-Stein φ  : 0.4561  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3093
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.22%
#     treasury_fund   : 9.62%
#     gold_fund       : 11.42%
#
# ── Regime 1  (71 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.25%  →  BS -0.57%
#     treasury_fund   : sample +18.99%  →  BS +14.71%
#     gold_fund       : sample +12.27%  →  BS +9.52%
#   Bayes-Stein φ  : 0.3796  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2448
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.70%
#     treasury_fund   : 13.79%
#     gold_fund       : 15.77%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.76%
#   Volatility     (ann.) : 6.24%
#   Sharpe ratio          : 1.2440
#   Weights:
#     index_fund    : 0.3311  (33.1%)
#     treasury_fund : 0.3931  (39.3%)
#     gold_fund     : 0.2758  (27.6%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.32%
#   Volatility     (ann.) : 6.83%
#   Sharpe ratio          : 1.3634
#   Weights:
#     index_fund    : 0.5243  (52.4%)
#     treasury_fund : 0.3279  (32.8%)
#     gold_fund     : 0.1477  (14.8%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.38%
#   Volatility     (ann.) : 8.94%
#   Sharpe ratio          : 1.0500
#   Weights:
#     index_fund    : 0.2385  (23.9%)
#     treasury_fund : 0.4376  (43.8%)
#     gold_fund     : 0.3238  (32.4%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.32%
#   Volatility     (ann.) : 10.24%
#   Sharpe ratio          : 1.2033
#   Weights:
#     index_fund    : 0.0547  (5.5%)
#     treasury_fund : 0.6470  (64.7%)
#     gold_fund     : 0.2983  (29.8%)
#
# ── Regime 0  (278 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.95%  →  BS +12.90%
#     treasury_fund   : sample +4.73%  →  BS +6.05%
#     gold_fund       : sample +3.26%  →  BS +4.09%
#   Bayes-Stein φ  : 0.4544  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3105
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.21%
#     treasury_fund   : 9.61%
#     gold_fund       : 11.41%
#
# ── Regime 1  (71 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.25%  →  BS -0.57%
#     treasury_fund   : sample +18.99%  →  BS +14.70%
#     gold_fund       : sample +12.27%  →  BS +9.55%
#   Bayes-Stein φ  : 0.3779  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2448
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.70%
#     treasury_fund   : 13.79%
#     gold_fund       : 15.77%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.78%
#   Volatility     (ann.) : 6.23%
#   Sharpe ratio          : 1.2489
#   Weights:
#     index_fund    : 0.3309  (33.1%)
#     treasury_fund : 0.3933  (39.3%)
#     gold_fund     : 0.2758  (27.6%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.36%
#   Volatility     (ann.) : 6.83%
#   Sharpe ratio          : 1.3702
#   Weights:
#     index_fund    : 0.5265  (52.7%)
#     treasury_fund : 0.3231  (32.3%)
#     gold_fund     : 0.1504  (15.0%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.39%
#   Volatility     (ann.) : 8.94%
#   Sharpe ratio          : 1.0510
#   Weights:
#     index_fund    : 0.2385  (23.9%)
#     treasury_fund : 0.4376  (43.8%)
#     gold_fund     : 0.3238  (32.4%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.32%
#   Volatility     (ann.) : 10.24%
#   Sharpe ratio          : 1.2040
#   Weights:
#     index_fund    : 0.0547  (5.5%)
#     treasury_fund : 0.6460  (64.6%)
#     gold_fund     : 0.2992  (29.9%)
#
# ── Regime 0  (279 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.95%  →  BS +12.90%
#     treasury_fund   : sample +4.95%  →  BS +6.25%
#     gold_fund       : sample +3.18%  →  BS +4.03%
#   Bayes-Stein φ  : 0.4566  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3230
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.19%
#     treasury_fund   : 9.66%
#     gold_fund       : 11.39%
#
# ── Regime 1  (71 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.25%  →  BS -0.52%
#     treasury_fund   : sample +18.99%  →  BS +14.74%
#     gold_fund       : sample +12.27%  →  BS +9.51%
#   Bayes-Stein φ  : 0.3801  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2448
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.70%
#     treasury_fund   : 13.79%
#     gold_fund       : 15.77%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.84%
#   Volatility     (ann.) : 6.23%
#   Sharpe ratio          : 1.2587
#   Weights:
#     index_fund    : 0.3316  (33.2%)
#     treasury_fund : 0.3900  (39.0%)
#     gold_fund     : 0.2783  (27.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.41%
#   Volatility     (ann.) : 6.82%
#   Sharpe ratio          : 1.3791
#   Weights:
#     index_fund    : 0.5242  (52.4%)
#     treasury_fund : 0.3284  (32.8%)
#     gold_fund     : 0.1474  (14.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.41%
#   Volatility     (ann.) : 8.94%
#   Sharpe ratio          : 1.0527
#   Weights:
#     index_fund    : 0.2385  (23.9%)
#     treasury_fund : 0.4376  (43.8%)
#     gold_fund     : 0.3238  (32.4%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.34%
#   Volatility     (ann.) : 10.23%
#   Sharpe ratio          : 1.2055
#   Weights:
#     index_fund    : 0.0556  (5.6%)
#     treasury_fund : 0.6470  (64.7%)
#     gold_fund     : 0.2974  (29.7%)
#
# ── Regime 0  (280 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.10%  →  BS +13.04%
#     treasury_fund   : sample +4.85%  →  BS +6.15%
#     gold_fund       : sample +3.13%  →  BS +3.97%
#   Bayes-Stein φ  : 0.4542  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3203
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.19%
#     treasury_fund   : 9.65%
#     gold_fund       : 11.38%
#
# ── Regime 1  (71 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.25%  →  BS -0.53%
#     treasury_fund   : sample +18.99%  →  BS +14.74%
#     gold_fund       : sample +12.27%  →  BS +9.52%
#   Bayes-Stein φ  : 0.3766  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2448
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.70%
#     treasury_fund   : 13.79%
#     gold_fund       : 15.77%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.83%
#   Volatility     (ann.) : 6.22%
#   Sharpe ratio          : 1.2596
#   Weights:
#     index_fund    : 0.3317  (33.2%)
#     treasury_fund : 0.3902  (39.0%)
#     gold_fund     : 0.2781  (27.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.48%
#   Volatility     (ann.) : 6.84%
#   Sharpe ratio          : 1.3861
#   Weights:
#     index_fund    : 0.5295  (52.9%)
#     treasury_fund : 0.3246  (32.5%)
#     gold_fund     : 0.1460  (14.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.41%
#   Volatility     (ann.) : 8.94%
#   Sharpe ratio          : 1.0528
#   Weights:
#     index_fund    : 0.2385  (23.9%)
#     treasury_fund : 0.4376  (43.8%)
#     gold_fund     : 0.3238  (32.4%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.34%
#   Volatility     (ann.) : 10.24%
#   Sharpe ratio          : 1.2059
#   Weights:
#     index_fund    : 0.0553  (5.5%)
#     treasury_fund : 0.6471  (64.7%)
#     gold_fund     : 0.2975  (29.8%)
#
# ── Regime 0  (281 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.77%  →  BS +12.70%
#     treasury_fund   : sample +5.12%  →  BS +6.43%
#     gold_fund       : sample +3.11%  →  BS +3.97%
#   Bayes-Stein φ  : 0.4672  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3274
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.26%
#     treasury_fund   : 9.73%
#     gold_fund       : 11.37%
#
# ── Regime 1  (71 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.25%  →  BS -0.51%
#     treasury_fund   : sample +18.99%  →  BS +14.75%
#     gold_fund       : sample +12.27%  →  BS +9.46%
#   Bayes-Stein φ  : 0.3831  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2448
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.70%
#     treasury_fund   : 13.79%
#     gold_fund       : 15.77%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.82%
#   Volatility     (ann.) : 6.22%
#   Sharpe ratio          : 1.2575
#   Weights:
#     index_fund    : 0.3315  (33.2%)
#     treasury_fund : 0.3896  (39.0%)
#     gold_fund     : 0.2789  (27.9%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.29%
#   Volatility     (ann.) : 6.78%
#   Sharpe ratio          : 1.3710
#   Weights:
#     index_fund    : 0.5140  (51.4%)
#     treasury_fund : 0.3418  (34.2%)
#     gold_fund     : 0.1442  (14.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.40%
#   Volatility     (ann.) : 8.94%
#   Sharpe ratio          : 1.0516
#   Weights:
#     index_fund    : 0.2385  (23.9%)
#     treasury_fund : 0.4376  (43.8%)
#     gold_fund     : 0.3238  (32.4%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.33%
#   Volatility     (ann.) : 10.24%
#   Sharpe ratio          : 1.2048
#   Weights:
#     index_fund    : 0.0557  (5.6%)
#     treasury_fund : 0.6483  (64.8%)
#     gold_fund     : 0.2960  (29.6%)
#
# ── Regime 0  (282 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.00%  →  BS +12.91%
#     treasury_fund   : sample +5.14%  →  BS +6.44%
#     gold_fund       : sample +3.34%  →  BS +4.18%
#   Bayes-Stein φ  : 0.4660  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3225
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.29%
#     treasury_fund   : 9.72%
#     gold_fund       : 11.41%
#
# ── Regime 1  (71 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.25%  →  BS -0.45%
#     treasury_fund   : sample +18.99%  →  BS +14.76%
#     gold_fund       : sample +12.27%  →  BS +9.54%
#   Bayes-Stein φ  : 0.3824  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2448
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.70%
#     treasury_fund   : 13.79%
#     gold_fund       : 15.77%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.95%
#   Volatility     (ann.) : 6.24%
#   Sharpe ratio          : 1.2738
#   Weights:
#     index_fund    : 0.3301  (33.0%)
#     treasury_fund : 0.3933  (39.3%)
#     gold_fund     : 0.2766  (27.7%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.44%
#   Volatility     (ann.) : 6.80%
#   Sharpe ratio          : 1.3875
#   Weights:
#     index_fund    : 0.5140  (51.4%)
#     treasury_fund : 0.3395  (34.0%)
#     gold_fund     : 0.1465  (14.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.44%
#   Volatility     (ann.) : 8.94%
#   Sharpe ratio          : 1.0566
#   Weights:
#     index_fund    : 0.2385  (23.9%)
#     treasury_fund : 0.4376  (43.8%)
#     gold_fund     : 0.3238  (32.4%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.34%
#   Volatility     (ann.) : 10.22%
#   Sharpe ratio          : 1.2082
#   Weights:
#     index_fund    : 0.0569  (5.7%)
#     treasury_fund : 0.6458  (64.6%)
#     gold_fund     : 0.2973  (29.7%)
#
# ── Regime 0  (283 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.02%  →  BS +12.94%
#     treasury_fund   : sample +5.14%  →  BS +6.43%
#     gold_fund       : sample +3.50%  →  BS +4.32%
#   Bayes-Stein φ  : 0.4660  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3202
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.27%
#     treasury_fund   : 9.70%
#     gold_fund       : 11.41%
#
# ── Regime 1  (71 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.25%  →  BS -0.43%
#     treasury_fund   : sample +18.99%  →  BS +14.75%
#     gold_fund       : sample +12.27%  →  BS +9.59%
#   Bayes-Stein φ  : 0.3826  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2448
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.70%
#     treasury_fund   : 13.79%
#     gold_fund       : 15.77%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.00%
#   Volatility     (ann.) : 6.24%
#   Sharpe ratio          : 1.2826
#   Weights:
#     index_fund    : 0.3302  (33.0%)
#     treasury_fund : 0.3940  (39.4%)
#     gold_fund     : 0.2758  (27.6%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.45%
#   Volatility     (ann.) : 6.78%
#   Sharpe ratio          : 1.3942
#   Weights:
#     index_fund    : 0.5126  (51.3%)
#     treasury_fund : 0.3370  (33.7%)
#     gold_fund     : 0.1504  (15.0%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.46%
#   Volatility     (ann.) : 8.94%
#   Sharpe ratio          : 1.0583
#   Weights:
#     index_fund    : 0.2385  (23.9%)
#     treasury_fund : 0.4376  (43.8%)
#     gold_fund     : 0.3238  (32.4%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.34%
#   Volatility     (ann.) : 10.21%
#   Sharpe ratio          : 1.2090
#   Weights:
#     index_fund    : 0.0572  (5.7%)
#     treasury_fund : 0.6444  (64.4%)
#     gold_fund     : 0.2984  (29.8%)
#
# ── Regime 0  (284 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.90%  →  BS +12.78%
#     treasury_fund   : sample +5.57%  →  BS +6.86%
#     gold_fund       : sample +3.74%  →  BS +4.56%
#   Bayes-Stein φ  : 0.4793  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3315
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.28%
#     treasury_fund   : 9.89%
#     gold_fund       : 11.45%
#
# ── Regime 1  (71 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.25%  →  BS -0.32%
#     treasury_fund   : sample +18.99%  →  BS +14.79%
#     gold_fund       : sample +12.27%  →  BS +9.60%
#   Bayes-Stein φ  : 0.3911  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2448
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.70%
#     treasury_fund   : 13.79%
#     gold_fund       : 15.77%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.22%
#   Volatility     (ann.) : 6.29%
#   Sharpe ratio          : 1.3064
#   Weights:
#     index_fund    : 0.3378  (33.8%)
#     treasury_fund : 0.3851  (38.5%)
#     gold_fund     : 0.2771  (27.7%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.49%
#   Volatility     (ann.) : 6.76%
#   Sharpe ratio          : 1.4033
#   Weights:
#     index_fund    : 0.5035  (50.3%)
#     treasury_fund : 0.3430  (34.3%)
#     gold_fund     : 0.1535  (15.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.51%
#   Volatility     (ann.) : 8.94%
#   Sharpe ratio          : 1.0639
#   Weights:
#     index_fund    : 0.2385  (23.9%)
#     treasury_fund : 0.4376  (43.8%)
#     gold_fund     : 0.3238  (32.4%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.35%
#   Volatility     (ann.) : 10.19%
#   Sharpe ratio          : 1.2126
#   Weights:
#     index_fund    : 0.0594  (5.9%)
#     treasury_fund : 0.6431  (64.3%)
#     gold_fund     : 0.2975  (29.7%)
#
# ── Regime 0  (285 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.91%  →  BS +12.80%
#     treasury_fund   : sample +5.44%  →  BS +6.73%
#     gold_fund       : sample +3.77%  →  BS +4.58%
#   Bayes-Stein φ  : 0.4777  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3357
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.26%
#     treasury_fund   : 9.89%
#     gold_fund       : 11.43%
#
# ── Regime 1  (71 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.25%  →  BS -0.35%
#     treasury_fund   : sample +18.99%  →  BS +14.77%
#     gold_fund       : sample +12.27%  →  BS +9.62%
#   Bayes-Stein φ  : 0.3890  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2448
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.70%
#     treasury_fund   : 13.79%
#     gold_fund       : 15.77%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.18%
#   Volatility     (ann.) : 6.29%
#   Sharpe ratio          : 1.3019
#   Weights:
#     index_fund    : 0.3381  (33.8%)
#     treasury_fund : 0.3841  (38.4%)
#     gold_fund     : 0.2779  (27.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.47%
#   Volatility     (ann.) : 6.76%
#   Sharpe ratio          : 1.4005
#   Weights:
#     index_fund    : 0.5069  (50.7%)
#     treasury_fund : 0.3372  (33.7%)
#     gold_fund     : 0.1559  (15.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.50%
#   Volatility     (ann.) : 8.94%
#   Sharpe ratio          : 1.0628
#   Weights:
#     index_fund    : 0.2385  (23.9%)
#     treasury_fund : 0.4376  (43.8%)
#     gold_fund     : 0.3238  (32.4%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.34%
#   Volatility     (ann.) : 10.19%
#   Sharpe ratio          : 1.2117
#   Weights:
#     index_fund    : 0.0588  (5.9%)
#     treasury_fund : 0.6427  (64.3%)
#     gold_fund     : 0.2984  (29.8%)
#
# ── Regime 0  (286 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.97%  →  BS +12.87%
#     treasury_fund   : sample +5.37%  →  BS +6.66%
#     gold_fund       : sample +3.71%  →  BS +4.52%
#   Bayes-Stein φ  : 0.4759  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3344
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.25%
#     treasury_fund   : 9.88%
#     gold_fund       : 11.41%
#
# ── Regime 1  (71 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.25%  →  BS -0.36%
#     treasury_fund   : sample +18.99%  →  BS +14.77%
#     gold_fund       : sample +12.27%  →  BS +9.61%
#   Bayes-Stein φ  : 0.3868  (mild shrinkage)
#   Ledoit-Wolf α  : 0.2448
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 20.70%
#     treasury_fund   : 13.79%
#     gold_fund       : 15.77%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.17%
#   Volatility     (ann.) : 6.28%
#   Sharpe ratio          : 1.3010
#   Weights:
#     index_fund    : 0.3383  (33.8%)
#     treasury_fund : 0.3840  (38.4%)
#     gold_fund     : 0.2777  (27.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.50%
#   Volatility     (ann.) : 6.77%
#   Sharpe ratio          : 1.4031
#   Weights:
#     index_fund    : 0.5104  (51.0%)
#     treasury_fund : 0.3352  (33.5%)
#     gold_fund     : 0.1544  (15.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.49%
#   Volatility     (ann.) : 8.94%
#   Sharpe ratio          : 1.0622
#   Weights:
#     index_fund    : 0.2385  (23.9%)
#     treasury_fund : 0.4376  (43.8%)
#     gold_fund     : 0.3238  (32.4%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.35%
#   Volatility     (ann.) : 10.19%
#   Sharpe ratio          : 1.2115
#   Weights:
#     index_fund    : 0.0585  (5.9%)
#     treasury_fund : 0.6431  (64.3%)
#     gold_fund     : 0.2984  (29.8%)
#   Refitting at 2019-12-31 (t=358, window=358 months)...
#     No dim reduction: feeding 15 raw indicators
# Best log-likelihood (per sample): -1325.5394
# Sort method: 'trace'
# Transition matrix:
# [[0.95165066 0.04834934]
#  [0.18946835 0.81053165]]
# State durations (months): ['20.7', '5.3']
# State 0 = Expansion  (tr(Σ)=1.3230  PC1_mean=0.043)
# State 1 = Recession  (tr(Σ)=3.0815  PC1_mean=-0.313)
#
# ── Regime 0  (285 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.28%  →  BS +13.26%
#     treasury_fund   : sample +5.17%  →  BS +6.42%
#     gold_fund       : sample +3.72%  →  BS +4.42%
#   Bayes-Stein φ  : 0.4341  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3904
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.88%
#     treasury_fund   : 9.83%
#     gold_fund       : 11.24%
#
# ── Regime 1  (73 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.45%  →  BS -0.31%
#     treasury_fund   : sample +19.28%  →  BS +14.85%
#     gold_fund       : sample +11.68%  →  BS +9.18%
#   Bayes-Stein φ  : 0.3947  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1978
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.41%
#     treasury_fund   : 13.71%
#     gold_fund       : 15.86%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.18%
#   Volatility     (ann.) : 6.24%
#   Sharpe ratio          : 1.3112
#   Weights:
#     index_fund    : 0.3400  (34.0%)
#     treasury_fund : 0.3790  (37.9%)
#     gold_fund     : 0.2811  (28.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.82%
#   Volatility     (ann.) : 6.84%
#   Sharpe ratio          : 1.4366
#   Weights:
#     index_fund    : 0.5407  (54.1%)
#     treasury_fund : 0.3111  (31.1%)
#     gold_fund     : 0.1482  (14.8%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.36%
#   Volatility     (ann.) : 8.83%
#   Sharpe ratio          : 1.0604
#   Weights:
#     index_fund    : 0.2432  (24.3%)
#     treasury_fund : 0.4396  (44.0%)
#     gold_fund     : 0.3172  (31.7%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.07%
#   Volatility     (ann.) : 10.02%
#   Sharpe ratio          : 1.2039
#   Weights:
#     index_fund    : 0.0835  (8.3%)
#     treasury_fund : 0.6496  (65.0%)
#     gold_fund     : 0.2669  (26.7%)
#
# ── Regime 0  (286 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.33%  →  BS +13.33%
#     treasury_fund   : sample +5.02%  →  BS +6.27%
#     gold_fund       : sample +3.72%  →  BS +4.42%
#   Bayes-Stein φ  : 0.4321  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3967
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.87%
#     treasury_fund   : 9.84%
#     gold_fund       : 11.22%
#
# ── Regime 1  (73 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.45%  →  BS -0.34%
#     treasury_fund   : sample +19.28%  →  BS +14.83%
#     gold_fund       : sample +11.68%  →  BS +9.20%
#   Bayes-Stein φ  : 0.3915  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1978
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.41%
#     treasury_fund   : 13.71%
#     gold_fund       : 15.86%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.15%
#   Volatility     (ann.) : 6.23%
#   Sharpe ratio          : 1.3071
#   Weights:
#     index_fund    : 0.3404  (34.0%)
#     treasury_fund : 0.3776  (37.8%)
#     gold_fund     : 0.2820  (28.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.85%
#   Volatility     (ann.) : 6.85%
#   Sharpe ratio          : 1.4367
#   Weights:
#     index_fund    : 0.5460  (54.6%)
#     treasury_fund : 0.3040  (30.4%)
#     gold_fund     : 0.1500  (15.0%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.35%
#   Volatility     (ann.) : 8.83%
#   Sharpe ratio          : 1.0593
#   Weights:
#     index_fund    : 0.2432  (24.3%)
#     treasury_fund : 0.4396  (44.0%)
#     gold_fund     : 0.3172  (31.7%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.06%
#   Volatility     (ann.) : 10.03%
#   Sharpe ratio          : 1.2031
#   Weights:
#     index_fund    : 0.0828  (8.3%)
#     treasury_fund : 0.6494  (64.9%)
#     gold_fund     : 0.2678  (26.8%)
#
# ── Regime 0  (287 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.29%  →  BS +13.27%
#     treasury_fund   : sample +5.32%  →  BS +6.56%
#     gold_fund       : sample +3.95%  →  BS +4.63%
#   Bayes-Stein φ  : 0.4389  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3888
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.87%
#     treasury_fund   : 9.90%
#     gold_fund       : 11.26%
#
# ── Regime 1  (73 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.45%  →  BS -0.25%
#     treasury_fund   : sample +19.28%  →  BS +14.86%
#     gold_fund       : sample +11.68%  →  BS +9.23%
#   Bayes-Stein φ  : 0.3971  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1978
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.41%
#     treasury_fund   : 13.71%
#     gold_fund       : 15.86%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.33%
#   Volatility     (ann.) : 6.27%
#   Sharpe ratio          : 1.3289
#   Weights:
#     index_fund    : 0.3444  (34.4%)
#     treasury_fund : 0.3750  (37.5%)
#     gold_fund     : 0.2806  (28.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.87%
#   Volatility     (ann.) : 6.82%
#   Sharpe ratio          : 1.4469
#   Weights:
#     index_fund    : 0.5379  (53.8%)
#     treasury_fund : 0.3097  (31.0%)
#     gold_fund     : 0.1524  (15.2%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.40%
#   Volatility     (ann.) : 8.83%
#   Sharpe ratio          : 1.0646
#   Weights:
#     index_fund    : 0.2432  (24.3%)
#     treasury_fund : 0.4396  (44.0%)
#     gold_fund     : 0.3172  (31.7%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.08%
#   Volatility     (ann.) : 10.01%
#   Sharpe ratio          : 1.2066
#   Weights:
#     index_fund    : 0.0844  (8.4%)
#     treasury_fund : 0.6477  (64.8%)
#     gold_fund     : 0.2678  (26.8%)
#
# ── Regime 0  (288 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.90%  →  BS +12.84%
#     treasury_fund   : sample +5.57%  →  BS +6.84%
#     gold_fund       : sample +4.03%  →  BS +4.74%
#   Bayes-Stein φ  : 0.4557  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3866
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 10.99%
#     treasury_fund   : 9.97%
#     gold_fund       : 11.28%
#
# ── Regime 1  (73 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.45%  →  BS -0.22%
#     treasury_fund   : sample +19.28%  →  BS +14.85%
#     gold_fund       : sample +11.68%  →  BS +9.21%
#   Bayes-Stein φ  : 0.4052  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1978
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.41%
#     treasury_fund   : 13.71%
#     gold_fund       : 15.86%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.31%
#   Volatility     (ann.) : 6.28%
#   Sharpe ratio          : 1.3236
#   Weights:
#     index_fund    : 0.3436  (34.4%)
#     treasury_fund : 0.3755  (37.5%)
#     gold_fund     : 0.2809  (28.1%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.61%
#   Volatility     (ann.) : 6.75%
#   Sharpe ratio          : 1.4237
#   Weights:
#     index_fund    : 0.5172  (51.7%)
#     treasury_fund : 0.3270  (32.7%)
#     gold_fund     : 0.1558  (15.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.39%
#   Volatility     (ann.) : 8.83%
#   Sharpe ratio          : 1.0639
#   Weights:
#     index_fund    : 0.2432  (24.3%)
#     treasury_fund : 0.4396  (44.0%)
#     gold_fund     : 0.3172  (31.7%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.06%
#   Volatility     (ann.) : 10.01%
#   Sharpe ratio          : 1.2055
#   Weights:
#     index_fund    : 0.0848  (8.5%)
#     treasury_fund : 0.6479  (64.8%)
#     gold_fund     : 0.2673  (26.7%)
#
# ── Regime 0  (289 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.31%  →  BS +12.22%
#     treasury_fund   : sample +5.75%  →  BS +7.05%
#     gold_fund       : sample +4.00%  →  BS +4.74%
#   Bayes-Stein φ  : 0.4773  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3853
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.25%
#     treasury_fund   : 10.03%
#     gold_fund       : 11.31%
#
# ── Regime 1  (73 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.45%  →  BS -0.26%
#     treasury_fund   : sample +19.28%  →  BS +14.81%
#     gold_fund       : sample +11.68%  →  BS +9.14%
#   Bayes-Stein φ  : 0.4137  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1978
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.41%
#     treasury_fund   : 13.71%
#     gold_fund       : 15.86%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.14%
#   Volatility     (ann.) : 6.32%
#   Sharpe ratio          : 1.2882
#   Weights:
#     index_fund    : 0.3366  (33.7%)
#     treasury_fund : 0.3811  (38.1%)
#     gold_fund     : 0.2824  (28.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.23%
#   Volatility     (ann.) : 6.73%
#   Sharpe ratio          : 1.3715
#   Weights:
#     index_fund    : 0.4912  (49.1%)
#     treasury_fund : 0.3511  (35.1%)
#     gold_fund     : 0.1577  (15.8%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.35%
#   Volatility     (ann.) : 8.83%
#   Sharpe ratio          : 1.0588
#   Weights:
#     index_fund    : 0.2432  (24.3%)
#     treasury_fund : 0.4396  (44.0%)
#     gold_fund     : 0.3172  (31.7%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.03%
#   Volatility     (ann.) : 10.02%
#   Sharpe ratio          : 1.2012
#   Weights:
#     index_fund    : 0.0842  (8.4%)
#     treasury_fund : 0.6493  (64.9%)
#     gold_fund     : 0.2664  (26.6%)
#
# ── Regime 0  (290 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.81%  →  BS +12.68%
#     treasury_fund   : sample +5.84%  →  BS +7.13%
#     gold_fund       : sample +4.23%  →  BS +4.94%
#   Bayes-Stein φ  : 0.4761  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3761
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.44%
#     treasury_fund   : 10.05%
#     gold_fund       : 11.37%
#
# ── Regime 1  (73 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.45%  →  BS -0.14%
#     treasury_fund   : sample +19.28%  →  BS +14.87%
#     gold_fund       : sample +11.68%  →  BS +9.23%
#   Bayes-Stein φ  : 0.4106  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1978
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.41%
#     treasury_fund   : 13.71%
#     gold_fund       : 15.86%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.34%
#   Volatility     (ann.) : 6.41%
#   Sharpe ratio          : 1.3003
#   Weights:
#     index_fund    : 0.3296  (33.0%)
#     treasury_fund : 0.3878  (38.8%)
#     gold_fund     : 0.2826  (28.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.51%
#   Volatility     (ann.) : 6.85%
#   Sharpe ratio          : 1.3887
#   Weights:
#     index_fund    : 0.4913  (49.1%)
#     treasury_fund : 0.3516  (35.2%)
#     gold_fund     : 0.1571  (15.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.43%
#   Volatility     (ann.) : 8.83%
#   Sharpe ratio          : 1.0683
#   Weights:
#     index_fund    : 0.2432  (24.3%)
#     treasury_fund : 0.4396  (44.0%)
#     gold_fund     : 0.3172  (31.7%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.07%
#   Volatility     (ann.) : 9.99%
#   Sharpe ratio          : 1.2085
#   Weights:
#     index_fund    : 0.0861  (8.6%)
#     treasury_fund : 0.6466  (64.7%)
#     gold_fund     : 0.2673  (26.7%)
#
# ── Regime 0  (291 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.96%  →  BS +12.83%
#     treasury_fund   : sample +5.75%  →  BS +7.04%
#     gold_fund       : sample +4.29%  →  BS +4.99%
#   Bayes-Stein φ  : 0.4739  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3754
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.44%
#     treasury_fund   : 10.05%
#     gold_fund       : 11.36%
#
# ── Regime 1  (73 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.45%  →  BS -0.15%
#     treasury_fund   : sample +19.28%  →  BS +14.87%
#     gold_fund       : sample +11.68%  →  BS +9.27%
#   Bayes-Stein φ  : 0.4076  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1978
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.41%
#     treasury_fund   : 13.71%
#     gold_fund       : 15.86%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.37%
#   Volatility     (ann.) : 6.41%
#   Sharpe ratio          : 1.3060
#   Weights:
#     index_fund    : 0.3292  (32.9%)
#     treasury_fund : 0.3885  (38.8%)
#     gold_fund     : 0.2824  (28.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.58%
#   Volatility     (ann.) : 6.86%
#   Sharpe ratio          : 1.3972
#   Weights:
#     index_fund    : 0.4944  (49.4%)
#     treasury_fund : 0.3469  (34.7%)
#     gold_fund     : 0.1587  (15.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.44%
#   Volatility     (ann.) : 8.83%
#   Sharpe ratio          : 1.0696
#   Weights:
#     index_fund    : 0.2432  (24.3%)
#     treasury_fund : 0.4396  (44.0%)
#     gold_fund     : 0.3172  (31.7%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.08%
#   Volatility     (ann.) : 9.98%
#   Sharpe ratio          : 1.2095
#   Weights:
#     index_fund    : 0.0861  (8.6%)
#     treasury_fund : 0.6457  (64.6%)
#     gold_fund     : 0.2682  (26.8%)
#
# ── Regime 0  (292 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +14.97%  →  BS +12.85%
#     treasury_fund   : sample +5.75%  →  BS +7.03%
#     gold_fund       : sample +4.32%  →  BS +5.01%
#   Bayes-Stein φ  : 0.4734  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3755
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.42%
#     treasury_fund   : 10.03%
#     gold_fund       : 11.34%
#
# ── Regime 1  (73 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.45%  →  BS -0.14%
#     treasury_fund   : sample +19.28%  →  BS +14.87%
#     gold_fund       : sample +11.68%  →  BS +9.28%
#   Bayes-Stein φ  : 0.4072  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1978
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.41%
#     treasury_fund   : 13.71%
#     gold_fund       : 15.86%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.38%
#   Volatility     (ann.) : 6.40%
#   Sharpe ratio          : 1.3094
#   Weights:
#     index_fund    : 0.3292  (32.9%)
#     treasury_fund : 0.3885  (38.8%)
#     gold_fund     : 0.2824  (28.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.59%
#   Volatility     (ann.) : 6.84%
#   Sharpe ratio          : 1.4008
#   Weights:
#     index_fund    : 0.4945  (49.5%)
#     treasury_fund : 0.3462  (34.6%)
#     gold_fund     : 0.1593  (15.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.45%
#   Volatility     (ann.) : 8.83%
#   Sharpe ratio          : 1.0699
#   Weights:
#     index_fund    : 0.2432  (24.3%)
#     treasury_fund : 0.4396  (44.0%)
#     gold_fund     : 0.3172  (31.7%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.08%
#   Volatility     (ann.) : 9.98%
#   Sharpe ratio          : 1.2098
#   Weights:
#     index_fund    : 0.0862  (8.6%)
#     treasury_fund : 0.6454  (64.5%)
#     gold_fund     : 0.2684  (26.8%)
#
# ── Regime 0  (293 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.17%  →  BS +13.03%
#     treasury_fund   : sample +5.90%  →  BS +7.17%
#     gold_fund       : sample +4.56%  →  BS +5.24%
#   Bayes-Stein φ  : 0.4737  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3638
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.46%
#     treasury_fund   : 10.03%
#     gold_fund       : 11.39%
#
# ── Regime 1  (73 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.45%  →  BS -0.06%
#     treasury_fund   : sample +19.28%  →  BS +14.91%
#     gold_fund       : sample +11.68%  →  BS +9.35%
#   Bayes-Stein φ  : 0.4082  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1978
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.41%
#     treasury_fund   : 13.71%
#     gold_fund       : 15.86%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.56%
#   Volatility     (ann.) : 6.44%
#   Sharpe ratio          : 1.3282
#   Weights:
#     index_fund    : 0.3290  (32.9%)
#     treasury_fund : 0.3910  (39.1%)
#     gold_fund     : 0.2800  (28.0%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.75%
#   Volatility     (ann.) : 6.88%
#   Sharpe ratio          : 1.4179
#   Weights:
#     index_fund    : 0.4932  (49.3%)
#     treasury_fund : 0.3468  (34.7%)
#     gold_fund     : 0.1600  (16.0%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.51%
#   Volatility     (ann.) : 8.83%
#   Sharpe ratio          : 1.0768
#   Weights:
#     index_fund    : 0.2432  (24.3%)
#     treasury_fund : 0.4396  (44.0%)
#     gold_fund     : 0.3172  (31.7%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.10%
#   Volatility     (ann.) : 9.96%
#   Sharpe ratio          : 1.2149
#   Weights:
#     index_fund    : 0.0876  (8.8%)
#     treasury_fund : 0.6431  (64.3%)
#     gold_fund     : 0.2693  (26.9%)
#
# ── Regime 0  (294 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.42%  →  BS +13.28%
#     treasury_fund   : sample +5.69%  →  BS +6.96%
#     gold_fund       : sample +4.83%  →  BS +5.47%
#   Bayes-Stein φ  : 0.4714  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3746
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.49%
#     treasury_fund   : 10.09%
#     gold_fund       : 11.43%
#
# ── Regime 1  (73 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.45%  →  BS -0.07%
#     treasury_fund   : sample +19.28%  →  BS +14.89%
#     gold_fund       : sample +11.68%  →  BS +9.47%
#   Bayes-Stein φ  : 0.4029  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1978
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.41%
#     treasury_fund   : 13.71%
#     gold_fund       : 15.86%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.62%
#   Volatility     (ann.) : 6.45%
#   Sharpe ratio          : 1.3356
#   Weights:
#     index_fund    : 0.3278  (32.8%)
#     treasury_fund : 0.3928  (39.3%)
#     gold_fund     : 0.2794  (27.9%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.85%
#   Volatility     (ann.) : 6.90%
#   Sharpe ratio          : 1.4283
#   Weights:
#     index_fund    : 0.4970  (49.7%)
#     treasury_fund : 0.3363  (33.6%)
#     gold_fund     : 0.1667  (16.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.53%
#   Volatility     (ann.) : 8.83%
#   Sharpe ratio          : 1.0798
#   Weights:
#     index_fund    : 0.2432  (24.3%)
#     treasury_fund : 0.4396  (44.0%)
#     gold_fund     : 0.3172  (31.7%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.11%
#   Volatility     (ann.) : 9.95%
#   Sharpe ratio          : 1.2169
#   Weights:
#     index_fund    : 0.0874  (8.7%)
#     treasury_fund : 0.6403  (64.0%)
#     gold_fund     : 0.2723  (27.2%)
#
# ── Regime 0  (295 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.19%  →  BS +13.05%
#     treasury_fund   : sample +5.70%  →  BS +6.98%
#     gold_fund       : sample +4.71%  →  BS +5.37%
#   Bayes-Stein φ  : 0.4756  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3661
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.52%
#     treasury_fund   : 10.07%
#     gold_fund       : 11.44%
#
# ── Regime 1  (73 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.45%  →  BS -0.10%
#     treasury_fund   : sample +19.28%  →  BS +14.87%
#     gold_fund       : sample +11.68%  →  BS +9.42%
#   Bayes-Stein φ  : 0.4048  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1978
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.41%
#     treasury_fund   : 13.71%
#     gold_fund       : 15.86%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.52%
#   Volatility     (ann.) : 6.46%
#   Sharpe ratio          : 1.3186
#   Weights:
#     index_fund    : 0.3262  (32.6%)
#     treasury_fund : 0.3953  (39.5%)
#     gold_fund     : 0.2784  (27.8%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.71%
#   Volatility     (ann.) : 6.90%
#   Sharpe ratio          : 1.4083
#   Weights:
#     index_fund    : 0.4930  (49.3%)
#     treasury_fund : 0.3437  (34.4%)
#     gold_fund     : 0.1633  (16.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.50%
#   Volatility     (ann.) : 8.83%
#   Sharpe ratio          : 1.0762
#   Weights:
#     index_fund    : 0.2432  (24.3%)
#     treasury_fund : 0.4396  (44.0%)
#     gold_fund     : 0.3172  (31.7%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.09%
#   Volatility     (ann.) : 9.96%
#   Sharpe ratio          : 1.2140
#   Weights:
#     index_fund    : 0.0869  (8.7%)
#     treasury_fund : 0.6416  (64.2%)
#     gold_fund     : 0.2716  (27.2%)
#
# ── Regime 0  (296 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +15.05%  →  BS +12.93%
#     treasury_fund   : sample +5.55%  →  BS +6.85%
#     gold_fund       : sample +4.65%  →  BS +5.31%
#   Bayes-Stein φ  : 0.4757  (mild shrinkage)
#   Ledoit-Wolf α  : 0.3684
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 11.52%
#     treasury_fund   : 10.08%
#     gold_fund       : 11.42%
#
# ── Regime 1  (73 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -7.45%  →  BS -0.17%
#     treasury_fund   : sample +19.28%  →  BS +14.84%
#     gold_fund       : sample +11.68%  →  BS +9.40%
#   Bayes-Stein φ  : 0.4035  (mild shrinkage)
#   Ledoit-Wolf α  : 0.1978
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.41%
#     treasury_fund   : 13.71%
#     gold_fund       : 15.86%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.40%
#   Volatility     (ann.) : 6.47%
#   Sharpe ratio          : 1.2986
#   Weights:
#     index_fund    : 0.3259  (32.6%)
#     treasury_fund : 0.3944  (39.4%)
#     gold_fund     : 0.2797  (28.0%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +9.61%
#   Volatility     (ann.) : 6.92%
#   Sharpe ratio          : 1.3888
#   Weights:
#     index_fund    : 0.4954  (49.5%)
#     treasury_fund : 0.3401  (34.0%)
#     gold_fund     : 0.1645  (16.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +9.47%
#   Volatility     (ann.) : 8.83%
#   Sharpe ratio          : 1.0720
#   Weights:
#     index_fund    : 0.2432  (24.3%)
#     treasury_fund : 0.4396  (44.0%)
#     gold_fund     : 0.3172  (31.7%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +12.07%
#   Volatility     (ann.) : 9.97%
#   Sharpe ratio          : 1.2107
#   Weights:
#     index_fund    : 0.0858  (8.6%)
#     treasury_fund : 0.6422  (64.2%)
#     gold_fund     : 0.2721  (27.2%)
#   Refitting at 2020-12-31 (t=370, window=370 months)...
#     No dim reduction: feeding 15 raw indicators
# Best log-likelihood (per sample): -1393.4456
# Sort method: 'trace'
# Transition matrix:
# [[0.95291323 0.04708677]
#  [0.31718    0.68282   ]]
# State durations (months): ['21.2', '3.2']
# State 0 = Expansion  (tr(Σ)=1.1218  PC1_mean=0.006)
# State 1 = Recession  (tr(Σ)=11.4317  PC1_mean=-0.279)
#
# ── Regime 0  (326 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.75%  →  BS +11.18%
#     treasury_fund   : sample +7.14%  →  BS +8.13%
#     gold_fund       : sample +5.35%  →  BS +5.87%
#   Bayes-Stein φ  : 0.8565  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.1788
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 12.77%
#     treasury_fund   : 9.98%
#     gold_fund       : 12.14%
#
# ── Regime 1  (44 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample -2.65%  →  BS +6.15%
#     treasury_fund   : sample +16.87%  →  BS +11.31%
#     gold_fund       : sample +10.51%  →  BS +7.56%
#   Bayes-Stein φ  : 0.6487  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3166
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 22.37%
#     treasury_fund   : 15.69%
#     gold_fund       : 15.67%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.54%
#   Volatility     (ann.) : 6.50%
#   Sharpe ratio          : 1.3130
#   Weights:
#     index_fund    : 0.3198  (32.0%)
#     treasury_fund : 0.4282  (42.8%)
#     gold_fund     : 0.2520  (25.2%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.96%
#   Volatility     (ann.) : 6.66%
#   Sharpe ratio          : 1.3452
#   Weights:
#     index_fund    : 0.3957  (39.6%)
#     treasury_fund : 0.4377  (43.8%)
#     gold_fund     : 0.1666  (16.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.80%
#   Volatility     (ann.) : 9.85%
#   Sharpe ratio          : 0.8938
#   Weights:
# ...
#     gold_fund     : 0.3129  (31.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.64%
#   Volatility     (ann.) : 7.40%
#   Sharpe ratio          : 1.1674
#   Weights:
#     index_fund    : 0.4420  (44.2%)
#     treasury_fund : 0.2886  (28.9%)
#     gold_fund     : 0.2694  (26.9%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.79%
#   Volatility     (ann.) : 9.78%
#   Sharpe ratio          : 0.7968
#   Weights:
#     index_fund    : 0.2248  (22.5%)
#     treasury_fund : 0.3728  (37.3%)
#     gold_fund     : 0.4025  (40.2%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.86%
#   Volatility     (ann.) : 9.82%
#   Sharpe ratio          : 0.8000
#   Weights:
#     index_fund    : 0.2548  (25.5%)
#     treasury_fund : 0.3824  (38.2%)
#     gold_fund     : 0.3628  (36.3%)
#
# ── Regime 0  (368 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.55%  →  BS +11.29%
#     treasury_fund   : sample +5.36%  →  BS +6.20%
#     gold_fund       : sample +6.36%  →  BS +6.61%
#   Bayes-Stein φ  : 0.8958  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2412
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.09%
#     treasury_fund   : 10.89%
#     gold_fund       : 12.10%
#
# ── Regime 1  (54 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +1.54%  →  BS +8.77%
#     treasury_fund   : sample +12.65%  →  BS +7.87%
#     gold_fund       : sample +8.55%  →  BS +7.11%
#   Bayes-Stein φ  : 0.7530  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3324
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.17%
#     treasury_fund   : 15.87%
#     gold_fund       : 15.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.92%
#   Volatility     (ann.) : 7.12%
#   Sharpe ratio          : 1.1125
#   Weights:
#     index_fund    : 0.3116  (31.2%)
#     treasury_fund : 0.3743  (37.4%)
#     gold_fund     : 0.3141  (31.4%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.53%
#   Volatility     (ann.) : 7.39%
#   Sharpe ratio          : 1.1550
#   Weights:
#     index_fund    : 0.4358  (43.6%)
#     treasury_fund : 0.2879  (28.8%)
#     gold_fund     : 0.2763  (27.6%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.77%
#   Volatility     (ann.) : 9.78%
#   Sharpe ratio          : 0.7940
#   Weights:
#     index_fund    : 0.2248  (22.5%)
#     treasury_fund : 0.3728  (37.3%)
#     gold_fund     : 0.4025  (40.2%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.82%
#   Volatility     (ann.) : 9.81%
#   Sharpe ratio          : 0.7967
#   Weights:
#     index_fund    : 0.2525  (25.3%)
#     treasury_fund : 0.3807  (38.1%)
#     gold_fund     : 0.3668  (36.7%)
#
# ── Regime 0  (369 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.51%  →  BS +11.25%
#     treasury_fund   : sample +5.31%  →  BS +6.15%
#     gold_fund       : sample +6.59%  →  BS +6.81%
#   Bayes-Stein φ  : 0.8958  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2425
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.07%
#     treasury_fund   : 10.89%
#     gold_fund       : 12.14%
#
# ── Regime 1  (54 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +1.54%  →  BS +8.75%
#     treasury_fund   : sample +12.65%  →  BS +7.82%
#     gold_fund       : sample +8.55%  →  BS +7.26%
#   Bayes-Stein φ  : 0.7540  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3324
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.17%
#     treasury_fund   : 15.87%
#     gold_fund       : 15.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.95%
#   Volatility     (ann.) : 7.11%
#   Sharpe ratio          : 1.1180
#   Weights:
#     index_fund    : 0.3121  (31.2%)
#     treasury_fund : 0.3750  (37.5%)
#     gold_fund     : 0.3130  (31.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.55%
#   Volatility     (ann.) : 7.38%
#   Sharpe ratio          : 1.1594
#   Weights:
#     index_fund    : 0.4335  (43.3%)
#     treasury_fund : 0.2831  (28.3%)
#     gold_fund     : 0.2834  (28.3%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.81%
#   Volatility     (ann.) : 9.78%
#   Sharpe ratio          : 0.7981
#   Weights:
#     index_fund    : 0.2248  (22.5%)
#     treasury_fund : 0.3728  (37.3%)
#     gold_fund     : 0.4025  (40.2%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.85%
#   Volatility     (ann.) : 9.81%
#   Sharpe ratio          : 0.8001
#   Weights:
#     index_fund    : 0.2507  (25.1%)
#     treasury_fund : 0.3764  (37.6%)
#     gold_fund     : 0.3730  (37.3%)
#
# ── Regime 0  (370 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.68%  →  BS +11.41%
#     treasury_fund   : sample +5.21%  →  BS +6.05%
#     gold_fund       : sample +6.64%  →  BS +6.86%
#   Bayes-Stein φ  : 0.8936  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2426
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.09%
#     treasury_fund   : 10.89%
#     gold_fund       : 12.13%
#
# ── Regime 1  (54 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +1.54%  →  BS +8.82%
#     treasury_fund   : sample +12.65%  →  BS +7.79%
#     gold_fund       : sample +8.55%  →  BS +7.30%
#   Bayes-Stein φ  : 0.7487  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3324
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.17%
#     treasury_fund   : 15.87%
#     gold_fund       : 15.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +7.97%
#   Volatility     (ann.) : 7.11%
#   Sharpe ratio          : 1.1222
#   Weights:
#     index_fund    : 0.3115  (31.2%)
#     treasury_fund : 0.3758  (37.6%)
#     gold_fund     : 0.3127  (31.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.62%
#   Volatility     (ann.) : 7.39%
#   Sharpe ratio          : 1.1670
#   Weights:
#     index_fund    : 0.4370  (43.7%)
#     treasury_fund : 0.2779  (27.8%)
#     gold_fund     : 0.2851  (28.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.82%
#   Volatility     (ann.) : 9.78%
#   Sharpe ratio          : 0.7998
#   Weights:
#     index_fund    : 0.2248  (22.5%)
#     treasury_fund : 0.3728  (37.3%)
#     gold_fund     : 0.4025  (40.2%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.87%
#   Volatility     (ann.) : 9.81%
#   Sharpe ratio          : 0.8019
#   Weights:
#     index_fund    : 0.2518  (25.2%)
#     treasury_fund : 0.3736  (37.4%)
#     gold_fund     : 0.3746  (37.5%)
#
# ── Regime 0  (371 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.80%  →  BS +11.52%
#     treasury_fund   : sample +5.27%  →  BS +6.11%
#     gold_fund       : sample +6.70%  →  BS +6.91%
#   Bayes-Stein φ  : 0.8930  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2413
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.08%
#     treasury_fund   : 10.88%
#     gold_fund       : 12.12%
#
# ── Regime 1  (54 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +1.54%  →  BS +8.89%
#     treasury_fund   : sample +12.65%  →  BS +7.83%
#     gold_fund       : sample +8.55%  →  BS +7.34%
#   Bayes-Stein φ  : 0.7481  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3324
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.17%
#     treasury_fund   : 15.87%
#     gold_fund       : 15.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.04%
#   Volatility     (ann.) : 7.11%
#   Sharpe ratio          : 1.1315
#   Weights:
#     index_fund    : 0.3110  (31.1%)
#     treasury_fund : 0.3760  (37.6%)
#     gold_fund     : 0.3130  (31.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.70%
#   Volatility     (ann.) : 7.39%
#   Sharpe ratio          : 1.1770
#   Weights:
#     index_fund    : 0.4372  (43.7%)
#     treasury_fund : 0.2781  (27.8%)
#     gold_fund     : 0.2847  (28.5%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.87%
#   Volatility     (ann.) : 9.78%
#   Sharpe ratio          : 0.8049
#   Weights:
#     index_fund    : 0.2248  (22.5%)
#     treasury_fund : 0.3728  (37.3%)
#     gold_fund     : 0.4025  (40.2%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.92%
#   Volatility     (ann.) : 9.81%
#   Sharpe ratio          : 0.8071
#   Weights:
#     index_fund    : 0.2523  (25.2%)
#     treasury_fund : 0.3736  (37.4%)
#     gold_fund     : 0.3741  (37.4%)
#
# ── Regime 0  (372 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.85%  →  BS +11.57%
#     treasury_fund   : sample +5.23%  →  BS +6.07%
#     gold_fund       : sample +6.67%  →  BS +6.88%
#   Bayes-Stein φ  : 0.8921  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2411
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.07%
#     treasury_fund   : 10.87%
#     gold_fund       : 12.11%
#
# ── Regime 1  (54 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +1.54%  →  BS +8.90%
#     treasury_fund   : sample +12.65%  →  BS +7.82%
#     gold_fund       : sample +8.55%  →  BS +7.32%
#   Bayes-Stein φ  : 0.7460  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3324
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.17%
#     treasury_fund   : 15.87%
#     gold_fund       : 15.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.03%
#   Volatility     (ann.) : 7.10%
#   Sharpe ratio          : 1.1316
#   Weights:
#     index_fund    : 0.3111  (31.1%)
#     treasury_fund : 0.3759  (37.6%)
#     gold_fund     : 0.3129  (31.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.72%
#   Volatility     (ann.) : 7.39%
#   Sharpe ratio          : 1.1786
#   Weights:
#     index_fund    : 0.4393  (43.9%)
#     treasury_fund : 0.2765  (27.6%)
#     gold_fund     : 0.2842  (28.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.86%
#   Volatility     (ann.) : 9.78%
#   Sharpe ratio          : 0.8038
#   Weights:
#     index_fund    : 0.2248  (22.5%)
#     treasury_fund : 0.3728  (37.3%)
#     gold_fund     : 0.4025  (40.2%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.91%
#   Volatility     (ann.) : 9.81%
#   Sharpe ratio          : 0.8061
#   Weights:
#     index_fund    : 0.2530  (25.3%)
#     treasury_fund : 0.3734  (37.3%)
#     gold_fund     : 0.3737  (37.4%)
#
# ── Regime 0  (373 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.88%  →  BS +11.60%
#     treasury_fund   : sample +5.23%  →  BS +6.07%
#     gold_fund       : sample +6.67%  →  BS +6.89%
#   Bayes-Stein φ  : 0.8917  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2411
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.05%
#     treasury_fund   : 10.86%
#     gold_fund       : 12.09%
#
# ── Regime 1  (54 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +1.54%  →  BS +8.92%
#     treasury_fund   : sample +12.65%  →  BS +7.82%
#     gold_fund       : sample +8.55%  →  BS +7.33%
#   Bayes-Stein φ  : 0.7453  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3324
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.17%
#     treasury_fund   : 15.87%
#     gold_fund       : 15.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.04%
#   Volatility     (ann.) : 7.09%
#   Sharpe ratio          : 1.1344
#   Weights:
#     index_fund    : 0.3111  (31.1%)
#     treasury_fund : 0.3760  (37.6%)
#     gold_fund     : 0.3129  (31.3%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.73%
#   Volatility     (ann.) : 7.39%
#   Sharpe ratio          : 1.1820
#   Weights:
#     index_fund    : 0.4399  (44.0%)
#     treasury_fund : 0.2759  (27.6%)
#     gold_fund     : 0.2841  (28.4%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.87%
#   Volatility     (ann.) : 9.78%
#   Sharpe ratio          : 0.8044
#   Weights:
#     index_fund    : 0.2248  (22.5%)
#     treasury_fund : 0.3728  (37.3%)
#     gold_fund     : 0.4025  (40.2%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +7.91%
#   Volatility     (ann.) : 9.81%
#   Sharpe ratio          : 0.8067
#   Weights:
#     index_fund    : 0.2532  (25.3%)
#     treasury_fund : 0.3732  (37.3%)
#     gold_fund     : 0.3736  (37.4%)
#
# ── Regime 0  (374 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +12.95%  →  BS +11.66%
#     treasury_fund   : sample +5.31%  →  BS +6.14%
#     gold_fund       : sample +6.94%  →  BS +7.12%
#   Bayes-Stein φ  : 0.8918  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2390
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.05%
#     treasury_fund   : 10.86%
#     gold_fund       : 12.16%
#
# ── Regime 1  (54 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +1.54%  →  BS +8.98%
#     treasury_fund   : sample +12.65%  →  BS +7.86%
#     gold_fund       : sample +8.55%  →  BS +7.50%
#   Bayes-Stein φ  : 0.7469  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3324
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.17%
#     treasury_fund   : 15.87%
#     gold_fund       : 15.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.17%
#   Volatility     (ann.) : 7.12%
#   Sharpe ratio          : 1.1477
#   Weights:
#     index_fund    : 0.3122  (31.2%)
#     treasury_fund : 0.3781  (37.8%)
#     gold_fund     : 0.3098  (31.0%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.84%
#   Volatility     (ann.) : 7.41%
#   Sharpe ratio          : 1.1941
#   Weights:
#     index_fund    : 0.4384  (43.8%)
#     treasury_fund : 0.2750  (27.5%)
#     gold_fund     : 0.2866  (28.7%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +7.97%
#   Volatility     (ann.) : 9.78%
#   Sharpe ratio          : 0.8147
#   Weights:
#     index_fund    : 0.2248  (22.5%)
#     treasury_fund : 0.3728  (37.3%)
#     gold_fund     : 0.4025  (40.2%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.01%
#   Volatility     (ann.) : 9.81%
#   Sharpe ratio          : 0.8167
#   Weights:
#     index_fund    : 0.2518  (25.2%)
#     treasury_fund : 0.3702  (37.0%)
#     gold_fund     : 0.3780  (37.8%)
#
# ── Regime 0  (375 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +13.00%  →  BS +11.71%
#     treasury_fund   : sample +5.34%  →  BS +6.16%
#     gold_fund       : sample +7.26%  →  BS +7.41%
#   Bayes-Stein φ  : 0.8916  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.2385
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 13.05%
#     treasury_fund   : 10.85%
#     gold_fund       : 12.25%
#
# ── Regime 1  (54 observations) ──
#   Mean returns — sample vs Bayes-Stein (annualized %):
#     index_fund      : sample +1.54%  →  BS +9.03%
#     treasury_fund   : sample +12.65%  →  BS +7.87%
#     gold_fund       : sample +8.55%  →  BS +7.71%
#   Bayes-Stein φ  : 0.7476  (heavy shrinkage)
#   Ledoit-Wolf α  : 0.3324
#   Implied annual volatilities (shrunk Σ):
#     index_fund      : 21.17%
#     treasury_fund   : 15.87%
#     gold_fund       : 15.07%
#
# ── min_variance  |  Regime 0 ──
#   Expected return (ann.) : +8.28%
#   Volatility     (ann.) : 7.14%
#   Sharpe ratio          : 1.1598
#   Weights:
#     index_fund    : 0.3133  (31.3%)
#     treasury_fund : 0.3811  (38.1%)
#     gold_fund     : 0.3056  (30.6%)
#
# ── max_sharpe  |  Regime 0 ──
#   Expected return (ann.) : +8.95%
#   Volatility     (ann.) : 7.42%
#   Sharpe ratio          : 1.2055
#   Weights:
#     index_fund    : 0.4367  (43.7%)
#     treasury_fund : 0.2728  (27.3%)
#     gold_fund     : 0.2905  (29.0%)
#
# ── min_variance  |  Regime 1 ──
#   Expected return (ann.) : +8.07%
#   Volatility     (ann.) : 9.78%
#   Sharpe ratio          : 0.8247
#   Weights:
#     index_fund    : 0.2248  (22.5%)
#     treasury_fund : 0.3728  (37.3%)
#     gold_fund     : 0.4025  (40.2%)
#
# ── max_sharpe  |  Regime 1 ──
#   Expected return (ann.) : +8.10%
#   Volatility     (ann.) : 9.80%
#   Sharpe ratio          : 0.8263
#   Weights:
#     index_fund    : 0.2499  (25.0%)
#     treasury_fund : 0.3658  (36.6%)
#     gold_fund     : 0.3843  (38.4%)
#
# Walk-forward results (84 months):
#   Ann. return  : 10.88%
#   Ann. vol     : 10.25%
#   Sharpe ratio : 1.061
#   Regime distribution: {0: 84}

# %%
# Compare HMM with and without dimensionality reduction
hmm_compare = pd.DataFrame({
    'HMM_WF (PLS, primary)': hmm_pls_returns['net_return_after_costs'],
    'HMM_WF (no reduction)': hmm_no_red_returns['net_return_after_costs'],
    '60_40':                 all_returns['60_40'],
    'Equal_Weight':          all_returns['Equal_Weight'],
}).dropna()

bench_ref = hmm_compare['60_40']
hmm_compare_perf = pd.DataFrame({
    col: summarize_performance(hmm_compare[col], bench_ref, rf_wf_annual)
    for col in hmm_compare.columns
})
avail = [m for m in metric_order if m in hmm_compare_perf.index]
hmm_compare_perf.loc[avail].to_csv(
    OUTPUT_TABLES_DIR / 'hmm_pls_vs_no_reduction.csv'
)
print('HMM: PLS (primary) vs No Reduction')
display(hmm_compare_perf.loc[avail])

fig, ax = plt.subplots(figsize=(12, 5))
hmm_cum = (1 + hmm_compare).cumprod()
colors = {
    'HMM_WF (PLS, primary)': ('#1a6faf', '-',  2.2),
    'HMM_WF (no reduction)': ('#ff7f0e', '-',  2.2),
    '60_40':                 ('#444444', ':',  1.2),
    'Equal_Weight':          ('#e07b00', ':',  1.2),
}
for col in hmm_cum.columns:
    c, ls, lw = colors.get(col, ('#888888', '--', 1.0))
    ax.plot(hmm_cum.index, hmm_cum[col], color=c, ls=ls, lw=lw, label=col)
ax.set_title('HMM Walk-Forward: PLS (primary) vs No Dimensionality Reduction')
ax.set_ylabel('Cumulative wealth (\$1 start)')
ax.legend(fontsize=9)
plt.tight_layout()
plt.savefig(OUTPUT_FIGURES_DIR / 'hmm_pls_vs_no_reduction.png',
            dpi=150, bbox_inches='tight')
plt.show()
# Out:
# HMM: PLS (primary) vs No Reduction
#                             HMM_WF (PLS, primary)  HMM_WF (no reduction)  \
# Annualized Return                        0.116662               0.108812
# Annualized Volatility                    0.100417               0.102524
# Sharpe Ratio                             0.887585               0.802010
# Sortino Ratio                            1.512261               1.372342
# Max Drawdown                            -0.200484              -0.213504
# VaR 95% (monthly)                        0.031975               0.033170
# CVaR 95% (monthly)                       0.049999               0.051373
# Information Ratio vs 60/40               0.218971               0.092588
#
#                                60_40  Equal_Weight
# Annualized Return           0.100091      0.120313
# Annualized Volatility       0.127855      0.099479
# Sharpe Ratio                0.603604      0.928138
# Sortino Ratio               0.948351      1.589837
# Max Drawdown               -0.257789     -0.196445
# VaR 95% (monthly)           0.055796      0.031279
# CVaR 95% (monthly)          0.070214      0.048962
# Information Ratio vs 60/40       NaN      0.267324

# %% [markdown]
# ### 3. PCA vs PLS comparison
#
# The PCA vs PLS comparison is embedded in the primary results: `HMM_PCA_WF` (robustness check 1) runs alongside `HMM_PLS_WF` (primary model) in the performance and cumulative wealth charts above. The walk-forward backtest outcome is the only empirical basis for preferring PLS over PCA here — PLS is more aligned with the portfolio objective by construction (it maximises covariance with asset returns rather than variance of the macro indicators), but a single historical evaluation window is limited evidence. Interpret the comparison cautiously.

# %%
# PCA vs PLS performance summary — draws on results already computed above
pls_compare = pd.DataFrame({
    'HMM_WF (PLS, primary)': hmm_pls_returns['net_return_after_costs'],
    'HMM_WF (PCA)':          hmm_pca_returns['net_return_after_costs'],
    '60_40':                  all_returns['60_40'],
    'Equal_Weight':           all_returns['Equal_Weight'],
}).dropna()

bench_ref = pls_compare['60_40']
pls_perf = pd.DataFrame({
    col: summarize_performance(pls_compare[col], bench_ref, rf_wf_annual)
    for col in pls_compare.columns
})
avail = [m for m in metric_order if m in pls_perf.index]
pls_perf.loc[avail].to_csv(OUTPUT_TABLES_DIR / 'hmm_pca_vs_pls.csv')
print('HMM: PCA vs PLS')
display(pls_perf.loc[avail])
# Out:
# HMM: PCA vs PLS
#                             HMM_WF (PLS, primary)  HMM_WF (PCA)     60_40  \
# Annualized Return                        0.116662      0.109168  0.100091
# Annualized Volatility                    0.100417      0.101552  0.127855
# Sharpe Ratio                             0.887585      0.811869  0.603604
# Sortino Ratio                            1.512261      1.380627  0.948351
# Max Drawdown                            -0.200484     -0.204347 -0.257789
# VaR 95% (monthly)                        0.031975      0.033575  0.055796
# CVaR 95% (monthly)                       0.049999      0.050170  0.070214
# Information Ratio vs 60/40               0.218971      0.090240       NaN
#
#                             Equal_Weight
# Annualized Return               0.120313
# Annualized Volatility           0.099479
# Sharpe Ratio                    0.928138
# Sortino Ratio                   1.589837
# Max Drawdown                   -0.196445
# VaR 95% (monthly)               0.031279
# CVaR 95% (monthly)              0.048962
# Information Ratio vs 60/40      0.267324

# %%
# Chart: cumulative wealth PLS vs PCA (reuses variables from above)
fig, ax = plt.subplots(figsize=(12, 5))
pls_cum = (1 + pls_compare).cumprod()
pls_colors = {
    'HMM_WF (PLS, primary)': ('#1a6faf', '-',  2.2),
    'HMM_WF (PCA)':          ('#2ca02c', '-',  2.2),
    '60_40':                 ('#444444', ':',  1.2),
    'Equal_Weight':          ('#e07b00', ':',  1.2),
}
for col in pls_cum.columns:
    c, ls, lw = pls_colors.get(col, ('#888888', '--', 1.0))
    ax.plot(pls_cum.index, pls_cum[col], color=c, ls=ls, lw=lw, label=col)
ax.set_title('HMM Walk-Forward: PLS (primary) vs PCA')
ax.set_ylabel('Cumulative wealth (\$1 start)')
ax.legend(fontsize=9)
plt.tight_layout()
plt.savefig(OUTPUT_FIGURES_DIR / 'hmm_pca_vs_pls.png',
            dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Save results

# %%
# Save all walk-forward outputs
all_returns.to_csv(OUTPUT_TABLES_DIR / 'walk_forward_returns.csv')

pd.DataFrame({
    'HMM_PLS_WF_State':  hmm_pls_states,
    'HMM_PCA_WF_State':  hmm_pca_states,
    'MSVAR_PCA_WF_State': msvar_pca_states,
}).to_csv(OUTPUT_TABLES_DIR / 'walk_forward_states.csv')

print('Saved:')
print('  walk_forward_returns.csv')
print('  walk_forward_states.csv')
print('  hmm_pls_vs_no_reduction.csv')
print('  hmm_pca_vs_pls.csv')
print('  gmv_strategies_comparison.csv')
# Out:
# Saved:
#   walk_forward_returns.csv
#   walk_forward_states.csv
#   hmm_pls_vs_no_reduction.csv
#   hmm_pca_vs_pls.csv
#   gmv_strategies_comparison.csv
